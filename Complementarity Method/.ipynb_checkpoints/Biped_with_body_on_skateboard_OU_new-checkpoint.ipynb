# %% [markdown]
# # Biped on Skateboard - OU

# %%
# import my libraries
import eomlib_biped_with_body
import skaterlib_biped_with_body_new
from importlib import reload
# import Python libraries
import cloudpickle
import numpy as np
import time
import winsound
from pyomo.environ import*
from pyomo.opt import SolverFactory
from pyomo.opt import SolverStatus, TerminationCondition

reload(eomlib_biped_with_body);
reload(skaterlib_biped_with_body_new);

# # Open a model to initialize the trajectory
# model = 'model_biped_RO_N65_25_09_2019_17_15.pkl' #0.5m rolling ollie
# model = 'model_biped_RO_N65_27_09_2019_09_09.pkl' # 0.5m, dq = 0 at N
# model = 'model_biped_RO_N65_30_09_2019_08_17.pkl' # 0.5m, dq = 0 at N, correct objective
# model = 'model_biped_RO_N65_30_09_2019_10_00.pkl' # 0.5m, dq = 0 at N, correct objective
# # model = 'model_biped_RO_N38_30_09_2019_23_25.pkl'
# model = 'model_biped_OU_N38_02_10_2019_16_18.pkl' # not working, but new stuff
# model = 'model_biped_OU_N38_03_10_2019_17_32.pkl'
model = 'model_biped_OU_N60_03_10_2019_17_53.pkl'
# model = 'model_biped_OU_N65_03_10_2019_20_01.pkl'
# model = 'model_biped_OU_N65_03_10_2019_20_48.pkl'

filepath = 'saved_models\\'
filename = filepath+model
with open(filename, mode='rb') as file:
    m_saved = cloudpickle.load(file)

# %%
# SKATEBOARD
EOMs_board_lamb = eomlib_biped_with_body.get_EOMs_board()
EOMs_board = EOMs_board_lamb[0]
lambEOMx_board   = EOMs_board_lamb[1][0]
lambEOMy_board   = EOMs_board_lamb[1][1]
lambEOMth_board  = EOMs_board_lamb[1][2]

# BIPED WITH BODY
EOMs_biped_lamb = eomlib_biped_with_body.get_EOMs_biped_with_body()
EOMs_biped = EOMs_biped_lamb[0]
lambEOMxp_biped    = EOMs_biped_lamb[1][0]
lambEOMyp_biped    = EOMs_biped_lamb[1][1]
lambEOMthp_biped   = EOMs_biped_lamb[1][2]
lambEOMthb_biped   = EOMs_biped_lamb[1][3]
lambEOMthll_biped  = EOMs_biped_lamb[1][4]
lambEOMrl_biped    = EOMs_biped_lamb[1][5]
lambEOMthlr_biped  = EOMs_biped_lamb[1][6]
lambEOMrr_biped    = EOMs_biped_lamb[1][7]

# FOOT POSITIONS AND VELOCITIES
EOMs_foot_lamb = eomlib_biped_with_body.get_foot_v_and_p()
lambfootx_l        = EOMs_foot_lamb[1][0][0]
lambfooty_l        = EOMs_foot_lamb[1][0][1]
lambfootx_l_board  = EOMs_foot_lamb[1][0][2]
lambfooty_l_board  = EOMs_foot_lamb[1][0][3]
lambvfootx_l_board = EOMs_foot_lamb[1][0][4]
lambfootx_r        = EOMs_foot_lamb[1][1][0]
lambfooty_r        = EOMs_foot_lamb[1][1][1]
lambfootx_r_board  = EOMs_foot_lamb[1][1][2]
lambfooty_r_board  = EOMs_foot_lamb[1][1][3]
lambvfootx_r_board = EOMs_foot_lamb[1][1][4]

# %%
if 'm' in globals():
    del m # deletes the model
    
m = ConcreteModel()

# SETS-----------------------------------------------------------------------------------------------------------------------

N = 30
N1 = 31 # the "pop" 
N2 = 55 # landing
N3 = 60 # steady
N4 = 65 # end
Nhw = round(0.5*(N1+N2)) # node to reach max height
m.N = RangeSet(N)

# %%
DOFs = ['x','y','th','xp','yp','thp','thb','thl_l','r_l','thl_r','r_r'] # generalized coordinates
m.DOF = Set(initialize = DOFs) 

Fs = ['BF','FF'] # front foot, backfoot
m.Fs = Set(initialize = Fs) 

legs = ['BL','FL'] # front leg, back leg
m.Legs = Set(initialize = legs) 

bodies = ['board','BL','FL'] # board, back leg, front leg
m.Bodies = Set(initialize = bodies) 

GRFs = ['BW','FW'] # front wheel, back wheel
m.GRFs = Set(initialize = GRFs) 

links = [('pelvis',1),('body',1),('left_leg',1),('left_leg',2),('right_leg',1),('right_leg',2)]
m.L = Set(dimen=2, initialize = links)

WDOFs = ['X','Y'] # absolute coordinates
m.WDOF = Set(initialize = WDOFs)

DOF_b = ['x_b','y_b'] # coordinates in skateboard frame
m.DOF_b = Set(initialize = DOF_b)

DOF_g = ['x_g','y_g'] # coordinates in ground frame
m.DOF_g = Set(initialize = DOF_g)

DOF_o = ['x_o','y_o'] # coordinates in obstruction frame
m.DOF_o = Set(initialize = DOF_o)

Bd = ['nose','tail','BW','FW'] # front foot, backfoot
m.Bd = Set(initialize = Bd) 

# PARAMETERS-----------------------------------------------------------------------------------------------------------------

# general
m.g = Param(initialize = 9.81) # gravity

# board
m.mbd = Param(initialize = 2.0) # mass of board
m.lbd = Param(initialize = 0.80) # length of board
m.lbrd = Param(initialize = 0.45) # length between wheels lb-(14.3+3)*2
m.hbd = Param(initialize = 0.09) # board clearance
m.etail = Param(initialize = -0.6) #coefficient of restitution of tail
m.Inbd = Param(initialize = 1/12*m.mbd*m.lbd**2) # moment of inertia about centre

h_h = 1.7 # human height
h_m = 73.0  # human weight

l_pelvis = 0.4 #1.7*0.191
h_knee = 0.45
h_thigh = 0.45
hr_max = 0.45
h_body = h_h - h_knee - h_thigh

m_knee = 2.0/20.0*h_m
m_thigh = 2.0/20.0*h_m
m_pelvis = 2.0/20.0*h_m
m_body = h_m - 2*m_thigh - 2*m_knee - m_pelvis

X_step = 1.2 # 2m
Y_step = 0.36
A_step = 1000.0

# biped
def get_m(n, lb, ln):
    l = (lb,ln)
    if lb == 'body':
        return m_body
    if lb == 'pelvis':
        return m_pelvis
    if l == ('left_leg',1) or l == ('right_leg',1): 
        return m_thigh
    if l == ('left_leg',2) or l == ('right_leg',2):
        return m_knee
m.m = Param(m.L, initialize = get_m) # mass of links

def get_len(n, lb, ln):
    l = (lb,ln)
    if lb == 'body':
        return h_body
    if lb == 'pelvis':
        return l_pelvis
    if l == ('left_leg',1) or l == ('right_leg',1): 
        return h_thigh
    if l == ('left_leg',2) or l == ('right_leg',2):
        return h_knee
m.len = Param(m.L, initialize = get_len) # length of links

def calculate_In(m, lb, ln): 
    l = (lb,ln)
    return 1/12*m.m[l]*m.len[l]**2 
m.In = Param(m.L, initialize = calculate_In) # moment of inertia

m_biped = sum(m.m[l] for l in links)
BW = m_biped*m.g

# %%
# VARIABLES -----------------------------------------------------------------------------------------------------------------

# system coordinates
m.q = Var(m.N, m.DOF) # position
m.dq = Var(m.N, m.DOF) # velocity
m.ddq = Var(m.N, m.DOF) # acceleration

# applied and ground reaction forces and torques
# sign set for positive and negative components
signs = ['ps','ng'] 
m.sgn = Set(initialize = signs)

m.Fb_b = Var(m.N, m.Fs, m.DOF_b, m.sgn, bounds = (0.0,None)) # Forces from front and back feet, board frame
m.Fb_b_total = Var(m.N, m.Fs, m.DOF_b)
m.GRF = Var(m.N, m.GRFs, bounds = (0.0, None)) # Ground reaction force on front and back wheel
m.GRF_s = Var(m.N, m.GRFs, bounds = (0.0, None)) # Ground reaction force on front and back wheel from step
m.GRFbf = Var(m.N, m.Fs, m.WDOF)
m.tau_a = Var(m.N, m.Legs, bounds = (-1.0,1.0)) # actuator torque at hip
m.tau_b = Var(m.N, bounds = (-1.0,1.0)) # actuator torque at body
m.F_a = Var(m.N, m.Legs, bounds = (-3.0,3.0)) # actuator force at knee
m.F_r = Var(m.N, m.Legs, m.sgn, bounds = (0.0,None)) # rebound force (acts parallel to the leg)

# AUXILIARY VARIABLES

# skateboard
m.ptail = Var(m.N, m.WDOF) # back of board
m.pnose = Var(m.N, m.WDOF) # front of board
m.pwheel = Var(m.N, m.GRFs, m.WDOF) # position of wheels
m.vtail = Var(m.N, m.WDOF) # velocity of back of board

def def_ptail(m,n,dof):
    if dof == 'X':
        return m.ptail[n, 'X'] == m.q[n,'x'] - 0.5*m.lbd*cos(m.q[n,'th'])
    if dof == 'Y':
        return m.ptail[n, 'Y'] == m.q[n,'y'] - 0.5*m.lbd*sin(m.q[n,'th']) 
    else:
        return Constraint.Skip
m.def_ptail = Constraint(m.N, m.WDOF,rule = def_ptail)

def def_pnose(m,n,dof):
    if dof == 'X':
        return m.pnose[n, 'X'] == m.q[n,'x'] + 0.5*m.lbd*cos(m.q[n,'th'])
    if dof == 'Y':
        return m.pnose[n, 'Y'] == m.q[n,'y'] + 0.5*m.lbd*sin(m.q[n,'th']) 
    else:
        return Constraint.Skip
m.def_pnose = Constraint(m.N, m.WDOF,rule = def_pnose)

def def_pwheels(m,n,wheel,dof):
    if wheel == 'BW':
        if dof == 'X':
            return m.pwheel[n,'BW','X'] == m.q[n,'x']-0.5*m.lbrd*cos(m.q[n,'th'])+m.hbd*sin(m.q[n,'th'])
        if dof == 'Y':
            return m.pwheel[n,'BW','Y'] == m.q[n,'y']-0.5*m.lbrd*sin(m.q[n,'th'])-m.hbd*cos(m.q[n,'th'])
        else:
            return Constraint.Skip
    if wheel == "FW":
        if dof == 'X':
            return m.pwheel[n,'FW','X'] == m.q[n,'x']+0.5*m.lbrd*cos(m.q[n,'th'])+m.hbd*sin(m.q[n,'th'])
        if dof == 'Y':
            return m.pwheel[n,'FW','Y'] == m.q[n,'y']+0.5*m.lbrd*sin(m.q[n,'th'])-m.hbd*cos(m.q[n,'th'])
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_pwheels = Constraint(m.N, m.GRFs, m.WDOF,rule = def_pwheels)

def def_vtail(m,n,dof):
    if dof == 'Y':
        return m.vtail[n, 'Y'] == m.dq[n,'y']-m.dq[n,'th']*0.5*m.lbd*cos(m.q[n,'th'])
    else:
        return Constraint.Skip
m.def_vtail = Constraint(m.N, m.WDOF,rule = def_vtail)

# skateboard - bound variables
for n in range(1,N+1):
    m.q[n,'th'].setub(np.pi/2)
    m.q[n,'th'].setlb(-np.pi/2)

# %%
# Ground function stuff ------------------------------------------------------------------------------------------------------------
m.Gfunc = Var(m.N, m.Bd, m.WDOF, bounds = (0.0, Y_step)) # ground function
m.pwheel_sgn_g = Var(m.N, m.GRFs, m.DOF_g, m.sgn, bounds = (0.0, None)) # position of wheels - slack

def def_pwheel_sgn_g(m,n,grf):
    if grf == 'BW':
        return m.pwheel_sgn_g[n,'BW','x_g','ps'] - m.pwheel_sgn_g[n,'BW','x_g','ng'] == m.pwheel[n,'BW','X'] - X_step
    if grf == 'FW':
        return m.pwheel_sgn_g[n,'FW','x_g','ps'] - m.pwheel_sgn_g[n,'FW','x_g','ng'] == m.pwheel[n,'FW','X'] - X_step
    else:
        return Constraint.Skip
m.def_pwheel_sgn_g = Constraint(m.N, m.GRFs,rule = def_pwheel_sgn_g)

m.pwheel_sgn_g2 = Var(m.N, m.GRFs, m.DOF_g, m.sgn, bounds = (0.0, None)) # position of wheels - slack

eps = 0.01

def def_pwheel_sgn_g2(m,n,grf):
    if grf == 'BW':
        return m.pwheel_sgn_g2[n,'BW','x_g','ps'] - m.pwheel_sgn_g2[n,'BW','x_g','ng'] == m.pwheel[n,'BW','X'] - X_step - eps
    if grf == 'FW':
        return m.pwheel_sgn_g2[n,'FW','x_g','ps'] - m.pwheel_sgn_g2[n,'FW','x_g','ng'] == m.pwheel[n,'FW','X'] - X_step - eps
    else:
        return Constraint.Skip
m.def_pwheel_sgn_g2 = Constraint(m.N, m.GRFs,rule = def_pwheel_sgn_g2)

# penalty for handling the changing ground function
ground_func_constraints = ['contact_BW1','contact_FW1','contact_BW2','contact_FW2','contact_BWmeh','contact_FWmeh']
m.ground_func_constraints = Set(initialize = ground_func_constraints) # set for indexing ground-related penalties
m.ground_func_penalty = Var(m.N, m.ground_func_constraints, bounds = (0.0,None))

def def_meh(m,n,gc):
    if gc == 'contact_BWmeh':
        return m.ground_func_penalty[n,'contact_BW1'] == m.pwheel_sgn_g[n,'BW','x_g','ps']*m.pwheel_sgn_g[n,'BW','x_g','ng']
    if gc == 'contact_FWmeh':
        return m.ground_func_penalty[n,'contact_FW1'] == m.pwheel_sgn_g[n,'FW','x_g','ps']*m.pwheel_sgn_g[n,'FW','x_g','ng']
    else:
        return Constraint.Skip
m.def_meh = Constraint(m.N, m.ground_func_constraints, rule = def_meh)

def def_Gfunc(m,n,gc):
    if gc == 'contact_BW1':
        return m.ground_func_penalty[n,'contact_BW1'] == m.Gfunc[n,'BW','Y']*m.pwheel_sgn_g[n,'BW','x_g','ng']
    if gc == 'contact_FW1':
        return m.ground_func_penalty[n,'contact_FW1'] == m.Gfunc[n,'FW','Y']*m.pwheel_sgn_g[n,'FW','x_g','ng']
    if gc == 'contact_BW2':
        return m.ground_func_penalty[n,'contact_BW2'] == (Y_step - m.Gfunc[n,'BW','Y'])*m.pwheel_sgn_g[n,'BW','x_g','ps']
    if gc == 'contact_FW2':
        return m.ground_func_penalty[n,'contact_FW2'] == (Y_step - m.Gfunc[n,'FW','Y'])*m.pwheel_sgn_g[n,'FW','x_g','ps']
    else:
        return Constraint.Skip
m.def_Gfunc = Constraint(m.N, m.ground_func_constraints, rule = def_Gfunc)

# %%
# Inequaliies for ground function ----------------------------------------------------------------------------------------

m.ptail_g = Var(m.N, m.DOF_g) # back of board
m.pnose_g = Var(m.N, m.DOF_g) # front of board
m.pwheel_g = Var(m.N, m.GRFs, m.DOF_g) # position of wheels

def board_g(m,n,bd):
#     if bd == 'nose':
#         return m.pnose_g[n,'y_g'] == m.pnose[n,'Y'] - m.Gfunc[n,'nose','Y']
    if bd == 'tail':
        return m.ptail_g[n,'y_g'] == m.ptail[n,'Y'] - m.Gfunc[n,'tail','Y']
    if bd == 'BW':
        return m.pwheel_g[n,'BW','y_g'] == m.pwheel[n,'BW','Y'] - m.Gfunc[n,'BW','Y']
    if bd == 'FW':
        return m.pwheel_g[n,'FW','y_g'] == m.pwheel[n,'FW','Y'] - m.Gfunc[n,'FW','Y']
    else: 
        return Constraint.Skip
m.board_g = Constraint(m.N, m.Bd, rule = board_g)

for n in range(1,N+1):
#     m.pnose[n,'Y'].setlb(0.0)
#     m.ptail_g[n,'y_g'].setlb(0.0)
    m.pnose[n,'Y'].setlb(0.0)
    m.ptail[n,'Y'].setlb(0.0)
    m.pwheel_g[n,'BW','y_g'].setlb(0.0)
    m.pwheel_g[n,'FW','y_g'].setlb(0.0)

# %%
# # Ross bump function stuff ------------------------------------------------------------------------------------------------------------
# m.OBSfunc = Var(m.N, m.Bd, m.WDOF) # ground function

# def def_OBSfunc(m,n,bd):
# #     if bd == 'nose':
# #         return m.pnose_g[n,'y_g'] == m.pnose[n,'Y'] - m.Gfunc[n,'nose','Y']
# #     if bd == 'tail':
# #         return m.ptail_g[n,'y_g'] == m.ptail[n,'Y'] - m.Gfunc[n,'tail','Y']
#     if bd == 'BW':
#         return m.OBSfunc[n,'BW','Y'] == -A_step*(m.pwheel[n,'BW','X']-X_step)**2 + Y_step
#     if bd == 'FW':
#         return m.OBSfunc[n,'FW','Y'] == -A_step*(m.pwheel[n,'FW','X']-X_step)**2 + Y_step
#     else: 
#         return Constraint.Skip
# m.def_OBSfunc = Constraint(m.N, m.Bd, rule = def_OBSfunc)

# def def_ineq_OBSfunc(m,n,bd):
# #     if bd == 'nose':
# #         return m.pnose_g[n,'y_g'] == m.pnose[n,'Y'] - m.Gfunc[n,'nose','Y']
# #     if bd == 'tail':
# #         return m.ptail_g[n,'y_g'] == m.ptail[n,'Y'] - m.Gfunc[n,'tail','Y']
#     if bd == 'BW':
#         return m.pwheel[n,'BW','Y'] >= m.OBSfunc[n,'BW','Y']
#     if bd == 'FW':
#         return m.pwheel[n,'FW','Y'] >= m.OBSfunc[n,'FW','Y']
#     else: 
#         return Constraint.Skip
# m.def_ineq_OBSfunc = Constraint(m.N, m.Bd, rule = def_ineq_OBSfunc)

# %%
# biped - bound variables
for n in range(1,N+1):  
    m.q[n,'thb'].setlb(np.pi/4)
    m.q[n,'thb'].setub(np.pi-np.pi/4)
    m.q[n,'thp'].setlb(-np.pi/2)
    m.q[n,'thp'].setub(np.pi/2)
    m.q[n,'thl_l'].setlb(-np.pi/2)
    m.q[n,'thl_l'].setub(np.pi/2)
    m.q[n,'thl_r'].setlb(-np.pi/2)
    m.q[n,'thl_r'].setub(np.pi/2)
    #m.GRFbf[n,'Y'].setlb(0.0)

# biped 
m.pfoot = Var(m.N, m.Fs, m.WDOF) # foot position
m.pfoot_b = Var(m.N, m.Fs, m.DOF_b) # foot position in skateboard frame
m.vfoot_b = Var(m.N, m.Fs, m.DOF_b, m.sgn, bounds = (0.0,None)) # foot velocity

for n in range(1,N+1):  
    m.pfoot[n,'BF','Y'].setlb(0.0)
    m.pfoot_b[n,'BF','y_b'].setlb(0.0)
    m.pfoot_b[n,'BF','x_b'].setub(0.0)
    m.pfoot_b[n,'BF','x_b'].setlb(-0.5*m.lbd)
    m.pfoot[n,'FF','Y'].setlb(0.0)
    m.pfoot_b[n,'FF','y_b'].setlb(0.0)
    m.pfoot_b[n,'FF','x_b'].setlb(0.0)
    m.pfoot_b[n,'FF','x_b'].setub(0.5*m.lbd)

def def_pfoot(m,n,fs,dof):
    # world frame
    if fs == 'BF':
        var_list = [m.len[('pelvis',1)], m.len[('left_leg',1)],m.len[('left_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_l'], m.q[n,'r_l']]
        if dof == 'X':
            return m.pfoot[n,'BF','X'] == lambfootx_l(*var_list)
        if dof == 'Y':
            return m.pfoot[n,'BF','Y'] == lambfooty_l(*var_list)
        else:
            return Constraint.Skip
    if fs == 'FF':
        var_list = [m.len[('pelvis',1)], m.len[('right_leg',1)],m.len[('right_leg',2)],
                        m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_r'], m.q[n,'r_r']]
        if dof == 'X':
            return m.pfoot[n,'FF','X'] == lambfootx_r(*var_list)
        if dof == 'Y':
            return m.pfoot[n,'FF','Y'] == lambfooty_r(*var_list)
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_pfoot = Constraint(m.N, m.Fs, m.WDOF, rule = def_pfoot)    
    
def def_pfoot_b(m,n,fs,dof): # board frame
    if fs == 'BF':
        var_list = [m.len[('pelvis',1)],m.len[('left_leg',1)],m.len[('left_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_l'], m.q[n,'r_l']]
        if dof == 'x_b':
            return m.pfoot_b[n,'BF','x_b'] == lambfootx_l_board(*var_list)
        if dof == 'y_b':
            return m.pfoot_b[n,'BF','y_b'] == lambfooty_l_board(*var_list)
        else:
            return Constraint.Skip
    if fs == 'FF':
        var_list = [m.len[('pelvis',1)], m.len[('right_leg',1)],m.len[('right_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_r'], m.q[n,'r_r']]
        if dof == 'x_b':
            return m.pfoot_b[n,'FF','x_b'] == lambfootx_r_board(*var_list)
        if dof == 'y_b':
            return m.pfoot_b[n,'FF','y_b'] == lambfooty_r_board(*var_list)
        else:
            return Constraint.Skip
m.def_pfoot_b = Constraint(m.N, m.Fs, m.DOF_b, rule = def_pfoot_b)      

def def_vfoot_b(m,n,fs,dof): # board frame
    if fs == 'BF':
        var_list = [m.len[('pelvis',1)], m.len[('left_leg',1)],m.len[('left_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_l'], m.q[n,'r_l'],
                    m.dq[n,'x'], m.dq[n,'y'], m.dq[n,'th'], m.dq[n,'xp'], m.dq[n,'yp'], m.dq[n,'thp'], m.dq[n,'thl_l'], m.dq[n,'r_l']]
        if dof == 'x_b':
            return m.vfoot_b[n,'BF','x_b','ps'] - m.vfoot_b[n,'BF','x_b','ng'] == lambvfootx_l_board(*var_list)
        else:
            return Constraint.Skip
    if fs == 'FF':
        var_list = [m.len[('pelvis',1)], m.len[('right_leg',1)],m.len[('right_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_r'], m.q[n,'r_r'],
                    m.dq[n,'x'], m.dq[n,'y'], m.dq[n,'th'], m.dq[n,'xp'], m.dq[n,'yp'], m.dq[n,'thp'], m.dq[n,'thl_r'], m.dq[n,'r_r']]
        if dof == 'x_b':
            return m.vfoot_b[n,'FF','x_b','ps'] - m.vfoot_b[n,'FF','x_b','ng'] == lambvfootx_r_board(*var_list)
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_vfoot_b = Constraint(m.N, m.Fs, m.DOF_b, rule = def_vfoot_b)

def def_Fb_b_total(m,n,fs,dof):
    if fs == 'BF':
        if dof == 'x_b':
            return m.Fb_b_total[n,'BF','x_b'] == m.Fb_b[n,'BF','x_b','ps']-m.Fb_b[n,'BF','x_b','ng']
        if dof == 'y_b':
            return m.Fb_b_total[n,'BF','y_b'] == m.Fb_b[n,'BF','y_b','ps']
        else:
            return Constraint.Skip
    if fs == 'FF':
        if dof == 'x_b':
            return m.Fb_b_total[n,'FF','x_b'] == m.Fb_b[n,'FF','x_b','ps']-m.Fb_b[n,'FF','x_b','ng']
        if dof == 'y_b':
            return m.Fb_b_total[n,'FF','y_b'] == m.Fb_b[n,'FF','y_b','ps']
    else:
        return Constraint.Skip
m.def_Fb_b_total = Constraint(m.N, m.Fs, m.DOF_b, rule = def_Fb_b_total) 

# Constraints for foot and board contact --------------------------------------------------------------------------------------

m.rF = Var(m.N, m.Fs) # distance to applied force

def def_rF(m,n,fs): # contact point on board
    if fs == 'BF':
        return m.rF[n,'BF'] == -m.pfoot_b[n,'BF','x_b']
    if fs == 'FF':
        return m.rF[n,'FF'] == m.pfoot_b[n,'FF','x_b']
    else:
        return Constraint.Skip
m.def_rF = Constraint(m.N, m.Fs, rule = def_rF)

# %%
# TIME AND INTEGRATION --------------------------------------------------------------------------------------------------------

# variable timestep
hm  = 0.01 #master timestep
m.h = Var(m.N, bounds = (0.8,1.2))

# Integration constraints 
def BwEuler_p(m,n,dof): # for positions
    if n > 1:
        return m.q[n,dof] == m.q[n-1,dof] + hm*m.h[n]*m.dq[n,dof]
    else:
        return Constraint.Skip 
m.integrate_p = Constraint(m.N, m.DOF, rule = BwEuler_p)

def BwEuler_v(m,n,dof): # for velocities
    if n > 1:
        if n==N1 and dof == 'y':
            return m.dq[n,'y'] == m.etail*m.vtail[n-1,'Y'] +  m.dq[n-1,'y'] + hm*m.h[n]*m.ddq[n-1,'y'] #switching constraint at impact of tail and ground
        else:    
            return m.dq[n,dof] == m.dq[n-1,dof] + hm*m.h[n]*m.ddq[n-1,dof]
    else:
        return Constraint.Skip 
m.integrate_v = Constraint(m.N, m.DOF, rule = BwEuler_v)

m.h[1].fix(0.0) # fix un-used time step

# %%
# AUXILIARY TO RESOLVE FOOT AND BOARD FORCES
# The back and front foot applied forces on the board, and the applied force of the monopod are in their own frames
# Need to transform them into the global frame.

m.F = Var(m.N, m.Bodies, m.Fs, m.WDOF) # Forces, global frame
m.thA = Var(m.N, m.Legs) # absolute angle of monopod

def def_thA(m,n,leg):
    if leg == 'BL':
        return m.thA[n, 'BL'] == m.q[n,'thp'] + m.q[n,'thl_l']
    if leg == 'FL':
        return m.thA[n, 'FL'] == m.q[n,'thp'] + m.q[n,'thl_r']
    else:
        return Constraint.Skip
m.def_thA = Constraint(m.N, m.Legs, rule = def_thA)

def def_F(m,n,body,fs,dof):
    if fs == 'BF':
        if body == 'BL':
            if dof == 'X':
                return m.F[n,'BL','BF','X'] == m.GRFbf[n,'BF','X']
            if dof == 'Y':
                return m.F[n,'BL','BF','Y'] == m.GRFbf[n,'BF','Y']
            else:
                return Constraint.Skip
        if body == 'board':
            if dof == 'X':
                return m.F[n,'board','BF','X'] == m.Fb_b_total[n,'BF','x_b']*cos(m.q[n,'th']) + m.Fb_b_total[n,'BF','y_b']*sin(m.q[n,'th'])
            if dof == 'Y':
                return m.F[n,'board','BF','Y'] == m.Fb_b_total[n,'BF','x_b']*sin(m.q[n,'th']) - m.Fb_b_total[n,'BF','y_b']*cos(m.q[n,'th'])
            else:
                return Constraint.Skip
        else:
            return Constraint.Skip
    if fs == 'FF':
        if body == 'FL':
            if dof == 'X':
                return m.F[n,'FL','FF','X'] == m.GRFbf[n,'FF','X']
            if dof == 'Y':
                return m.F[n,'FL','FF','Y'] == m.GRFbf[n,'FF','Y'] 
            else:
                return Constraint.Skip
        if body == 'board':
            if dof == 'X':
                return m.F[n,'board','FF','X'] == m.Fb_b_total[n,'FF','x_b']*cos(m.q[n,'th']) + m.Fb_b_total[n,'FF','y_b']*sin(m.q[n,'th'])
            if dof == 'Y':
                return m.F[n,'board','FF','Y'] == m.Fb_b_total[n,'FF','x_b']*sin(m.q[n,'th']) - m.Fb_b_total[n,'FF','y_b']*cos(m.q[n,'th'])
            else:
                return Constraint.Skip
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_F = Constraint(m.N, m.Bodies, m.Fs, m.WDOF, rule = def_F)

def def_contact_forces(m,n,fs,dof): # resolve into X and Y - global frame
    if fs == 'BF':
        if dof == 'X':
            return m.F[n,'BL','BF','X'] == -m.F[n,'board','BF','X']
        if dof == 'Y':
            return m.F[n,'BL','BF','Y'] == -m.F[n,'board','BF','Y']
        else:
            return Constraint.Skip
    if fs == 'FF':
        if dof == 'X':
            return m.F[n,'FL','FF','X'] == -m.F[n,'board','FF','X']
        if dof == 'Y':
            return m.F[n,'FL','FF','Y'] == -m.F[n,'board','FF','Y']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_contact_forces = Constraint(m.N, m.Fs, m.WDOF, rule = def_contact_forces)

# %%
# -----------------------------------------------------------------------------------------------------------------------------
# Contact Forces
# -----------------------------------------------------------------------------------------------------------------------------
# paramters
m.mu = Param(initialize = 0.78) # friction coefficient

ground_constraints = ['contact_BW','contact_FW','step_BW','step_FW','GRF_BW_penalty',
                      'GRF_FW_penalty','GRFs_BW_penalty','GRFs_FW_penalty']
m.ground_constraints = Set(initialize = ground_constraints) # set for indexing ground-related penalties
m.ground_penalty = Var(m.N, m.ground_constraints, bounds = (0.0,None))

contact_constraints = ['contact_Fy', 'friction','slip_x_ps','slip_x_ng','foot_velocity']
m.contact_constraints = Set(initialize = contact_constraints) # set for indexing ground-related penalties
m.contact_penalty = Var(m.N, m.Fs, m.contact_constraints, bounds = (0.0,None))

m.friction_cone = Var(m.N, m.Fs, bounds = (0.0,None))

# ground contact complemetarity  
def ground_contact(m,n,gc):
    if n < N: 
        if gc == 'contact_BW':
            return m.ground_penalty[n,'contact_BW'] == m.pwheel[n+1,'BW','Y']*m.GRF[n,'BW']
        if gc == 'contact_FW':
            return m.ground_penalty[n,'contact_FW'] == m.pwheel[n+1,'FW','Y']*m.GRF[n,'FW']
        if gc == 'step_BW':
            return m.ground_penalty[n,'step_BW'] == (m.pwheel[n+1,'BW','Y']-Y_step)*m.GRF_s[n,'BW']
        if gc == 'step_FW':
            return m.ground_penalty[n,'step_FW'] == (m.pwheel[n+1,'FW','Y']-Y_step)*m.GRF_s[n,'FW']
#         if gc == 'xpos_BW':
#             return m.ground_penalty[n,'xpos_BW'] == m.pwheel_sgn_g[n,'BW','x_g','ng']*m.GRF[n,'FW']
#         if gc == 'xneg_BW':
#             return m.ground_penalty[n,'xneg_BW'] == m.pwheel_sgn_g[n,'BW','x_g','ps']*m.GRF[n,'FW']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.ground_contact = Constraint(m.N, m.ground_constraints, rule = ground_contact)

# compliment GRF and GRF_s  
def GRF_penalty(m,n,gc):
    if n < N:
        if gc == 'GRF_BW_penalty':
            return m.ground_penalty[n,'GRF_BW_penalty']  == m.pwheel_sgn_g2[n,'BW','x_g','ps']*m.GRF[n,'BW']
        if gc == 'GRFs_BW_penalty':
            return m.ground_penalty[n,'GRFs_BW_penalty'] == (m.pwheel_sgn_g2[n,'BW','x_g','ng'])*m.GRF_s[n,'BW']
        if gc == 'GRF_FW_penalty':
            return m.ground_penalty[n,'GRF_FW_penalty']  == m.pwheel_sgn_g2[n,'FW','x_g','ps']*m.GRF[n,'FW']
        if gc == 'GRFs_FW_penalty':
            return m.ground_penalty[n,'GRFs_FW_penalty'] == (m.pwheel_sgn_g2[n,'FW','x_g','ng'])*m.GRF_s[n,'FW']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.GRF_penalty = Constraint(m.N,m.ground_constraints, rule = GRF_penalty)

# foot on board contact complemetarity  
def foot_board_contact(m,n,fs,cc):
    if n < N:
        if fs == 'BF':
            if cc == 'contact_Fy':
                return m.contact_penalty[n,'BF','contact_Fy'] == m.pfoot_b[n+1,'BF','y_b']*m.Fb_b[n,'BF','y_b','ps']
            else:
                return Constraint.Skip
        if fs == 'FF':
            if cc == 'contact_Fy':
                return m.contact_penalty[n,'FF','contact_Fy'] == m.pfoot_b[n+1,'FF','y_b']*m.Fb_b[n,'FF','y_b','ps']
            else:
                return Constraint.Skip
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.foot_board_contact = Constraint(m.N, m.Fs, m.contact_constraints, rule = foot_board_contact)

# Friction
def def_friction_cone(m,n,fs):
    if fs == 'BF':
        return m.friction_cone[n,'BF'] == m.mu*m.Fb_b[n,'BF','y_b','ps'] - (m.Fb_b[n,'BF','x_b','ps']+m.Fb_b[n,'BF','x_b','ng'])
    if fs == 'FF':
        return m.friction_cone[n,'FF'] == m.mu*m.Fb_b[n,'FF','y_b','ps'] - (m.Fb_b[n,'FF','x_b','ps']+m.Fb_b[n,'FF','x_b','ng'])
    else:
        return Constraint.Skip
m.def_friction_cone = Constraint(m.N, m.Fs, rule = def_friction_cone)

def board_friction(m,n,fs): # the foot can't move if not over max static friction, and no normal force means no friction force.
    if fs == 'BF':
        return m.contact_penalty[n,'BF','friction'] == (m.vfoot_b[n,'BF','x_b','ps']+m.vfoot_b[n,'BF','x_b','ng'])*m.friction_cone[n,'BF']
    if fs == 'FF':
        return m.contact_penalty[n,'FF','friction'] == (m.vfoot_b[n,'FF','x_b','ps']+m.vfoot_b[n,'FF','x_b','ng'])*m.friction_cone[n,'FF']
    else:
        return Constraint.Skip
m.board_friction = Constraint(m.N, m.Fs, rule = board_friction)

# slipping of foot on board
def board_slip(m,n,fs,cc): # the friction force must be applied in opposite direction to velocity of foot.
    if fs == 'BF':
        if cc == 'slip_x_ps':
            return m.contact_penalty[n,'BF','slip_x_ps'] == m.vfoot_b[n,'BF','x_b','ps']*m.Fb_b[n,'BF','x_b','ng']
        if cc == 'slip_x_ng':
            return m.contact_penalty[n,'BF','slip_x_ng'] == m.vfoot_b[n,'BF','x_b','ng']*m.Fb_b[n,'BF','x_b','ps']
        else:
            return Constraint.Skip
    if fs == 'FF':
        if cc == 'slip_x_ps':
            return m.contact_penalty[n,'FF','slip_x_ps'] == m.vfoot_b[n,'FF','x_b','ps']*m.Fb_b[n,'FF','x_b','ng']
        if cc == 'slip_x_ng':
            return m.contact_penalty[n,'FF','slip_x_ng'] == m.vfoot_b[n,'FF','x_b','ng']*m.Fb_b[n,'FF','x_b','ps']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.board_slip = Constraint(m.N, m.Fs, m.contact_constraints, rule = board_slip)

# foot velocity - only vf+ or vf- must be non-zero, not both.
def vfoot_b_penalty(m,n,fs):
    if fs == 'BF':
        return m.contact_penalty[n,'BF','foot_velocity'] == m.vfoot_b[n,'BF','x_b','ps']*m.vfoot_b[n,'BF','x_b','ng']
    if fs == 'FF':
        return m.contact_penalty[n,'FF','foot_velocity'] == m.vfoot_b[n,'FF','x_b','ps']*m.vfoot_b[n,'FF','x_b','ng']
    else:
        return Constraint.Skip
m.vfoot_b_penalty = Constraint(m.N, m.Fs, rule = vfoot_b_penalty)

for leg in legs:
    m.tau_a[N,leg].fix(0.0)
    m.tau_b[N].fix(0.0)
for grf in GRFs:
    m.GRF[N, grf].fix(0.0)
    m.GRF_s[N, grf].fix(0.0)
for fs in Fs:
    for dof in DOF_b:
        for sgn in signs:
            m.Fb_b[N, fs, dof, sgn].fix(0.0)
    for cc in contact_constraints:
        m.contact_penalty[N, fs, cc].fix(0.0)
for gnd in ground_constraints:
    m.ground_penalty[N, gnd].fix(0.0)

# %%
# Reaction force at knee

# sets
joints = ['knee']
m.J = Set(initialize = joints)

joint_constraints = ['up','lo'] # set of joint penalties
m.joint_constraints = Set(initialize = joint_constraints)

knee_bound = [0.0,hr_max]
m.knee_bound = Param(m.joint_constraints, initialize = {'up':knee_bound[1],'lo':knee_bound[0]})

# we can bound the joint coordinates directly
for n in range(1,N+1):
    m.q[n,'r_l'].setlb(knee_bound[0])
    m.q[n,'r_l'].setub(knee_bound[1])
    m.q[n,'r_r'].setlb(knee_bound[0])
    m.q[n,'r_r'].setub(knee_bound[1])
    
m.joint_penalty = Var(m.N, m.Legs, m.J, m.joint_constraints, bounds = (0.0,None))

def knee_limits(m,n,leg,jc):
    if n < N:
        if leg == 'BL':
            if jc == 'up':
                # NEXT distance
                return m.joint_penalty[n,'BL','knee',jc] == (m.knee_bound['up'] - m.q[n+1,'r_l'])*m.F_r[n,'BL','ng']
            else: # jc =='low'
                return m.joint_penalty[n,'BL','knee',jc] == (m.q[n+1,'r_l'] - m.knee_bound['lo'])*m.F_r[n,'BL','ps']
        if leg == 'FL':
            if jc == 'up':
                # NEXT distance
                return m.joint_penalty[n,'FL','knee',jc] == (m.knee_bound['up'] - m.q[n+1,'r_r'])*m.F_r[n,'FL','ng']
            else: # jc =='low'
                return m.joint_penalty[n,'FL','knee',jc] == (m.q[n+1,'r_r'] - m.knee_bound['lo'])*m.F_r[n,'FL','ps']
        else: 
            return Constraint.Skip
    else:
        return Constraint.Skip
m.knee_limits = Constraint(m.N, m.Legs, m.joint_constraints, rule = knee_limits)

# bound contact forces at last node
for sgn in signs:
    for leg in legs:
        m.F_r[N,leg,sgn].fix(0.0)
    
for jc in joint_constraints:
    for leg in legs:
        for j in joints:
            m.joint_penalty[N,leg,j,jc].fix(0.0)

# %%
# EOMs --------------------------------------------------------------------------------------------------------------------------

skaterlib_biped_with_body_new.define_EOMs(m,BW,lambEOMx_board,lambEOMy_board,lambEOMth_board,lambEOMxp_biped,lambEOMyp_biped,
                            lambEOMthp_biped,lambEOMthb_biped,lambEOMthll_biped,lambEOMthlr_biped,lambEOMrl_biped,lambEOMrr_biped)

# %%
# COST FUNCTION ---------------------------------------------------------------------------------------------------------------

# New cost function
# minimum force and penalties
def CostFun(m):
    penalty_sum = 0
    force_sum = 0
    torque_sum = 0
    for n in range(1,N+1):
        for gc in ground_constraints:
            penalty_sum += 10*m.ground_penalty[n,gc]
        for gfc in ground_func_constraints:
            penalty_sum += 10*m.ground_func_penalty[n,gfc]
        for cc in contact_constraints:
            for fs in Fs:
                penalty_sum += m.contact_penalty[n,fs,cc]
        for jc in joint_constraints:
            for leg in legs:
                for j in joints:
                    penalty_sum += m.joint_penalty[n,leg,j,jc]
        
        force_sum  += (m.F_a[n,'BL']**2 + m.F_a[n,'FL']**2)*hm*m.h[n]
        torque_sum += (m.tau_a[n,'BL']**2 + m.tau_a[n,'FL']**2 + m.tau_b[n]**2)*hm*m.h[n]
#     return penalty_sum
    return force_sum + torque_sum + 1000*penalty_sum

m.Cost = Objective(rule = CostFun)

# %%
# # LOW DROP 3
# m.pwheel[1,'BW','X'].fix(2.0)
# m.pwheel_g[1,'BW','y_g'].fix(0.1)
# m.q[1,'th'].fix(0.0)

# m.pfoot_b[1,'BF','x_b'].setub(-0.5*m.lbrd)
# m.pfoot_b[1,'BF','y_b'].fix(0.1)
# m.pfoot_b[1,'FF','y_b'].fix(0.1)

# m.q[1,'thp'].fix(0.0)
# m.q[1,'thb'].fix(np.pi/2)
# m.q[1,'thl_l'].fix(0.0)
# m.q[1,'thl_r'].fix(0.0)

# # both
# for dof in DOFs:
#     m.dq[1,dof].fix(0.0)
    
# for i in range(1,N+1):
#     m.F_a[i,'BL'].fix(0.0)
#     m.F_a[i,'FL'].fix(0.0)
#     m.tau_a[i,'BL'].fix(0.0)
#     m.tau_a[i,'FL'].fix(0.0)
#     m.tau_b[i].fix(0.0)

# %%
# # LOW DROP 4
# m.pwheel[1,'BW','X'].fix(0.0)
# m.pwheel_g[1,'BW','y_g'].fix(0.1)
# m.q[1,'th'].fix(0.0)

# m.pfoot_b[1,'BF','x_b'].setub(-0.5*m.lbrd)
# m.pfoot_b[1,'BF','y_b'].fix(0.1)
# m.pfoot_b[1,'FF','y_b'].fix(0.1)

# m.q[1,'thp'].fix(0.0)
# m.q[1,'thb'].fix(np.pi/2)
# m.q[1,'thl_l'].fix(0.0)
# m.q[1,'thl_r'].fix(0.0)

# # both
# for dof in DOFs:
#     m.dq[1,dof].fix(0.0)
    
# for i in range(1,N+1):
#     m.F_a[i,'BL'].fix(0.0)
#     m.F_a[i,'FL'].fix(0.0)
#     m.tau_a[i,'BL'].fix(0.0)
#     m.tau_a[i,'FL'].fix(0.0)
#     m.tau_b[i].fix(0.0)

# %%
# AIRBORNE ACROSS X_STEP
m.pwheel[1,'BW','X'].fix(0.0)
m.pwheel_g[1,'BW','y_g'].fix(1.5)
m.q[1,'th'].fix(0.0)

m.pfoot_b[1,'BF','x_b'].setub(-0.5*m.lbrd)
m.pfoot_b[1,'BF','y_b'].fix(0.3)
m.pfoot_b[1,'FF','y_b'].fix(0.3)

m.q[1,'thp'].fix(0.0)
m.q[1,'thb'].fix(np.pi/2)
m.q[1,'thl_l'].fix(0.0)
m.q[1,'thl_r'].fix(0.0)

# both
for dof in DOFs:
    m.dq[1,dof].fix(0.0)
m.dq[1,'x'].fix(7.0)
m.dq[1,'xp'].fix(7.0)
    
for i in range(1,N+1):
    m.F_a[i,'BL'].fix(0.0)
    m.F_a[i,'FL'].fix(0.0)
    m.tau_a[i,'BL'].fix(0.0)
    m.tau_a[i,'FL'].fix(0.0)
    m.tau_b[i].fix(0.0)
    
#     eps = 1e-6
#     for n in range(1,N+1):
#         for gc in ground_constraints:
#             m.ground_penalty[n,gc].setub(eps)
#         for gfc in ground_func_constraints:
#             m.ground_func_penalty[n,gfc].setub(eps)
#         for cc in contact_constraints:
#             for fs in Fs:
#                 m.contact_penalty[n,fs,cc].setub(eps)
#         for jc in joint_constraints:
#             for leg in legs:
#                 for j in joints:
#                     m.joint_penalty[n,leg,j,jc].setub(eps)

# %%
# # PATH CONSTRAINTS
# m.pwheel[1,'BW','X'].setub(0.0)
# m.pwheel_g[1,'BW','y_g'].fix(0.0)
# m.q[1,'th'].fix(0.0)

# m.pfoot_b[1,'BF','x_b'].setub(-0.5*m.lbrd)
# m.pfoot_b[1,'BF','y_b'].fix(0.0)
# m.pfoot_b[1,'FF','y_b'].fix(0.0)

# m.q[1,'thp'].fix(0.0)
# m.q[1,'thb'].fix(np.pi/2)
# m.q[1,'thl_l'].fix(0.0)
# m.q[1,'thl_r'].fix(0.0)

# # both
# for dof in DOFs:
#     m.dq[1,dof].fix(0.0)
# m.dq[1,'x'].fixed = False
# m.dq[1,'xp'].fixed = False
# m.dq[1,'x'].setub(5.0)
# m.dq[1,'xp'].setub(5.0)

# if N>=N1-1:
#     # the "POP"
# #     m.pwheel[N1-1,'BW','X'].setlb(0.2)
#     m.ptail[N1-1,'Y'].fix(0.0)
#     print("N>=N1-1, N =", N)

# if N>=Nhw:
#     # the apex
# #     m.pwheel[Nhw,'BW','Y'].setlb(0.7)
# #     m.pwheel[Nhw,'FW','Y'].setlb(0.7)
# #     m.q[Nhw,'th'].fix(0.0)
#     m.pwheel[Nhw,'FW','X'].fix(X_step)
#     print("N>=Nhw, N =", N)   

# if N>=N2:
#     # board landing
# #     m.pwheel[N2,'BW','X'].setlb(X_step)
#     m.pwheel_g[N2,'BW','y_g'].fix(0.0)
#     m.pwheel_g[N2,'FW','y_g'].fix(0.0)
#     print("N>=N2, N =", N)    

# if N>=N3:
#     # board and biped landing
#     m.pwheel_g[N3,'BW','y_g'].fix(0.0)
#     m.pwheel_g[N3,'FW','y_g'].fix(0.0)
# #     m.q[N3,'thp'].fix(0.0)
# #     m.q[N3,'thb'].fix(np.pi/2)
# #     m.q[N3,'thl_l'].fix(0.0)
# #     m.q[N3,'thl_r'].fix(0.0)
#     m.pfoot_b[N3,'BF','x_b'].fix(-0.5*m.lbrd)
#     m.pfoot_b[N3,'FF','x_b'].fix(0.5*m.lbrd)
#     m.pfoot_b[N3,'BF','y_b'].fix(0.0)
#     m.pfoot_b[N3,'FF','y_b'].fix(0.0)
#     print("N>=N3, N =",N)
    
# if N==N4:
#     # Final Conditions - standing
#     m.pwheel_g[N,'BW','y_g'].fix(0.0)
#     m.pwheel_g[N,'FW','y_g'].fix(0.0)
#     m.q[N,'thp'].fix(0.0)
#     m.q[N,'thb'].fix(np.pi/2)
#     m.q[N,'thl_l'].fix(0.0)
# #     m.q[N,'thl_r'].fix(0.0)
#     m.pfoot_b[N3,'BF','x_b'].fix(-0.5*m.lbrd)
#     m.pfoot_b[N3,'FF','x_b'].fix(0.5*m.lbrd)
#     m.pfoot_b[N,'BF','y_b'].fix(0.0)
#     m.pfoot_b[N,'FF','y_b'].fix(0.0)

#     m.dq[N,'thl_l'].fix(0.0)
#     m.dq[N,'thl_r'].fix(0.0)
#     m.dq[N,'thp'].fix(0.0)
#     m.dq[N,'thb'].fix(0.0)
#     m.dq[N,'r_l'].fix(0.0)
#     m.dq[N,'r_r'].fix(0.0)    

#     m.pwheel[N,'BW','X'].setlb(2.0)  

# #INITIALIZE
# if 'm_saved' in globals():
#     print("Loading previous model:", model, "results as initialization.")
#     N_saved = m_saved.N.bounds()[1]
#     if N_saved > N: N_count = N
#     else: N_count = N_saved
#     for n in range(1,N_count+1):
        
#         for dof in DOFs:
#             if not m.q[n,dof].fixed:
#                 m.q[n,dof] = m_saved.q[n,dof].value
#             if not m.dq[n,dof].fixed:
#                 m.dq[n,dof] = m_saved.dq[n,dof].value
        
#         for leg in legs:
#             if not m.F_a[n,leg].fixed:
#                 m.F_a[n,leg] = m_saved.F_a[n,leg].value
#             if not m.tau_a[n,leg].fixed:
#                 m.tau_a[n,leg] = m_saved.tau_a[n,leg].value
        
#         m.tau_b[n] = m_saved.tau_b[n].value
        
#         for fs in Fs:
#             for dof in DOF_b:
#                 for sgn in signs:
#                     if (not m.Fb_b[n,fs,dof,sgn].fixed) and (m_saved.Fb_b[n,fs,dof,sgn].value is not None):
#                         m.Fb_b[n,fs,dof,sgn] = m_saved.Fb_b[n,fs,dof,sgn].value
                
#         for grf in GRFs:
#             if (not m.GRF[n, grf].fixed) and (m_saved.GRF[n, grf].value is not None):
#                 m.GRF[n, grf] = m_saved.GRF[n, grf].value
#             if (not m.GRF_s[n, grf].fixed) and (m_saved.GRF_s[n, grf].value is not None):
#                 m.GRF_s[n, grf] = m_saved.GRF_s[n, grf].value
        
#         m.h[n] = m_saved.h[n].value
        
# #     eps = 1e-6
# #     for n in range(1,N+1):
# #         for gc in ground_constraints:
# #             m.ground_penalty[n,gc].setub(eps)
# #         for gfc in ground_func_constraints:
# #             m.ground_func_penalty[n,gfc].setub(eps)

# %%
# m.dq.pprint()

# %%
# SOLVE --------------------------------------------------------------------------------------------------------------------  
t = time.time()
results = skaterlib_biped_with_body_new.solve(m, display_results = True, expect_infeasible = 'yes')
skaterlib_biped_with_body_new.print_results(m, N, hm, ground_constraints, contact_constraints, joint_constraints, ground_func_constraints, joints, Fs, legs)
print("Elapsed Time:", (time.time() - t)/60.0, "mins")
# Out:
# Ipopt 3.12.9: linear_solver=ma86
# expect_infeasible_problem=yes
# halt_on_ampl_error=yes
# print_level=5
# max_iter=100000
# max_cpu_time=1800
# Tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.9, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    15308
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     5153
#
# Total number of variables............................:     3933
#                      variables with only lower bounds:     1881
#                 variables with lower and upper bounds:      384
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     3234
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.5259955e+04 7.16e+02 9.90e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.7598750e+04 7.08e+02 9.79e+01  -1.0 7.05e+02    -  1.47e-02 1.10e-02f  1
#    2  3.3657867e+04 6.80e+02 9.56e+01  -1.0 4.12e+02    -  1.96e-02 4.01e-02f  1
#    3  3.2122886e+04 6.59e+02 9.09e+01  -1.0 6.93e+02    -  6.35e-02 3.25e-02f  1
#    4  3.1983294e+04 6.16e+02 8.49e+01  -1.0 2.74e+02    -  1.01e-01 6.52e-02f  1
#    5  3.0669102e+04 4.54e+02 6.86e+01  -1.0 2.10e+02    -  1.48e-01 2.74e-01f  1
#    6  2.9328012e+04 4.24e+02 6.24e+01  -1.0 3.12e+02  -4.0 9.09e-02 6.86e-02f  1
#    7  2.7670539e+04 3.83e+02 5.72e+01  -1.0 2.69e+02  -4.5 1.69e-01 9.64e-02f  1
#    8  2.5849943e+04 3.35e+02 5.04e+01  -1.0 4.74e+02  -5.0 1.02e-01 1.25e-01f  1
#    9  2.5680040e+04 3.31e+02 4.99e+01  -1.0 6.46e+00  -0.0 4.52e-03 1.37e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.3664584e+04 2.76e+02 4.21e+01  -1.0 8.64e+00  -0.5 1.46e-01 1.63e-01f  1
#   11  2.3142287e+04 2.60e+02 4.00e+01  -1.0 9.65e+00  -0.1 4.05e-02 5.93e-02h  1
#   12  2.0805627e+04 1.97e+02 3.19e+01  -1.0 4.19e+00  -0.5 6.27e-01 2.37e-01f  1
#   13  1.6836791e+04 9.37e+01 2.79e+01  -1.0 8.21e+00  -1.0 1.00e+00 5.22e-01f  1
#   14  1.5472635e+04 6.13e+01 1.94e+01  -1.0 9.53e+00  -1.5 3.71e-01 3.49e-01h  1
#   15  1.3724627e+04 1.65e+01 1.19e+01  -1.0 4.38e+00  -2.0 7.62e-01 7.41e-01h  1
#   16  1.3721539e+04 1.64e+01 1.19e+01  -1.0 6.11e+01  -0.6 3.06e-03 2.69e-03h  1
#   17  1.3303628e+04 9.42e+00 6.73e+02  -1.0 9.47e-01  -1.1 1.00e+00 4.27e-01h  1
#   18  1.3221904e+04 4.56e+00 3.37e+02  -1.0 5.25e-01   0.2 5.25e-01 5.16e-01h  1
#   19  1.3163233e+04 8.88e-01 1.26e+02  -1.0 4.17e-01  -0.3 8.29e-01 8.06e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.3128845e+04 5.88e-02 3.53e+02  -1.0 3.05e-01  -0.7 1.00e+00 9.36e-01h  1
#   21  1.3123344e+04 5.24e-02 3.50e+02  -1.0 4.63e+00  -1.2 1.22e-01 1.11e-01h  1
#   22  1.3114107e+04 4.93e-02 3.46e+03  -1.0 1.61e+00  -1.7 1.00e+00 6.25e-02h  5
#   23  1.2813458e+04 1.08e-01 7.55e+01  -1.0 4.04e+00  -2.2 1.00e+00 1.00e+00H  1
#   24  1.2770823e+04 1.01e-01 2.11e+03  -1.0 6.74e+00  -2.7 1.00e+00 2.50e-01h  3
#   25  1.2772795e+04 7.95e-03 7.78e+00  -1.0 5.16e-01  -1.3 1.00e+00 1.00e+00h  1
#   26  1.2762545e+04 7.32e-03 3.22e+02  -1.0 1.41e+00  -1.8 3.09e-01 1.83e-01h  2
#   27  1.2752920e+04 1.74e-03 8.28e+00  -1.0 6.80e-02  -0.5 1.00e+00 1.00e+00h  1
#   28  1.2745468e+04 4.74e-05 2.16e+01  -1.0 2.02e-01  -1.0 1.00e+00 1.00e+00H  1
#   29  1.2745206e+04 4.74e-05 1.88e+03  -1.0 5.78e-01  -1.4 1.00e+00 1.56e-02h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.2738230e+04 8.02e-05 2.87e+01  -1.0 2.22e-01  -1.0 1.00e+00 1.00e+00H  1
#   31  1.2713629e+04 2.98e-05 1.04e+02  -1.0 6.32e-01  -1.5 1.00e+00 1.00e+00H  1
#   32  1.2712762e+04 3.03e-05 1.37e+03  -1.0 1.64e+00  -2.0 1.00e+00 3.12e-02f  6
#   33  1.2712029e+04 3.07e-05 1.63e+03  -1.0 4.01e+00  -2.4 1.00e+00 1.56e-02f  7
#   34  1.2711859e+04 3.07e-05 3.86e+03  -1.0 7.97e+00  -2.9 7.06e-01 2.97e-03f  9
#   35  1.2711900e+04 2.35e-05 5.41e-01  -1.0 9.78e-02  -0.7 1.00e+00 1.00e+00H  1
#   36  7.4889084e+03 1.09e-01 1.17e+01  -2.5 1.63e+00  -1.2 4.74e-01 4.73e-01f  1
#   37  6.3469299e+03 1.05e-01 2.19e+02  -2.5 2.01e+00  -1.6 4.43e-01 1.95e-01f  1
#   38  4.8898005e+03 7.75e-02 1.47e+02  -2.5 4.96e-01  -0.3 8.03e-01 3.51e-01f  1
#   39  3.8922771e+03 9.58e-02 1.15e+02  -2.5 1.14e+00  -0.8 4.05e-01 3.49e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.7661071e+03 4.63e-02 3.31e+02  -2.5 5.27e-01  -0.4 1.15e-01 6.59e-01f  1
#   41  2.4165134e+03 5.36e-02 1.91e+02  -2.5 1.05e+00  -0.8 5.31e-01 4.27e-01f  1
#   42  2.2500171e+03 6.10e-02 1.57e+02  -2.5 2.24e+00  -1.3 1.99e-01 1.76e-01f  1
#   43  2.1449359e+03 4.64e-02 1.20e+02  -2.5 6.55e-01  -0.9 6.40e-01 2.36e-01f  1
#   44  1.9651333e+03 3.19e-02 8.93e+01  -2.5 2.87e+00  -1.4 1.71e-01 2.57e-01f  1
#   45  1.7194673e+03 1.40e-01 8.37e+01  -2.5 1.93e+01  -1.8 6.44e-02 6.12e-02f  1
#   46  1.6080709e+03 1.26e-01 1.99e+02  -2.5 2.29e+00  -1.4 1.00e+00 1.73e-01f  1
#   47  1.4105730e+03 1.74e-01 1.74e+02  -2.5 9.98e+00  -1.9 1.33e-01 1.51e-01f  1
#   48  1.3275253e+03 1.41e-01 1.70e+02  -2.5 2.33e+00  -1.5 1.00e+00 2.12e-01f  1
#   49  1.1907057e+03 1.41e-01 1.34e+02  -2.5 7.64e+00  -1.9 2.15e-01 2.26e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.1408546e+03 1.57e-01 1.42e+02  -2.5 1.82e+01  -2.4 4.17e-02 6.16e-02f  1
#   51  1.0818820e+03 5.91e-02 9.15e+01  -2.5 1.06e-01   0.7 2.63e-01 6.24e-01h  1
#   52  1.0490871e+03 2.02e-03 6.82e+01  -2.5 4.63e-02   0.2 3.41e-01 1.00e+00f  1
#   53  1.0435056e+03 1.61e-03 5.72e+01  -2.5 1.62e-01  -0.2 2.58e-01 4.44e-01f  1
#   54  1.0280561e+03 3.96e-03 9.65e-01  -2.5 2.15e-01  -0.7 1.00e+00 1.00e+00f  1
#   55  1.0080294e+03 2.44e-02 6.65e+00  -2.5 5.29e-01  -1.2 9.32e-01 1.00e+00h  1
#   56  1.0088676e+03 2.78e-05 2.48e-01  -2.5 2.51e-02   0.1 1.00e+00 1.00e+00h  1
#   57  8.6185509e+02 4.53e-04 7.41e+01  -3.8 9.57e-02  -0.3 9.13e-01 5.48e-01f  1
#   58  7.8731051e+02 2.54e-03 1.03e+02  -3.8 2.62e-01  -0.8 7.04e-01 5.77e-01f  1
#   59  7.5241179e+02 1.07e-03 1.63e+02  -3.8 1.04e-01  -0.4 8.50e-01 6.80e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  7.3863408e+02 1.31e-03 3.41e+02  -3.8 3.31e-01  -0.9 1.00e+00 4.77e-01f  1
#   61  7.2992413e+02 2.27e-03 3.35e+02  -3.8 9.20e-01  -1.3 1.00e+00 2.56e-01f  1
#   62  7.2219021e+02 2.69e-03 1.40e+02  -3.8 1.65e+00  -1.8 6.40e-01 1.31e-01f  1
#   63  7.1069902e+02 1.16e-02 1.26e+02  -3.8 4.69e+00  -2.3 9.85e-02 1.01e-01f  1
#   64  6.9273687e+02 3.33e-02 1.01e+02  -3.8 1.58e+00  -1.9 6.41e-01 4.09e-01f  1
#   65  6.8516932e+02 3.53e-02 9.03e+01  -3.8 5.15e+00  -2.3 6.34e-02 7.66e-02f  1
#   66  6.7734078e+02 5.27e-02 8.85e+01  -3.8 4.29e+01  -2.8 2.60e-02 2.40e-02f  1
#   67  6.6321164e+02 1.04e-01 4.64e+02  -3.8 6.35e+00  -2.4 4.03e-01 1.44e-01f  1
#   68  6.6095173e+02 5.79e-07 1.14e+00  -3.8 3.27e-03   2.5 1.00e+00 1.00e+00h  1
#   69  6.6012799e+02 3.69e-07 1.51e-01  -3.8 1.30e-03   2.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  6.5989117e+02 2.05e-07 2.92e-02  -3.8 7.60e-04   1.6 1.00e+00 1.00e+00h  1
#   71  6.5979407e+02 1.03e-06 2.32e-02  -3.8 1.79e-03   1.1 1.00e+00 1.00e+00h  1
#   72  6.5964165e+02 3.99e-06 2.32e-02  -3.8 5.39e-03   0.6 1.00e+00 1.00e+00h  1
#   73  6.5929148e+02 3.90e-06 2.31e-02  -3.8 1.61e-02   0.2 1.00e+00 1.00e+00h  1
#   74  6.5836006e+02 7.95e-05 2.37e-02  -3.8 4.83e-02  -0.3 1.00e+00 1.00e+00f  1
#   75  6.5579552e+02 1.14e-03 1.08e-01  -3.8 1.44e-01  -0.8 1.00e+00 1.00e+00f  1
#   76  6.4968952e+02 1.21e-02 5.72e+01  -3.8 4.29e-01  -1.3 1.00e+00 8.82e-01f  1
#   77  6.4413527e+02 2.09e-02 1.75e+02  -3.8 1.27e+00  -1.8 1.00e+00 2.90e-01f  1
#   78  6.3058994e+02 1.81e-01 1.23e+02  -3.8 3.81e+00  -2.2 3.20e-01 3.15e-01f  1
#   79  6.3055112e+02 1.80e-01 1.18e+02  -3.8 4.10e-01  -0.9 2.94e-02 4.38e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  6.3021343e+02 1.65e-01 2.58e+02  -3.8 4.93e-01  -1.4 5.62e-02 8.46e-02f  1
#   81  6.2563248e+02 1.15e-01 2.32e+02  -3.8 1.50e+00  -1.9 4.54e-02 3.11e-01f  1
#   82  6.1690274e+02 1.02e-01 5.52e+02  -3.8 4.73e+00  -2.3 5.30e-03 1.93e-01f  1
#   83  6.1675445e+02 6.20e-02 4.84e+02  -3.8 7.77e-02  -0.1 2.18e-01 3.94e-01f  1
#   84  6.1560151e+02 8.90e-05 2.51e+01  -3.8 7.69e-02  -0.6 9.64e-01 1.00e+00f  1
#   85  6.1339565e+02 3.34e-04 1.74e+02  -3.8 2.33e-01  -1.1 3.42e-01 8.98e-01f  1
#   86  6.1339913e+02 2.49e-07 3.06e-02  -3.8 1.36e-03   1.2 1.00e+00 1.00e+00f  1
#   87  6.1334859e+02 2.64e-07 2.06e-02  -3.8 4.11e-03   0.7 1.00e+00 1.00e+00h  1
#   88  6.1322243e+02 9.61e-07 2.06e-02  -3.8 1.23e-02   0.2 1.00e+00 1.00e+00h  1
#   89  6.1284499e+02 9.75e-06 2.06e-02  -3.8 3.68e-02  -0.3 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  6.1172079e+02 7.76e-05 2.05e-02  -3.8 1.10e-01  -0.7 1.00e+00 1.00e+00h  1
#   91  6.0838237e+02 6.77e-04 2.23e-02  -3.8 3.31e-01  -1.2 1.00e+00 1.00e+00f  1
#   92  5.9846867e+02 5.78e-03 9.06e-02  -3.8 9.95e-01  -1.7 1.00e+00 1.00e+00f  1
#   93  5.7779732e+02 2.52e-02 1.18e+02  -3.8 3.05e+00  -2.2 1.00e+00 6.89e-01f  1
#   94  5.5436048e+02 3.91e-02 8.34e+01  -3.8 9.76e+00  -2.6 2.89e-01 2.44e-01f  1
#   95  5.5321826e+02 3.78e-02 8.42e+01  -3.8 3.36e+00  -2.2 1.31e-01 3.31e-02h  1
#   96  5.3746271e+02 3.17e-02 1.22e+02  -3.8 1.09e+01  -2.7 2.93e-01 1.46e-01f  1
#   97  5.2561355e+02 2.15e-02 8.56e+01  -3.8 3.86e+00  -2.3 3.35e-01 3.12e-01f  1
#   98  5.2182831e+02 1.59e-02 6.43e+01  -3.8 1.43e+00  -1.8 1.70e-01 2.60e-01f  1
#   99  5.2180660e+02 1.56e-02 6.37e+01  -3.8 2.09e-01  -0.5 9.42e-03 1.86e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  5.2180329e+02 1.56e-02 6.37e+01  -3.8 9.89e-01  -1.0 3.24e-04 1.06e-03f  2
#  101  5.2165604e+02 1.20e-02 4.76e+01  -3.8 4.01e-02   0.3 2.51e-01 2.29e-01h  1
#  102  5.2094952e+02 1.37e-06 2.16e-02  -3.8 2.77e-02  -0.1 1.00e+00 1.00e+00f  1
#  103  5.2017227e+02 6.22e-06 2.02e-02  -3.8 8.26e-02  -0.6 1.00e+00 1.00e+00f  1
#  104  5.1776468e+02 3.68e-05 2.04e-02  -3.8 2.49e-01  -1.1 1.00e+00 1.00e+00f  1
#  105  5.1057627e+02 2.78e-04 6.58e-02  -3.8 7.57e-01  -1.6 1.00e+00 1.00e+00f  1
#  106  4.9086682e+02 1.96e-03 7.31e+00  -3.8 2.36e+00  -2.0 1.00e+00 9.37e-01f  1
#  107  4.6947675e+02 4.69e-03 6.00e+01  -3.8 7.44e+00  -2.5 4.69e-01 3.24e-01f  1
#  108  4.6653330e+02 4.70e-03 2.49e+02  -3.8 2.06e+01  -3.0 1.45e-01 1.40e-02f  1
#  109  4.4902290e+02 9.05e-03 1.28e+02  -3.8 4.20e+00  -2.6 6.15e-01 5.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  4.3286424e+02 1.49e-02 7.65e+01  -3.8 1.58e+01  -3.0 1.20e-01 1.42e-01f  1
#  111  4.1867593e+02 1.44e-02 1.49e+01  -3.8 4.72e+00  -2.6 2.12e-01 3.54e-01f  1
#  112  4.0945691e+02 1.45e-02 5.65e+01  -3.8 1.72e+01  -3.1 4.55e-02 6.80e-02f  1
#  113  4.0657512e+02 1.36e-02 1.14e+02  -3.8 4.23e+00  -2.7 3.19e-01 6.51e-02f  1
#  114  3.9502955e+02 1.17e-02 3.13e+01  -3.8 1.04e+01  -3.1 7.68e-02 1.36e-01f  1
#  115  3.8754552e+02 8.92e-03 3.13e+02  -3.8 4.15e+00  -2.7 6.96e-01 2.41e-01f  1
#  116  3.7489626e+02 1.02e-02 2.94e+02  -3.8 1.21e+01  -3.2 1.79e-01 1.66e-01f  1
#  117  3.7090792e+02 8.78e-03 4.90e+02  -3.8 4.40e+00  -2.8 5.37e-01 1.44e-01f  1
#  118  3.5419629e+02 9.77e-03 2.02e+02  -3.8 1.49e+01  -3.3 1.83e-01 2.33e-01f  1
#  119  3.4511504e+02 6.57e-03 2.62e+02  -3.8 4.78e+00  -2.8 4.53e-01 3.41e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  3.3816343e+02 2.46e-01 8.65e+02  -3.8 8.35e+01  -3.3 2.06e-02 4.67e-02f  1
#  121  3.3546560e+02 1.42e-01 8.15e+02  -3.8 8.29e-01  -2.0 1.13e-01 4.23e-01h  1
#  122  3.3362489e+02 4.42e-02 6.18e+02  -3.8 3.11e-01  -1.5 2.05e-01 6.89e-01h  1
#  123  3.2999044e+02 1.49e-02 6.49e+01  -3.8 9.51e-01  -2.0 1.00e+00 6.94e-01h  1
#  124  3.1594223e+02 5.28e-02 2.53e+03  -3.8 2.96e+00  -2.5 2.79e-01 1.00e+00f  1
#  125  3.1010942e+02 8.36e-03 1.52e+03  -3.8 1.12e+00  -2.1 1.00e+00 1.00e+00h  1
#  126  2.9475171e+02 7.53e-02 1.74e+02  -3.8 3.55e+00  -2.6 1.00e+00 8.81e-01h  1
#  127  2.8238721e+02 1.36e-01 1.33e+02  -3.8 1.45e+01  -3.0 9.06e-02 1.87e-01h  1
#  128  2.8152323e+02 1.09e-01 9.13e+01  -3.8 5.89e-01  -1.7 2.20e-01 1.98e-01h  1
#  129  2.7919479e+02 1.81e-02 3.93e+02  -3.8 2.14e-01  -1.3 5.00e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  2.7842617e+02 5.42e-03 3.69e+02  -3.8 8.54e-02  -0.8 4.84e-01 1.00e+00h  1
#  131  2.7585581e+02 8.50e-02 1.73e+02  -3.8 3.48e-01  -1.3 5.77e-01 6.13e-01h  1
#  132  2.7239521e+02 5.53e-02 1.28e-01  -3.8 1.29e-01  -0.9 1.00e+00 1.00e+00f  1
#  133  2.6932171e+02 1.07e-01 3.89e+00  -3.8 2.48e+00  -1.4 3.98e-02 4.28e-02h  1
#  134  2.6510624e+02 1.04e-01 8.98e+01  -3.8 2.03e-01  -1.0 8.33e-01 5.30e-01f  1
#  135  2.5994340e+02 1.94e-01 8.49e+01  -3.8 7.87e+00  -1.4 7.31e-03 2.15e-02f  1
#  136  2.5523994e+02 1.72e-01 1.54e+02  -3.8 3.25e-01  -1.0 7.73e-01 2.84e-01h  1
#  137  2.5203066e+02 1.74e-01 1.66e+02  -3.8 2.12e+00  -1.5 1.02e-01 5.38e-02h  1
#  138  2.4770270e+02 1.39e-01 1.69e+02  -3.8 2.07e+00  -2.0 8.22e-01 2.03e-01h  1
#  139  2.3296269e+02 1.20e-01 1.19e+02  -3.8 6.55e+00  -2.4 2.38e-01 2.99e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  2.3065385e+02 1.17e-01 1.10e+02  -3.8 1.54e+01  -2.9 6.07e-02 2.68e-02h  1
#  141  2.3029439e+02 8.21e-02 1.79e+02  -3.8 4.52e-03   1.1 1.00e+00 2.99e-01f  1
#  142  2.2947154e+02 2.24e-05 6.44e-02  -3.8 4.55e-03   0.6 1.00e+00 1.00e+00f  1
#  143  2.2948005e+02 4.30e-06 2.93e-01  -3.8 1.62e-02   0.2 1.00e+00 1.00e+00h  1
#  144  2.2927477e+02 1.71e-05 2.39e-02  -3.8 4.82e-02  -0.3 1.00e+00 1.00e+00h  1
#  145  2.2860099e+02 1.39e-04 3.17e-02  -3.8 1.40e-01  -0.8 1.00e+00 1.00e+00h  1
#  146  2.2656302e+02 1.00e-03 8.21e-02  -3.8 3.97e-01  -1.3 1.00e+00 1.00e+00h  1
#  147  2.2066997e+02 6.56e-03 2.17e-01  -3.8 1.12e+00  -1.7 1.00e+00 1.00e+00h  1
#  148  2.1169544e+02 1.64e-02 1.27e+02  -3.8 3.20e+00  -2.2 1.00e+00 5.57e-01h  1
#  149  1.8856182e+02 9.98e-02 6.03e+01  -3.8 9.35e+00  -2.7 5.26e-01 5.25e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  1.8532162e+02 7.89e-02 1.38e+02  -3.8 3.52e+00  -2.3 8.30e-01 2.09e-01h  1
#  151  1.6764169e+02 7.60e-02 5.50e+01  -3.8 1.03e+01  -2.7 3.23e-01 3.98e-01f  1
#  152  1.5096839e+02 6.47e-02 1.01e+02  -3.8 3.01e+01  -3.2 2.66e-01 1.36e-01f  1
#  153  1.2577941e+02 5.98e-02 5.00e+02  -3.8 8.77e+01  -3.7 3.38e-01 7.22e-02f  1
#  154  1.2469963e+02 4.96e-02 4.01e+02  -3.8 6.50e+00  -3.3 1.98e-01 1.98e-01h  1
#  155  1.2327399e+02 4.00e-02 1.75e+02  -3.8 2.71e+00  -2.8 9.52e-01 2.33e-01h  1
#  156  1.1711479e+02 2.12e-01 1.39e+02  -3.8 7.00e+00  -3.3 3.09e-01 7.25e-01h  1
#  157  1.1491312e+02 4.63e-02 2.56e+01  -3.8 2.75e+00  -2.9 7.88e-01 8.79e-01h  1
#  158  1.1424632e+02 4.37e-03 9.64e+00  -3.8 1.04e+00  -2.5 1.00e+00 9.74e-01f  1
#  159  1.1396853e+02 3.82e-04 7.09e+01  -3.8 3.89e-01  -2.0 5.75e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  1.1296376e+02 3.03e-03 1.28e+00  -3.8 1.16e+00  -2.5 1.00e+00 1.00e+00h  1
#  161  1.1012492e+02 1.87e-02 3.94e+00  -3.8 3.46e+00  -3.0 1.00e+00 1.00e+00h  1
#  162  1.0914983e+02 1.77e-02 1.06e+03  -3.8 9.56e+00  -3.5 1.00e+00 1.34e-01h  1
#  163  1.0895251e+02 7.49e-03 6.38e+01  -3.8 3.61e-01  -2.1 1.00e+00 5.90e-01h  1
#  164  1.0870609e+02 3.42e-03 6.14e+01  -3.8 5.83e-01  -2.6 1.00e+00 5.39e-01f  1
#  165  1.0785199e+02 1.50e-03 4.80e+00  -3.8 1.90e+00  -3.1 1.00e+00 1.00e+00f  1
#  166  1.0772460e+02 1.46e-03 2.31e+02  -3.8 9.81e+00  -3.6 5.47e-02 5.08e-02h  1
#  167  1.0679296e+02 2.75e-03 7.36e+01  -3.8 2.18e+00  -3.2 9.96e-01 1.00e+00f  1
#  168  1.0674564e+02 6.75e-06 3.81e+01  -3.8 1.03e-01  -1.8 1.00e+00 1.00e+00h  1
#  169  1.0661788e+02 5.53e-05 3.40e+00  -3.8 3.06e-01  -2.3 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  1.0624275e+02 4.90e-04 3.33e+01  -3.8 9.20e-01  -2.8 1.00e+00 1.00e+00h  1
#  171  1.0610395e+02 6.88e-05 8.02e+00  -3.8 3.45e-01  -2.3 1.00e+00 1.00e+00h  1
#  172  1.0568973e+02 6.01e-04 2.97e+01  -3.8 1.04e+00  -2.8 1.00e+00 1.00e+00h  1
#  173  1.0445670e+02 4.87e-03 6.58e+02  -3.8 3.13e+00  -3.3 3.98e-01 1.00e+00h  1
#  174  1.0079784e+02 3.34e-02 5.07e+02  -3.8 9.35e+00  -3.8 8.50e-01 1.00e+00h  1
#  175  9.9220113e+01 5.36e-03 1.37e+01  -3.8 3.38e+00  -3.4 1.00e+00 1.00e+00h  1
#  176  9.6823843e+01 1.66e-02 9.53e+01  -3.8 1.25e+01  -3.8 5.94e-01 5.16e-01h  1
#  177  9.6222012e+01 7.98e-03 3.38e+02  -3.8 4.03e+00  -3.4 1.00e+00 5.39e-01f  1
#  178  9.5672853e+01 1.05e-03 7.63e+00  -3.8 9.22e-01  -3.0 1.00e+00 1.00e+00f  1
#  179  9.4345649e+01 7.75e-03 1.46e+01  -3.8 2.46e+00  -3.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  9.4025761e+01 6.94e-04 3.55e+00  -3.8 1.13e+00  -3.0 1.00e+00 1.00e+00h  1
#  181  9.2831315e+01 7.75e-03 1.03e+01  -3.8 2.74e+00  -3.5 1.00e+00 1.00e+00h  1
#  182  9.2515735e+01 1.06e-03 3.13e+00  -3.8 9.98e-01  -3.1 1.00e+00 1.00e+00h  1
#  183  9.1479870e+01 8.58e-03 1.51e+01  -3.8 3.08e+00  -3.6 1.00e+00 1.00e+00h  1
#  184  9.1379937e+01 1.10e-03 8.20e+00  -3.8 1.16e+00  -3.1 1.00e+00 1.00e+00h  1
#  185  9.0795016e+01 8.39e-03 1.82e+02  -3.8 3.47e+00  -3.6 1.00e+00 1.00e+00h  1
#  186  9.0539925e+01 4.56e-05 1.13e+01  -3.8 1.63e-01  -2.3 1.00e+00 1.00e+00h  1
#  187  9.0173080e+01 1.95e-04 8.86e+00  -3.8 4.92e-01  -2.8 1.00e+00 1.00e+00h  1
#  188  8.9876153e+01 1.75e-03 3.25e+01  -3.8 1.47e+00  -3.2 1.00e+00 1.00e+00h  1
#  189  8.8879635e+01 1.36e-02 2.38e+02  -3.8 4.38e+00  -3.7 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  8.8531488e+01 1.88e-03 2.12e+01  -3.8 1.65e+00  -3.3 1.00e+00 1.00e+00h  1
#  191  8.7415767e+01 1.54e-02 1.12e+02  -3.8 4.94e+00  -3.8 1.00e+00 1.00e+00h  1
#  192  8.4086784e+01 1.15e-01 7.17e+02  -3.8 1.51e+01  -4.2 8.89e-01 1.00e+00h  1
#  193  8.2974937e+01 1.10e-02 1.71e+01  -3.8 6.51e+00  -3.8 1.00e+00 1.00e+00h  1
#  194  8.2570307e+01 1.14e-03 1.52e+01  -3.8 2.38e+00  -3.4 1.00e+00 1.00e+00h  1
#  195  8.1783134e+01 9.54e-04 1.60e+00  -3.8 8.86e-01  -3.0 1.00e+00 1.00e+00h  1
#  196  8.1742230e+01 1.15e-03 3.65e+00  -3.8 2.66e+00  -3.4 1.00e+00 1.00e+00h  1
#  197  8.0166418e+01 4.47e-04 8.71e+01  -3.8 1.00e+00  -3.0 1.00e+00 8.16e-01H  1
#  198  8.0568510e+01 1.46e-03 8.29e+01  -3.8 2.99e+00  -3.5 3.32e-01 1.00e+00f  1
#  199  8.0566465e+01 1.44e-03 1.23e+02  -3.8 1.99e+00  -3.1 2.26e-01 3.86e-02h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  8.1995289e+01 4.57e-04 4.53e+02  -3.8 1.84e-01  -1.7 3.32e-01 1.00e+00h  1
#  201  8.1893141e+01 5.25e-04 4.33e+02  -3.8 2.84e+00  -2.2 1.16e-01 3.12e-02h  3
#  202  8.1249202e+01 4.21e-05 1.28e+00  -3.8 5.88e-02  -1.8 1.00e+00 1.00e+00h  1
#  203  8.0942540e+01 2.27e-04 8.32e-02  -3.8 1.80e-01  -2.3 1.00e+00 1.00e+00H  1
#  204  8.1022936e+01 1.33e-04 9.16e-02  -3.8 5.43e-01  -2.7 1.00e+00 1.00e+00h  1
#  205  8.0940692e+01 9.74e-04 2.61e-01  -3.8 1.66e+00  -3.2 1.00e+00 1.00e+00h  1
#  206  8.0333473e+01 5.68e-04 2.00e-01  -3.8 6.21e-01  -2.8 1.00e+00 1.00e+00h  1
#  207  8.0385910e+01 5.26e-04 2.56e-01  -3.8 1.90e+00  -3.3 1.00e+00 1.00e+00h  1
#  208  8.0401808e+01 2.68e-04 8.48e-02  -3.8 7.19e-01  -2.8 1.00e+00 1.00e+00h  1
#  209  8.0051201e+01 7.78e-05 2.44e-02  -3.8 2.70e-01  -2.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  7.9942736e+01 6.79e-05 6.99e-02  -3.8 8.15e-01  -2.9 1.00e+00 1.00e+00h  1
#  211  7.9511731e+01 4.84e-04 2.53e-01  -3.8 2.53e+00  -3.4 1.00e+00 1.00e+00h  1
#  212  7.8787020e+01 6.23e-04 2.90e+01  -3.8 8.81e+00  -3.9 4.87e-01 4.08e-01h  1
#  213  7.8206779e+01 8.08e-04 5.14e+01  -3.8 4.43e+01  -4.3 1.45e-01 5.92e-02f  1
#  214  7.6690430e+01 4.58e-03 3.59e+01  -3.8 1.14e+01  -3.9 5.64e-01 7.87e-01f  1
#  215  7.6256369e+01 1.65e-02 2.71e+02  -3.8 9.22e+00  -4.4 3.02e-01 1.00e+00f  1
#  216  7.5736298e+01 1.56e-02 2.43e+02  -3.8 7.57e+01  -4.9 5.86e-02 4.82e-02h  1
#  217  7.4653634e+01 2.08e-02 4.07e+02  -3.8 2.51e+02  -5.3 7.31e-02 6.78e-02f  1
#  218  7.3728782e+01 2.58e-02 3.06e+02  -3.8 3.21e+01  -4.9 5.54e-01 2.06e-01f  1
#  219  7.3211128e+01 2.55e-02 3.85e+02  -3.8 1.09e+03  -5.4 3.55e-02 1.60e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  7.3102750e+01 1.73e-02 3.57e+02  -3.8 1.51e+00  -3.2 1.96e-01 3.26e-01h  1
#  221  7.3082403e+01 1.69e-02 3.30e+02  -3.8 5.00e-01  -0.9 4.79e-02 1.85e-02h  1
#  222  7.2854709e+01 8.61e-03 4.31e+02  -3.8 4.18e-02  -1.4 1.00e+00 4.92e-01h  1
#  223  7.2951344e+01 2.38e-06 6.43e-01  -3.8 1.11e-01  -1.9 1.00e+00 1.00e+00f  1
#  224  7.2850406e+01 7.02e-06 1.28e-01  -3.8 1.67e-01  -2.4 1.00e+00 1.00e+00h  1
#  225  7.2800559e+01 4.98e-05 2.13e-01  -3.8 4.90e-01  -2.8 1.00e+00 1.00e+00h  1
#  226  7.2661829e+01 3.29e-04 4.77e-01  -3.8 1.35e+00  -3.3 1.00e+00 1.00e+00h  1
#  227  7.2693636e+01 3.30e-04 2.55e+02  -3.8 3.59e+00  -3.8 9.85e-01 2.50e-01h  3
#  228  7.2263539e+01 1.62e-04 4.92e-02  -3.8 1.89e-01  -2.5 1.00e+00 1.00e+00h  1
#  229  7.2533083e+01 2.56e-05 1.06e-01  -3.8 5.50e-01  -2.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  7.2389454e+01 2.84e-04 2.84e-01  -3.8 1.56e+00  -3.4 1.00e+00 1.00e+00h  1
#  231  7.1451766e+01 3.45e-03 1.11e+00  -3.8 4.16e+00  -3.9 1.00e+00 1.00e+00h  1
#  232  7.1053013e+01 2.08e-02 7.11e+00  -3.8 9.52e+00  -4.4 1.00e+00 1.00e+00h  1
#  233  7.1605183e+01 1.35e-02 9.00e+01  -3.8 3.60e+00  -3.9 3.41e-01 2.22e-01h  2
#  234  7.2715008e+01 6.18e-03 1.82e+02  -3.8 1.33e-01  -1.7 6.52e-01 5.00e-01h  2
#  235  7.2214812e+01 4.66e-03 3.24e+02  -3.8 2.66e-01  -2.2 8.85e-01 2.43e-01h  1
#  236  7.1228014e+01 1.68e-04 1.66e-01  -3.8 3.90e-02  -1.8 1.00e+00 1.00e+00f  1
#  237  7.1138737e+01 4.35e-05 1.72e-02  -3.8 7.02e-02  -2.2 1.00e+00 1.00e+00h  1
#  238  7.1036887e+01 1.98e-04 3.79e-02  -3.8 2.08e-01  -2.7 1.00e+00 1.00e+00h  1
#  239  7.0986960e+01 1.33e-04 9.75e-02  -3.8 6.08e-01  -3.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  7.0900266e+01 6.81e-04 3.57e-01  -3.8 1.72e+00  -3.7 1.00e+00 1.00e+00h  1
#  241  7.0681407e+01 1.03e-02 2.13e+00  -3.8 5.19e+00  -4.1 1.00e+00 1.00e+00h  1
#  242  7.0141093e+01 2.24e-03 7.13e-01  -3.8 2.03e+00  -3.7 1.00e+00 1.00e+00h  1
#  243  7.0109758e+01 1.70e-02 3.14e+00  -3.8 6.72e+00  -4.2 1.00e+00 1.00e+00h  1
#  244  7.0480050e+01 4.99e-04 1.03e-01  -3.8 3.09e-01  -2.9 1.00e+00 1.00e+00h  1
#  245  6.9936542e+01 3.15e-04 2.45e-02  -3.8 1.18e-01  -2.4 1.00e+00 1.00e+00h  1
#  246  7.0003685e+01 2.45e-05 5.19e-02  -3.8 3.59e-01  -2.9 1.00e+00 1.00e+00h  1
#  247  6.9796450e+01 3.22e-04 1.39e-01  -3.8 1.10e+00  -3.4 1.00e+00 1.00e+00h  1
#  248  6.9730559e+01 3.47e-03 6.09e-01  -3.8 3.44e+00  -3.9 1.00e+00 1.00e+00h  1
#  249  6.9681667e+01 5.14e-04 1.95e-01  -3.8 1.31e+00  -3.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  6.9532705e+01 8.77e-05 5.28e-02  -3.8 4.94e-01  -3.0 1.00e+00 1.00e+00h  1
#  251  6.9440547e+01 3.34e-04 1.60e-01  -3.8 1.51e+00  -3.5 1.00e+00 1.00e+00h  1
#  252  6.9180008e+01 4.56e-03 8.13e-01  -3.8 4.73e+00  -4.0 1.00e+00 1.00e+00h  1
#  253  6.8984615e+01 3.36e-04 2.63e-01  -3.8 1.77e+00  -3.5 1.00e+00 1.00e+00h  1
#  254  6.8729384e+01 6.55e-03 1.12e+00  -3.8 5.43e+00  -4.0 1.00e+00 1.00e+00h  1
#  255  6.8157310e+01 3.49e-03 3.40e-01  -3.8 2.04e+00  -3.6 1.00e+00 1.00e+00h  1
#  256  6.8106895e+01 1.03e-02 1.40e+00  -3.8 6.06e+00  -4.1 1.00e+00 1.00e+00h  1
#  257  6.8387510e+01 9.28e-03 1.51e+02  -3.8 1.06e+01  -3.6 9.32e-02 3.10e-02h  3
#  258  6.8731397e+01 3.41e-05 1.39e-01  -3.8 1.53e-02  -1.4 1.00e+00 1.00e+00h  1
#  259  6.8061025e+01 7.25e-05 4.71e-02  -3.8 3.95e-02  -1.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  6.7992001e+01 9.05e-05 7.73e-03  -3.8 1.19e-01  -2.4 1.00e+00 1.00e+00h  1
#  261  5.7353290e+01 1.31e-03 2.55e+02  -5.7 4.61e-01  -2.8 7.72e-01 5.21e-01f  1
#  262  5.2883619e+01 6.90e-04 6.04e+02  -5.7 7.71e-02  -1.5 8.95e-01 5.11e-01h  1
#  263  4.9652865e+01 7.31e-04 4.85e+02  -5.7 1.59e-01  -2.0 8.65e-01 6.46e-01h  1
#  264  4.9032908e+01 6.38e-04 1.33e+03  -5.7 3.67e-01  -2.5 1.00e+00 3.11e-01h  1
#  265  4.8423077e+01 2.96e-04 8.81e+02  -5.7 1.30e-01  -2.0 1.00e+00 5.56e-01h  1
#  266  4.8203320e+01 2.09e-04 1.08e+03  -5.7 3.50e-01  -2.5 1.00e+00 3.07e-01f  1
#  267  4.8074530e+01 1.81e-04 9.02e+02  -5.7 6.86e-01  -3.0 1.00e+00 1.67e-01f  1
#  268  4.7972910e+01 1.66e-04 9.34e+02  -5.7 1.73e+00  -3.5 1.00e+00 1.04e-01f  1
#  269  4.7670459e+01 3.02e-04 2.71e+02  -5.7 6.20e-01  -3.1 1.00e+00 6.79e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  4.7584614e+01 2.88e-04 2.39e+02  -5.7 1.90e+00  -3.5 3.04e-01 1.61e-01f  1
#  271  4.7411930e+01 2.52e-04 6.31e+02  -5.7 5.76e+00  -4.0 5.78e-01 1.83e-01f  1
#  272  4.7237422e+01 5.60e-04 7.18e+02  -5.7 1.64e+01  -4.5 2.67e-01 1.03e-01f  1
#  273  4.7143184e+01 1.09e-03 6.51e+02  -5.7 5.00e+01  -5.0 1.88e-02 2.21e-02h  1
#  274  4.7123440e+01 8.69e-04 3.09e+02  -5.7 2.89e-01  -2.7 4.71e-01 2.09e-01f  1
#  275  4.7064510e+01 6.68e-06 4.90e-01  -5.7 1.09e-01  -2.3 1.00e+00 1.00e+00f  1
#  276  4.7031682e+01 4.51e-05 1.37e+00  -5.7 3.21e-01  -2.8 9.58e-01 9.21e-01h  1
#  277  4.7013667e+01 8.73e-05 1.99e+00  -5.7 9.62e-01  -3.3 1.72e-01 1.53e-01f  1
#  278  4.6995712e+01 1.11e-04 3.04e+00  -5.7 3.61e-01  -2.8 4.82e-01 4.56e-01f  1
#  279  4.6987229e+01 4.53e-05 2.76e+01  -5.7 1.35e-01  -2.4 1.00e+00 7.68e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  4.6976022e+01 3.25e-05 5.65e+01  -5.7 4.07e-01  -2.9 1.00e+00 3.22e-01f  1
#  281  4.6878224e+01 1.39e-04 3.19e-02  -5.7 1.22e+00  -3.4 1.00e+00 1.00e+00f  1
#  282  4.6792414e+01 2.06e-04 3.77e+01  -5.7 3.66e+00  -3.8 1.00e+00 3.01e-01h  1
#  283  4.6553047e+01 2.13e-04 3.62e+01  -5.7 1.10e+01  -4.3 6.75e-01 2.96e-01f  1
#  284  4.6499623e+01 1.69e-04 2.92e+01  -5.7 3.31e+00  -3.9 2.08e-01 1.93e-01f  1
#  285  4.6325811e+01 1.39e-04 5.44e+01  -5.7 1.03e+01  -4.4 1.00e+00 2.07e-01f  1
#  286  4.5817541e+01 1.61e-03 3.53e+01  -5.7 3.03e+01  -4.8 1.45e-01 2.13e-01f  1
#  287  4.4286775e+01 6.71e-03 2.43e+01  -5.7 8.80e+01  -5.3 2.21e-01 2.28e-01f  1
#  288  4.2968120e+01 1.31e-02 5.85e+01  -5.7 3.39e+01  -4.9 8.22e-02 5.21e-01f  1
#  289  4.2765816e+01 1.09e-02 7.08e+01  -5.7 1.56e+01  -4.5 3.90e-02 1.71e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  4.2208867e+01 7.73e-04 1.16e+02  -5.7 7.96e+00  -4.0 1.16e-01 8.23e-01f  1
#  291  4.1457165e+01 7.07e-03 1.29e+02  -5.7 3.13e+03  -4.5 1.51e-03 2.05e-03f  1
#  292  4.1457665e+01 6.94e-03 1.22e+02  -5.7 3.03e+01  -5.0 4.00e-02 1.88e-02f  2
#  293  4.1445203e+01 6.93e-03 6.79e+01  -5.7 2.12e+02  -5.5 5.96e-02 9.82e-04h  1
#  294  4.1116529e+01 4.33e-03 4.89e+01  -5.7 3.29e+01  -5.0 2.52e-01 1.76e-01f  1
#  295  4.0298781e+01 2.60e-02 6.54e+01  -5.7 9.60e+01  -5.5 6.66e-02 1.53e-01f  1
#  296  3.9896144e+01 1.91e-02 9.30e+01  -5.7 9.92e+00  -4.2 1.98e-01 6.40e-01f  1
#  297  3.9309802e+01 1.71e-02 1.79e+01  -5.7 1.93e+01  -4.7 6.66e-01 5.14e-01h  1
#  298  3.8079268e+01 2.18e-01 1.18e+02  -5.7 2.98e+01  -5.1 1.77e-02 8.11e-01f  1
#  299  3.7981827e+01 1.65e-01 1.29e+02  -5.7 1.06e+01  -4.7 2.13e-02 2.53e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  3.7454096e+01 2.31e-01 2.47e+03  -5.7 3.80e+01  -5.2 3.69e-05 5.70e-01f  1
#  301  3.7455671e+01 2.25e-01 2.40e+03  -5.7 1.17e-01  -2.1 7.46e-02 2.87e-02f  4
#  302  3.7503379e+01 3.28e-05 4.24e+01  -5.7 1.97e-01  -2.5 7.95e-01 1.00e+00h  1
#  303  3.7496158e+01 1.68e-05 1.03e+00  -5.7 2.36e-01  -3.0 9.99e-01 9.71e-01h  1
#  304  3.7504491e+01 6.18e-04 3.14e+04  -5.7 2.42e+00  -3.5 9.90e-03 1.00e+00f  1
#  305  3.7490386e+01 6.07e-04 3.08e+04  -5.7 6.94e-02   1.4 1.34e-01 1.90e-02h  1
#  306  3.7489747e+01 5.97e-04 3.03e+04  -5.7 1.97e-01   1.0 8.01e-02 1.50e-02h  1
#  307  3.7490990e+01 5.73e-04 2.91e+04  -5.7 8.23e-01   0.5 1.67e-02 4.03e-02h  1
#  308  3.7492446e+01 5.52e-04 2.80e+04  -5.7 1.96e-01   0.9 4.89e-02 3.65e-02f  2
#  309  3.7497223e+01 5.02e-04 2.55e+04  -5.7 7.30e-01   0.4 1.10e-01 8.57e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  3.7498855e+01 4.97e-04 2.53e+04  -5.7 8.36e+00  -0.0 6.20e-03 9.07e-03f  2
#  311  3.7505009e+01 4.41e-04 2.24e+04  -5.7 5.32e-01   0.4 3.27e-01 1.09e-01h  2
#  312  3.7507744e+01 4.23e-04 2.15e+04  -5.7 2.45e+00  -0.1 8.71e-02 3.77e-02h  4
#  313  3.7509590e+01 4.06e-04 2.07e+04  -5.7 3.46e-01   0.3 6.23e-01 3.91e-02h  4
#  314  3.7545655e+01 1.10e-05 2.08e+03  -5.7 1.70e+00  -0.1 2.43e-01 6.15e-01h  1
#  315  3.7533199e+01 7.88e-06 1.47e+03  -5.7 1.03e-02  -0.6 2.88e-01 2.85e-01h  1
#  316  3.7517404e+01 3.42e-06 1.34e+03  -5.7 3.06e-02  -1.1 7.20e-02 5.65e-01f  1
#  317  3.7511027e+01 2.82e-06 6.00e+02  -5.7 7.53e-02  -1.6 5.68e-01 1.73e-01f  1
#  318  3.7503395e+01 1.88e-06 3.94e+02  -5.7 1.17e-01  -2.0 3.52e-01 2.96e-01f  1
#  319  3.7474144e+01 1.24e-05 1.85e+02  -5.7 3.24e-01  -2.5 6.26e-01 5.69e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  3.7466125e+01 1.18e-05 2.72e+02  -5.7 4.61e-01  -3.0 6.78e-01 9.26e-02f  1
#  321  3.7452307e+01 1.14e-05 1.65e+02  -5.7 6.58e-01  -3.5 2.58e-01 3.87e-01f  1
#  322  3.7368403e+01 6.65e-04 3.78e+01  -5.7 1.93e+00  -4.0 6.94e-01 1.00e+00f  1
#  323  3.7336953e+01 8.49e-05 3.29e+01  -5.7 7.16e-01  -3.5 6.02e-01 1.00e+00h  1
#  324  3.7241467e+01 7.60e-04 2.26e-01  -5.7 2.22e+00  -4.0 1.00e+00 1.00e+00h  1
#  325  3.7204802e+01 1.02e-04 2.40e-02  -5.7 8.46e-01  -3.6 1.00e+00 1.00e+00h  1
#  326  3.7093496e+01 8.84e-04 6.32e-01  -5.7 2.68e+00  -4.1 1.00e+00 1.00e+00h  1
#  327  3.7049669e+01 1.16e-04 1.05e-01  -5.7 1.03e+00  -3.6 1.00e+00 1.00e+00h  1
#  328  3.6916516e+01 9.82e-04 1.30e+00  -5.7 3.30e+00  -4.1 1.00e+00 1.00e+00h  1
#  329  3.6862243e+01 1.24e-04 2.22e-01  -5.7 1.27e+00  -3.7 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  3.6695945e+01 1.29e-03 2.77e+00  -5.7 4.14e+00  -4.2 1.00e+00 1.00e+00h  1
#  331  3.6624680e+01 2.37e-04 5.02e-01  -5.7 1.60e+00  -3.7 1.00e+00 1.00e+00h  1
#  332  3.6403088e+01 2.57e-03 7.10e+00  -5.7 5.37e+00  -4.2 1.00e+00 1.00e+00h  1
#  333  3.6300646e+01 4.96e-04 1.42e+00  -5.7 2.10e+00  -3.8 1.00e+00 1.00e+00h  1
#  334  3.6123289e+01 1.93e-03 1.22e+02  -5.7 7.34e+00  -4.3 1.00e+00 5.42e-01h  1
#  335  3.6116675e+01 1.92e-03 1.24e+04  -5.7 3.83e+01  -4.7 1.38e-01 6.66e-03h  1
#  336  3.5874215e+01 1.78e-03 1.06e+04  -5.7 6.66e+01  -5.2 2.35e-01 7.51e-02h  1
#  337  3.4709338e+01 1.37e-02 5.09e+01  -5.7 2.39e+01  -4.8 1.00e+00 1.00e+00f  1
#  338  3.3451947e+01 2.52e-02 4.74e+02  -5.7 7.56e+01  -5.3 2.78e-01 3.34e-01h  1
#  339  3.2622298e+01 1.91e-02 1.84e+03  -5.7 2.87e+01  -4.8 7.92e-02 5.70e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340  3.2634466e+01 1.89e-02 1.22e+03  -5.7 2.35e+01  -4.4 2.05e-01 8.58e-03h  3
#  341  3.2547406e+01 1.52e-02 1.45e+03  -5.7 1.16e+01  -4.9 6.75e-02 1.72e-01h  1
#  342  3.2532295e+01 1.49e-02 1.28e+03  -5.7 8.75e+00  -4.5 7.82e-02 2.54e-02h  1
#  343  3.2395791e+01 1.39e-02 1.29e+03  -5.7 4.65e+01  -4.9 3.22e-02 5.35e-02f  1
#  344  3.2291663e+01 1.38e-02 1.21e+03  -5.7 1.64e+02  -5.4 2.59e-02 1.27e-02f  1
#  345  3.1570835e+01 5.46e-03 7.76e+02  -5.7 4.85e+01  -5.0 3.19e-01 2.91e-01f  1
#  346  3.1007581e+01 1.15e-02 6.37e-01  -5.7 1.43e+01  -4.6 1.00e+00 1.00e+00h  1
#  347  3.0385948e+01 4.74e-02 1.75e+00  -5.7 2.65e+01  -5.0 7.18e-01 7.20e-01h  1
#  348  3.0385743e+01 4.73e-02 4.71e+01  -5.7 5.11e+00  -4.6 1.00e+00 1.97e-03h  1
#  349  3.0386957e+01 4.65e-02 3.87e+01  -5.7 1.77e-01  -2.4 1.79e-01 1.56e-02h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350  3.0388358e+01 4.62e-02 3.98e+01  -5.7 2.96e+00  -2.9 1.72e-02 6.74e-03h  1
#  351  3.0390785e+01 4.48e-02 3.53e+01  -5.7 1.67e-01  -2.4 3.47e-01 3.12e-02h  6
#  352  3.0472185e+01 2.73e-05 7.33e+00  -5.7 1.34e-01  -2.0 7.68e-01 1.00e+00h  1
#  353  3.0462970e+01 2.60e-06 3.69e-02  -5.7 8.48e-02  -2.5 1.00e+00 1.00e+00h  1
#  354  3.0456123e+01 6.61e-06 3.53e+00  -5.7 2.39e-01  -3.0 1.00e+00 9.03e-01h  1
#  355  3.0454262e+01 9.87e-06 2.60e+01  -5.7 3.68e-01  -3.4 1.00e+00 2.89e-01f  1
#  356  3.0430399e+01 5.01e-04 7.56e-03  -5.7 1.01e+00  -3.9 1.00e+00 1.00e+00f  1
#  357  3.0357720e+01 4.19e-03 8.18e-03  -5.7 3.08e+00  -4.4 1.00e+00 1.00e+00h  1
#  358  3.0140455e+01 3.19e-02 2.57e-01  -5.7 9.22e+00  -4.9 1.00e+00 1.00e+00h  1
#  359  2.9494581e+01 1.57e-01 1.08e+02  -5.7 2.75e+01  -5.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360  2.9256029e+01 1.48e-02 1.32e+01  -5.7 1.03e+01  -4.9 1.00e+00 1.00e+00h  1
#  361  2.9166334e+01 1.82e-03 5.84e-01  -5.7 3.87e+00  -4.5 1.00e+00 1.00e+00h  1
#  362  2.8897155e+01 8.66e-03 3.70e+00  -5.7 1.16e+01  -5.0 1.00e+00 1.00e+00h  1
#  363  2.8795410e+01 4.14e-04 9.92e+00  -5.7 4.77e+00  -4.6 7.34e-01 1.00e+00h  1
#  364  2.8409237e+01 2.67e-02 1.24e+01  -5.7 2.13e+01  -5.0 1.00e+00 1.00e+00h  1
#  365  2.8068507e+01 1.56e-02 4.41e+01  -5.7 1.07e+01  -4.6 4.88e-01 1.00e+00h  1
#  366  2.7745332e+01 2.92e-02 1.61e+02  -5.7 2.23e+02  -5.1 1.73e-01 4.63e-02h  1
#  367  2.7669157e+01 2.28e-02 1.29e+02  -5.7 1.15e+01  -4.7 1.98e-01 2.15e-01h  1
#  368  2.7537034e+01 1.14e-02 1.02e+02  -5.7 5.41e+00  -4.2 7.65e-03 5.15e-01f  1
#  369  2.6958983e+01 2.82e-02 2.88e+01  -5.7 1.49e+01  -4.7 5.94e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370  2.6806728e+01 1.02e-02 1.47e+01  -5.7 5.66e+00  -4.3 1.00e+00 7.00e-01h  1
#  371  2.6153467e+01 3.86e-02 6.02e+01  -5.7 1.73e+01  -4.8 3.47e-01 1.00e+00f  1
#  372  2.5994582e+01 2.96e-02 8.19e+01  -5.7 1.13e+01  -4.3 2.28e-02 2.54e-01h  1
#  373  2.5742541e+01 1.39e-03 6.24e+00  -5.7 3.45e+00  -3.9 9.51e-01 1.00e+00f  1
#  374  2.5727591e+01 1.38e-03 2.11e+01  -5.7 6.53e+01  -4.4 5.15e-03 3.48e-03h  1
#  375  2.5708922e+01 1.36e-03 1.58e+01  -5.7 2.18e+01  -4.9 1.30e-01 1.99e-02f  1
#  376  2.5674968e+01 1.27e-03 4.75e+01  -5.7 9.24e+00  -4.4 3.59e-01 7.81e-02f  1
#  377  2.5601469e+01 1.24e-03 4.56e+01  -5.7 2.76e+01  -4.9 4.33e-02 5.98e-02f  1
#  378  2.5383037e+01 2.22e-03 2.18e+01  -5.7 9.53e+00  -4.5 1.00e+00 5.51e-01f  1
#  379  2.4732540e+01 2.66e-02 1.74e+01  -5.7 2.31e+01  -5.0 8.01e-01 7.69e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380  2.4734142e+01 2.63e-02 7.82e+01  -5.7 1.55e+00  -1.8 3.85e-02 9.03e-03h  1
#  381  2.4739163e+01 2.29e-02 5.70e+01  -5.7 3.26e-01  -2.3 4.07e-01 1.30e-01h  1
#  382  2.4740709e+01 2.22e-02 7.65e+01  -5.7 1.52e-01  -2.8 8.88e-01 3.12e-02f  6
#  383  2.4777354e+01 1.58e-05 5.24e-02  -5.7 4.73e-01  -3.3 1.00e+00 1.00e+00h  1
#  384  2.4773994e+01 9.47e-06 5.17e+01  -5.7 8.08e-01  -3.7 1.00e+00 1.59e-01h  1
#  385  2.4741897e+01 1.44e-03 7.23e-02  -5.7 1.64e+00  -4.2 1.00e+00 1.00e+00f  1
#  386  2.4643712e+01 1.39e-02 1.71e+00  -5.7 4.90e+00  -4.7 1.00e+00 1.00e+00h  1
#  387  2.4606975e+01 1.93e-03 1.72e-01  -5.7 1.84e+00  -4.3 1.00e+00 1.00e+00h  1
#  388  2.4496789e+01 1.88e-02 3.90e+00  -5.7 5.51e+00  -4.7 1.00e+00 1.00e+00h  1
#  389  2.4455515e+01 2.60e-03 3.85e-01  -5.7 2.07e+00  -4.3 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390  2.4331731e+01 2.56e-02 1.38e+01  -5.7 6.19e+00  -4.8 1.00e+00 1.00e+00h  1
#  391  2.4285370e+01 3.51e-03 1.48e+00  -5.7 2.32e+00  -4.4 1.00e+00 1.00e+00h  1
#  392  2.4238573e+01 6.24e-03 4.04e+02  -5.7 6.96e+00  -4.8 1.00e+00 3.37e-01h  1
#  393  2.3822017e+01 3.56e-01 1.13e+02  -5.7 2.08e+01  -5.3 1.00e+00 1.00e+00f  1
#  394  2.3691078e+01 8.75e-02 2.11e+02  -5.7 7.80e+00  -4.9 1.00e+00 8.41e-01h  1
#  395  2.3224430e+01 5.01e-01 3.60e+01  -5.7 2.33e+01  -5.4 1.00e+00 1.00e+00h  1
#  396  2.3127245e+01 2.40e-01 2.62e+02  -5.7 8.75e+00  -4.9 7.11e-01 5.57e-01h  1
#  397  2.3123409e+01 2.22e-01 3.02e+02  -5.7 9.48e+00  -4.5 1.13e-02 7.48e-02h  1
#  398  2.3124777e+01 1.80e-01 2.24e+02  -5.7 5.69e-03   0.4 2.52e-01 1.90e-01f  2
#  399  2.3125289e+01 8.35e-03 6.39e+00  -5.7 1.07e-03   0.8 9.71e-01 9.54e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400  2.3126029e+01 1.66e-07 3.74e+02  -5.7 5.37e-04   0.4 1.73e-01 1.00e+00h  1
#  401  2.3124517e+01 1.41e-07 3.72e+02  -5.7 2.14e-01  -0.1 2.17e-01 1.18e-02h  1
#  402  2.3126122e+01 2.03e-08 5.60e+02  -5.7 4.08e-03  -0.6 5.84e-01 2.50e-01f  3
#  403  2.3125022e+01 1.14e-07 1.15e+00  -5.7 6.12e-03  -1.1 1.00e+00 1.00e+00h  1
#  404  2.3124611e+01 2.83e-08 6.85e-02  -5.7 3.63e-03  -1.5 1.00e+00 1.00e+00h  1
#  405  2.3123762e+01 5.16e-08 4.29e-03  -5.7 1.08e-02  -2.0 1.00e+00 1.00e+00h  1
#  406  2.3123046e+01 2.54e-07 2.21e-02  -5.7 3.17e-02  -2.5 1.00e+00 1.00e+00h  1
#  407  2.3121024e+01 4.66e-06 5.24e-02  -5.7 9.34e-02  -3.0 1.00e+00 1.00e+00h  1
#  408  2.3120335e+01 7.11e-07 2.82e-02  -5.7 3.49e-02  -2.5 1.00e+00 1.00e+00h  1
#  409  2.3120089e+01 8.42e-08 2.04e-02  -5.7 1.31e-02  -2.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410  2.3120069e+01 4.31e-08 5.07e+00  -5.7 7.24e-03  -1.7 6.52e-01 7.90e-01h  1
#  411  2.3120070e+01 4.31e-08 5.07e+00  -5.7 9.64e+00  -2.2 1.92e-05 1.58e-05f  2
#  412  2.3120078e+01 4.33e-08 1.43e+01  -5.7 1.38e+00   1.0 3.46e-03 1.02e-04f  2
#  413  2.3120040e+01 4.07e-08 5.41e+01  -5.7 5.25e-03   0.5 8.87e-01 5.74e-02h  2
#  414  2.3119873e+01 1.35e-08 3.94e+00  -5.7 1.32e-04   0.0 8.43e-01 1.00e+00h  1
#  415  2.3119975e+01 4.06e-08 3.49e+01  -5.7 3.37e-03  -0.5 6.79e-01 1.29e-01h  3
#  416  2.3120494e+01 1.12e-06 1.82e+01  -5.7 3.13e-03  -0.9 4.11e-01 1.00e+00h  1
#  417  2.3120519e+01 1.12e-06 3.60e+01  -5.7 2.99e-02  -1.4 2.07e-01 5.54e-03h  6
#  418  2.3120583e+01 1.11e-06 1.43e+02  -5.7 9.56e-03  -1.0 1.00e+00 8.99e-03h  7
#  419  2.3120624e+01 1.10e-06 1.57e+02  -5.7 2.66e-02  -1.5 4.76e-01 7.81e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420  2.3120644e+01 1.10e-06 1.61e+02  -5.7 1.08e-02  -1.0 1.00e+00 1.95e-03h 10
#  421  2.3120654e+01 1.10e-06 1.65e+02  -5.7 2.73e-02  -1.5 2.81e-01 1.95e-03h 10
#  422  2.3120658e+01 1.10e-06 1.40e+02  -5.7 1.01e-02  -1.1 5.51e-01 9.77e-04h 11
#  423  2.3123283e+01 2.79e-06 1.30e+02  -5.7 5.58e-02  -1.6 7.19e-02 7.19e-02s 21
#  424  2.3131258e+01 2.26e-05 2.49e+01  -5.7 1.33e-02  -1.1 8.08e-01 8.08e-01s 21
#  425  2.3133557e+01 3.16e-06 1.09e-01  -5.7 4.48e-03  -0.7 1.00e+00 1.00e+00s 21
#  426r 2.3133557e+01 3.16e-06 1.00e+03  -5.7 0.00e+00  -1.2 0.00e+00 0.00e+00R  1
#  427r 2.3133775e+01 5.53e-07 9.26e+02  -5.7 1.68e+00    -  1.68e-01 9.90e-04f  1
#  428r 2.3176844e+01 1.34e-04 7.29e+02  -5.7 6.92e-01    -  4.45e-01 1.41e-01f  1
#  429r 2.3252015e+01 1.18e-04 5.71e+02  -5.7 1.52e-01    -  2.31e-01 1.16e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430r 2.3418293e+01 9.19e-05 3.44e+02  -5.7 1.81e-01    -  2.94e-01 2.16e-01h  1
#  431r 2.4290989e+01 9.83e-05 3.91e+02  -5.7 2.07e-01    -  2.70e-01 7.89e-01h  1
#  432r 2.5599495e+01 1.22e-05 2.11e+02  -5.7 1.47e-02  -2.0 5.30e-01 1.00e+00h  1
#  433r 2.8319262e+01 7.81e-05 1.99e+02  -5.7 1.07e-01    -  5.40e-01 1.00e+00h  1
#  434r 3.4260071e+01 8.57e-05 1.44e+02  -5.7 1.14e-01    -  3.70e-01 1.00e+00h  1
#  435r 4.1236581e+01 4.77e-05 1.12e+02  -5.7 2.45e-01    -  3.05e-01 8.44e-01h  1
#  436r 5.3732905e+01 1.57e-04 1.08e+02  -5.7 3.81e-01    -  4.10e-01 1.00e+00h  1
#  437r 7.5838351e+01 1.05e-04 8.93e+01  -5.7 3.20e-01    -  4.41e-01 1.00e+00h  1
#  438r 1.1667815e+02 2.64e-04 5.47e+01  -5.7 1.92e-02  -2.5 4.59e-01 1.00e+00h  1
#  439r 1.9662995e+02 1.58e-03 4.58e+01  -5.7 2.11e-01    -  1.69e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440r 2.2822046e+02 9.41e-04 1.47e+01  -5.7 3.00e-02  -2.1 6.79e-01 4.03e-01h  1
#  441r 4.0521169e+02 2.04e-04 1.07e+01  -5.7 4.34e-02  -2.5 2.72e-01 7.68e-01h  1
#  442r 7.3132448e+02 2.82e-03 5.77e+00  -5.7 6.23e-01    -  4.63e-01 1.00e+00h  1
#  443r 1.2764126e+03 4.19e-03 2.76e+00  -5.7 1.43e-01    -  5.23e-01 1.00e+00h  1
#  444r 2.3263423e+03 1.27e-03 1.49e+00  -5.7 2.50e-01    -  4.89e-01 1.00e+00h  1
#  445r 3.7853108e+03 6.15e-03 1.32e+00  -5.7 5.05e-01    -  4.52e-01 8.20e-01h  1
#  446r 6.1427765e+03 3.14e-03 1.24e+00  -5.7 2.75e-01    -  6.21e-01 1.00e+00h  1
#  447r 1.0644007e+04 3.24e-03 1.63e+00  -5.7 2.36e-01    -  5.69e-01 1.00e+00h  1
#  448r 1.8287343e+04 4.69e-03 1.75e+00  -5.7 1.34e-01    -  4.54e-01 9.67e-01h  1
#  449r 2.8389874e+04 1.23e-03 1.63e+00  -5.7 1.04e-01    -  4.23e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450r 3.7458538e+04 1.15e-03 2.46e-03  -5.7 4.84e-02    -  1.00e+00 1.00e+00h  1
#  451r 5.8927511e+04 1.41e-04 3.23e-03  -5.7 6.14e-02    -  1.00e+00 1.00e+00h  1
#  452r 5.2424052e+04 3.44e-05 6.14e-05  -5.7 1.31e-02    -  1.00e+00 1.00e+00h  1
#  453r 5.1563016e+04 1.83e-07 3.30e-08  -5.7 1.43e-03    -  1.00e+00 1.00e+00h  1
#  454  5.1497789e+04 1.73e-07 9.92e+01  -5.7 3.95e+03    -  2.87e-02 1.95e-05f 10
#  455  5.1461457e+04 1.67e-07 9.92e+01  -5.7 7.52e+03    -  8.53e-03 3.29e-05f 11
#  456  1.3959097e+04 6.05e-02 9.52e+01  -5.7 6.78e+03    -  3.08e-02 4.02e-02f  1
#  457  1.3817842e+04 6.05e-02 3.98e+03  -5.7 1.32e+03    -  4.87e-01 1.01e-03f  1
#  458  1.0223781e+04 1.07e-01 3.21e+03  -5.7 1.02e+03    -  8.31e-02 1.38e-01f  1
#  459  7.8683032e+03 1.09e-01 3.24e+03  -5.7 4.90e+02    -  2.60e-01 1.35e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460  7.4305672e+03 1.05e-01 4.69e+03  -5.7 1.77e+02    -  6.43e-01 3.88e-02f  1
#  461  7.0154273e+03 9.98e-02 4.47e+03  -5.7 3.10e+01    -  6.19e-02 4.88e-02f  1
#  462  6.4807378e+03 9.21e-02 4.36e+03  -5.7 3.07e+01    -  6.80e-01 6.73e-02f  1
#  463  6.4602362e+03 9.18e-02 4.26e+03  -5.7 1.04e+02    -  1.31e-01 2.96e-03f  1
#  464  5.7205436e+03 8.13e-02 4.03e+03  -5.7 1.36e+00  -1.7 9.04e-01 1.09e-01f  1
#  465  2.2741552e+03 4.16e-02 1.61e+03  -5.7 3.44e+00  -2.1 6.28e-01 5.89e-01f  1
#  466  1.7005077e+03 3.42e-02 1.56e+03  -5.7 1.51e+00  -2.6 7.65e-02 2.55e-01f  1
#  467  1.5568476e+03 3.17e-02 4.40e+02  -5.7 3.27e+00  -3.1 6.69e-01 8.58e-02f  1
#  468  1.4317944e+03 2.79e-02 3.16e+02  -5.7 7.46e+00  -3.6 2.20e-01 8.14e-02f  1
#  469  1.4266181e+03 2.78e-02 3.15e+02  -5.7 3.57e+00  -1.3 3.35e-03 3.41e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470  1.4265978e+03 2.78e-02 3.14e+02  -5.7 2.04e+02  -1.8 5.01e-09 5.21e-05f  1
#  471  1.4265039e+03 2.78e-02 3.14e+02  -5.7 5.46e+01  -2.3 4.99e-09 5.74e-05f  1
#  472  1.4265039e+03 2.78e-02 3.14e+02  -5.7 3.09e+02  -1.9 3.89e-10 2.27e-06f  2
#  473  1.4257306e+03 2.77e-02 4.07e+02  -5.7 1.45e-01  -0.5 8.62e-01 5.61e-04h  1
#  474  7.8926807e+02 1.48e-02 1.81e+02  -5.7 1.08e-01  -1.0 2.98e-02 4.63e-01f  1
#  475  7.5721177e+02 1.39e-02 1.73e+02  -5.7 1.33e+00  -1.5 5.29e-02 4.27e-02f  1
#  476  7.1544674e+02 1.27e-02 1.63e+02  -5.7 2.30e+00  -2.0 3.07e-02 5.78e-02f  1
#  477  5.2697690e+02 1.46e-02 1.23e+02  -5.7 1.13e+00  -2.5 5.22e-01 2.76e-01f  1
#  478  4.0344073e+02 1.29e-02 1.57e+02  -5.7 1.68e+00  -2.9 6.15e-01 2.50e-01f  1
#  479  2.1490509e+02 1.00e-02 1.63e+02  -5.7 6.34e-01  -2.5 6.32e-01 5.17e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480  1.8810264e+02 8.45e-03 3.11e+02  -5.7 1.39e+00  -3.0 7.06e-01 1.47e-01f  1
#  481  1.4690815e+02 6.11e-03 2.97e+02  -5.7 6.02e-01  -2.6 4.74e-01 2.68e-01f  1
#  482  1.2876334e+02 5.13e-03 3.13e+02  -5.7 1.46e+00  -3.0 4.47e-01 1.55e-01f  1
#  483  9.6183562e+01 3.26e-03 1.08e+02  -5.7 6.44e-01  -2.6 1.66e-02 3.36e-01f  1
#  484  9.2876677e+01 3.10e-03 3.88e+02  -5.7 1.49e+00  -3.1 4.22e-01 4.89e-02f  1
#  485  8.6648252e+01 2.79e-03 3.38e+02  -5.7 4.37e+00  -3.6 6.32e-02 9.24e-02f  1
#  486  7.6762261e+01 2.27e-03 4.52e+02  -5.7 1.52e+00  -3.1 4.49e-01 1.69e-01f  1
#  487  7.2833821e+01 2.04e-03 4.36e+02  -5.7 5.95e+00  -3.6 1.33e-01 7.66e-02f  1
#  488  6.4379493e+01 1.60e-03 3.19e+02  -5.7 1.68e+00  -3.2 2.06e-02 1.87e-01f  1
#  489  5.0739710e+01 8.66e-04 1.96e+02  -5.7 6.42e-01  -2.8 3.24e-01 3.75e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490  4.0052332e+01 4.42e-04 7.17e+02  -5.7 2.34e-01  -2.3 9.85e-01 4.61e-01f  1
#  491  3.2870823e+01 1.97e-04 7.73e+02  -5.7 2.81e-02  -1.0 8.33e-01 5.51e-01f  1
#  492  3.2570778e+01 1.96e-04 9.45e+04  -5.7 3.25e-01   2.1 6.71e-02 1.09e-03f  1
#  493  3.1700068e+01 1.64e-04 9.38e+04  -5.7 4.32e-02   1.6 6.47e-03 1.65e-01f  1
#  494  2.8184084e+01 2.55e-05 7.93e+04  -5.7 6.09e-04   3.0 1.52e-01 8.44e-01f  1
#  495  2.7534907e+01 3.48e-06 5.45e+04  -5.7 4.50e-04   2.5 3.13e-01 8.64e-01f  1
#  496  2.7440118e+01 2.52e-06 4.95e+04  -5.7 8.62e-04   2.0 9.08e-02 2.75e-01f  1
#  497  2.7403170e+01 2.34e-06 2.68e+04  -5.7 1.60e-03   1.5 4.58e-01 7.30e-02f  1
#  498  2.7356855e+01 2.20e-06 2.49e+04  -5.7 3.76e-03   1.1 7.16e-02 5.63e-02f  1
#  499  2.7119727e+01 2.46e-06 2.47e+04  -5.7 4.48e-03   0.6 7.15e-03 3.06e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500  2.7039717e+01 2.42e-06 1.61e+04  -5.7 6.44e-03   0.1 3.48e-01 1.09e-01f  1
#  501  2.6849740e+01 2.76e-06 1.47e+04  -5.7 1.72e-02  -0.4 8.59e-02 2.37e-01f  1
#  502  2.6719133e+01 2.59e-06 1.26e+04  -5.7 3.49e-02  -0.8 1.44e-01 1.04e-01f  1
#  503  2.6524452e+01 2.91e-06 1.03e+04  -5.7 1.23e-02  -0.4 1.87e-01 3.73e-01f  1
#  504  2.6439951e+01 2.53e-06 7.24e+01  -5.7 2.73e-02  -0.9 1.00e+00 1.90e-01f  1
#  505  2.6352548e+01 5.78e-06 1.06e+02  -5.7 5.97e-02  -1.4 1.00e+00 2.67e-01f  1
#  506  2.6305470e+01 3.30e-06 4.36e+01  -5.7 2.32e-02  -0.9 6.33e-01 4.54e-01f  1
#  507  2.6232781e+01 7.76e-06 1.99e+01  -5.7 7.14e-02  -1.4 7.33e-01 5.38e-01f  1
#  508  2.6144726e+01 2.84e-05 1.02e+02  -5.7 1.88e-01  -1.9 9.96e-01 3.70e-01f  1
#  509  2.6108222e+01 7.49e-05 9.39e+01  -5.7 9.91e-01  -2.4 6.63e-02 7.63e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510  2.6028526e+01 1.09e-04 1.08e+02  -5.7 8.36e-01  -2.8 1.75e-01 8.44e-02f  1
#  511  2.5841641e+01 4.69e-04 8.51e+01  -5.7 2.73e+00  -3.3 3.78e-02 8.41e-02f  1
#  512  2.5688935e+01 4.36e-04 6.59e+01  -5.7 9.48e-01  -2.9 3.32e-01 1.84e-01f  1
#  513  2.5566169e+01 5.39e-04 6.38e+01  -5.7 2.33e+00  -3.4 7.54e-02 5.56e-02f  1
#  514  2.5488424e+01 4.96e-04 5.42e+01  -5.7 7.59e-01  -3.0 5.46e-01 1.23e-01f  1
#  515  2.5336812e+01 5.38e-04 5.28e+01  -5.7 1.95e+00  -3.4 1.43e-01 1.08e-01f  1
#  516  2.5255888e+01 4.78e-04 3.95e+01  -5.7 6.73e-01  -3.0 2.34e-01 2.18e-01f  1
#  517  2.5063034e+01 2.01e-03 3.11e+01  -5.7 2.14e+00  -3.5 7.80e-02 1.67e-01f  1
#  518  2.5042603e+01 1.91e-03 2.95e+01  -5.7 7.78e-01  -3.1 1.73e-01 5.22e-02f  1
#  519  2.5022501e+01 1.64e-03 4.00e+01  -5.7 5.14e-01  -2.6 6.86e-02 1.42e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520  2.5006368e+01 1.56e-03 3.74e+01  -5.7 8.50e-01  -3.1 4.60e-03 5.28e-02f  1
#  521  2.4968474e+01 1.66e-03 3.60e+01  -5.7 2.62e+00  -3.6 3.80e-02 3.82e-02f  1
# ...
# 1913  1.8494818e-01 1.35e-08 2.49e-03  -5.7 1.77e-02    -  1.00e+00 1.00e+00h  1
# 1914  1.8495000e-01 1.35e-08 2.53e-03  -5.7 1.77e-02    -  1.00e+00 1.00e+00h  1
# 1915  1.8495185e-01 1.35e-08 2.57e-03  -5.7 1.77e-02    -  1.00e+00 1.00e+00h  1
# 1916  1.8495373e-01 1.35e-08 2.61e-03  -5.7 1.76e-02    -  1.00e+00 1.00e+00h  1
# 1917  1.8495563e-01 1.35e-08 2.65e-03  -5.7 1.76e-02    -  1.00e+00 1.00e+00h  1
# 1918  1.8495757e-01 1.35e-08 2.70e-03  -5.7 1.75e-02    -  1.00e+00 1.00e+00h  1
# 1919  1.8495955e-01 1.35e-08 2.74e-03  -5.7 1.75e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1920  1.8496157e-01 1.35e-08 2.79e-03  -5.7 1.74e-02    -  1.00e+00 1.00e+00h  1
# 1921  1.8496362e-01 1.35e-08 2.84e-03  -5.7 1.73e-02    -  1.00e+00 1.00e+00h  1
# 1922  1.8496573e-01 1.35e-08 2.90e-03  -5.7 1.73e-02    -  1.00e+00 1.00e+00h  1
# 1923  1.8496787e-01 1.35e-08 2.95e-03  -5.7 1.72e-02    -  1.00e+00 1.00e+00h  1
# 1924  1.8497007e-01 1.35e-08 3.01e-03  -5.7 1.72e-02    -  1.00e+00 1.00e+00h  1
# 1925  1.8497232e-01 1.34e-08 3.06e-03  -5.7 1.71e-02    -  1.00e+00 1.00e+00h  1
# 1926  1.8497463e-01 1.34e-08 3.13e-03  -5.7 1.70e-02    -  1.00e+00 1.00e+00h  1
# 1927  1.8497699e-01 1.34e-08 3.19e-03  -5.7 1.70e-02    -  1.00e+00 1.00e+00h  1
# 1928  1.8497941e-01 1.34e-08 3.26e-03  -5.7 1.69e-02    -  1.00e+00 1.00e+00h  1
# 1929  1.8498189e-01 1.34e-08 3.33e-03  -5.7 1.68e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1930  1.8498444e-01 1.34e-08 3.40e-03  -5.7 1.67e-02    -  1.00e+00 1.00e+00h  1
# 1931  1.8498705e-01 1.34e-08 3.47e-03  -5.7 1.67e-02    -  1.00e+00 1.00e+00h  1
# 1932  1.8498973e-01 1.34e-08 3.55e-03  -5.7 1.66e-02    -  1.00e+00 1.00e+00h  1
# 1933  1.8499247e-01 1.34e-08 3.64e-03  -5.7 1.65e-02    -  1.00e+00 1.00e+00h  1
# 1934  1.8499529e-01 1.34e-08 3.73e-03  -5.7 1.64e-02    -  1.00e+00 1.00e+00h  1
# 1935  1.8499819e-01 1.34e-08 3.82e-03  -5.7 1.63e-02    -  1.00e+00 1.00e+00h  1
# 1936  1.8500116e-01 1.34e-08 3.92e-03  -5.7 1.62e-02    -  1.00e+00 1.00e+00h  1
# 1937  1.8500420e-01 1.34e-08 4.02e-03  -5.7 1.61e-02    -  1.00e+00 1.00e+00h  1
# 1938  1.8500733e-01 1.34e-08 4.13e-03  -5.7 1.60e-02    -  1.00e+00 1.00e+00h  1
# 1939  1.8501053e-01 1.34e-08 4.25e-03  -5.7 1.59e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1940  1.8501382e-01 1.34e-08 4.38e-03  -5.7 1.58e-02    -  1.00e+00 1.00e+00h  1
# 1941  1.8501720e-01 1.34e-08 4.51e-03  -5.7 1.57e-02    -  1.00e+00 1.00e+00h  1
# 1942  1.8502066e-01 1.34e-08 4.66e-03  -5.7 1.55e-02    -  1.00e+00 1.00e+00h  1
# 1943  1.8502421e-01 1.34e-08 4.81e-03  -5.7 1.54e-02    -  1.00e+00 1.00e+00h  1
# 1944  1.8502784e-01 1.34e-08 4.98e-03  -5.7 1.53e-02    -  1.00e+00 1.00e+00h  1
# 1945  1.8503157e-01 1.34e-08 5.16e-03  -5.7 1.51e-02    -  1.00e+00 1.00e+00h  1
# 1946  1.8503539e-01 1.34e-08 5.36e-03  -5.7 1.50e-02    -  1.00e+00 1.00e+00h  1
# 1947  1.8503930e-01 1.34e-08 5.57e-03  -5.7 1.48e-02    -  1.00e+00 1.00e+00h  1
# 1948  1.8504330e-01 1.34e-08 5.81e-03  -5.7 1.46e-02    -  1.00e+00 1.00e+00h  1
# 1949  1.8504739e-01 1.34e-08 6.08e-03  -5.7 1.45e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1950  1.8505157e-01 1.34e-08 6.38e-03  -5.7 1.43e-02    -  1.00e+00 1.00e+00h  1
# 1951  1.8505584e-01 1.34e-08 6.71e-03  -5.7 1.41e-02    -  1.00e+00 1.00e+00h  1
# 1952  1.8506020e-01 1.34e-08 7.10e-03  -5.7 1.39e-02    -  1.00e+00 1.00e+00h  1
# 1953  1.8506464e-01 1.34e-08 7.55e-03  -5.7 1.37e-02    -  1.00e+00 1.00e+00h  1
# 1954  1.8506915e-01 1.34e-08 8.09e-03  -5.7 1.34e-02    -  1.00e+00 1.00e+00h  1
# 1955  1.8507373e-01 1.34e-08 8.74e-03  -5.7 1.32e-02    -  1.00e+00 1.00e+00h  1
# 1956  1.8507838e-01 1.34e-08 9.60e-03  -5.7 1.30e-02    -  1.00e+00 1.00e+00h  1
# 1957  1.8508306e-01 1.34e-08 1.09e-02  -5.7 1.27e-02    -  1.00e+00 1.00e+00h  1
# 1958  1.8508836e-01 1.34e-08 6.07e-03  -5.7 8.77e-04  -6.3 1.00e+00 1.00e+00h  1
# 1959  1.8509233e-01 1.34e-08 4.37e-02  -5.7 6.20e-03  -5.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1960  1.8509727e-01 1.34e-08 1.31e-03  -5.7 1.87e-04  -5.4 1.00e+00 1.00e+00h  1
# 1961  1.8510266e-01 1.34e-08 2.31e-03  -5.7 3.34e-04  -5.0 1.00e+00 1.00e+00h  1
# 1962  1.8510815e-01 1.34e-08 1.49e-03  -5.7 2.17e-04  -5.5 1.00e+00 1.00e+00h  1
# 1963  1.8511354e-01 1.34e-08 7.64e-03  -5.7 1.12e-03  -5.1 1.00e+00 1.00e+00h  1
# 1964  1.8511106e-01 1.34e-08 2.84e-01  -5.7 3.65e-02  -5.5 1.00e+00 1.00e+00h  1
# 1965  1.8511077e-01 1.34e-08 2.08e-01  -5.7 2.45e-02  -5.1 1.00e+00 1.00e+00h  1
# 1966  1.8511293e-01 1.34e-08 7.31e-02  -5.7 8.65e-03  -4.7 1.00e+00 1.00e+00h  1
# 1967  1.8510897e-01 1.34e-08 5.81e-01  -5.7 5.73e-02  -5.2 1.00e+00 1.00e+00h  1
# 1968  1.8510980e-01 1.34e-08 2.26e-01  -5.7 2.16e-02  -4.7 1.00e+00 1.00e+00h  1
# 1969  1.8510093e-01 1.34e-08 1.92e+00  -5.7 1.27e-01  -5.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1970  1.8510047e-01 1.34e-08 7.41e-01  -5.7 4.58e-02  -4.8 1.00e+00 1.00e+00h  1
# 1971  1.8509024e-01 1.34e-08 5.81e+00  -5.7 2.20e-01  -5.3 1.00e+00 1.00e+00h  1
# 1972  1.8508949e-01 1.34e-08 1.55e+00  -5.7 6.59e-02  -4.8 1.00e+00 1.00e+00h  1
# 1973  1.8508324e-01 1.34e-08 7.75e+00  -5.7 2.41e-01  -5.3 1.00e+00 1.00e+00h  1
# 1974  1.8506303e-01 2.99e-08 8.07e+01  -5.7 3.98e+00  -5.8 2.47e-01 1.37e-01h  2
# 1975  1.8504680e-01 1.34e-08 2.15e+00  -5.7 1.33e-01  -5.4 1.00e+00 1.00e+00h  1
# 1976  1.8504099e-01 3.45e-08 6.77e+01  -5.7 9.29e-01  -5.8 1.00e+00 1.00e+00h  1
# 1977  1.8499638e-01 5.55e-08 2.76e+02  -5.7 5.42e+00    -  6.95e-01 4.58e-01h  2
# 1978  1.8496936e-01 6.39e-08 1.47e+02  -5.7 5.01e+00    -  1.00e+00 1.00e+00h  1
# 1979  1.8503177e-01 1.32e-07 2.72e+02  -5.7 1.09e+01    -  6.31e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1980  1.8500810e-01 9.44e-08 2.54e+02  -5.7 1.13e+01    -  1.00e+00 1.00e+00h  1
# 1981  1.8505505e-01 2.72e-07 5.19e+02  -5.7 4.21e+01    -  6.04e-01 1.00e+00h  1
# 1982  1.8491639e-01 1.01e-05 4.05e+04  -5.7 4.50e+02    -  1.61e-01 1.00e+00H  1
# 1983  1.8502855e-01 2.47e-06 9.92e+03  -5.7 2.74e+02    -  1.00e+00 1.00e+00h  1
# 1984  1.8504344e-01 3.56e-07 1.44e+03  -5.7 6.56e+01    -  1.00e+00 1.00e+00h  1
# 1985  1.8506365e-01 3.89e-07 1.50e+03  -5.7 2.03e+02    -  1.00e+00 1.00e+00h  1
# 1986  1.8505278e-01 1.34e-06 5.62e+03  -5.7 7.34e+02    -  1.00e+00 1.00e+00h  1
# 1987  1.8507181e-01 2.49e-06 1.03e+04  -5.7 1.19e+03    -  1.00e+00 1.00e+00h  1
# 1988  1.8506498e-01 7.48e-07 3.11e+03  -5.7 5.88e+02    -  1.00e+00 1.00e+00h  1
# 1989  1.8507210e-01 1.63e-06 6.53e+03  -5.7 3.19e+03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1990  1.8506911e-01 6.18e-06 2.53e+04  -5.7 9.39e+03    -  1.00e+00 1.00e+00h  1
# 1991  1.8507512e-01 1.15e-06 4.72e+03  -5.7 2.51e+03    -  1.00e+00 1.00e+00h  1
# 1992  1.8507640e-01 1.69e-06 7.06e+03  -5.7 1.47e+04    -  1.00e+00 1.00e+00h  1
# 1993  1.8507951e-01 6.88e-06 2.82e+04  -5.7 5.17e+04    -  1.00e+00 1.00e+00h  1
# 1994  1.8508075e-01 2.32e-07 9.52e+02  -5.7 2.76e+03    -  1.00e+00 1.00e+00h  1
# 1995  1.8508261e-01 3.36e-08 1.34e+02  -5.7 1.11e+04    -  1.00e+00 1.00e+00h  1
# 1996  1.8508434e-01 1.34e-08 2.30e+00  -5.7 1.62e+03    -  1.00e+00 1.00e+00h  1
# 1997  1.8508600e-01 1.34e-08 4.54e-05  -5.7 5.47e-01    -  1.00e+00 1.00e+00h  1
# 1998  1.8508759e-01 1.34e-08 1.45e-06  -5.7 1.76e-02    -  1.00e+00 1.00e+00h  1
# 1999  8.0649683e-02 9.36e-02 4.02e+00  -7.0 1.72e+01    -  5.00e-01 4.77e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2000 -1.1215216e-02 1.57e-02 6.63e+00  -7.0 5.23e-01  -6.3 7.48e-01 8.31e-01h  1
# 2001 -2.6130309e-02 1.81e-03 1.75e+00  -7.0 4.46e-02  -4.1 9.14e-01 8.85e-01h  1
# 2002 -2.6956449e-02 5.33e-05 3.84e-01  -7.0 5.06e-02  -4.6 1.00e+00 1.00e+00h  1
# 2003 -2.1449141e-02 1.37e-04 5.25e+01  -7.0 5.56e-02  -5.0 6.64e-01 1.00e+00H  1
# 2004 -2.0088517e-02 1.14e-04 2.52e+01  -7.0 5.10e-01  -5.5 4.00e-01 1.26e-01h  3
# 2005 -1.4508271e-02 5.67e-05 5.97e-01  -7.0 9.77e-02  -5.1 1.00e+00 1.00e+00H  1
# 2006 -1.4509274e-02 5.30e-05 4.13e+00  -7.0 4.79e+02    -  2.12e-02 3.77e-04h  6
# 2007 -1.5596312e-02 7.54e-06 4.45e-02  -7.0 2.28e-02  -4.7 1.00e+00 1.00e+00h  1
# 2008r-1.5596312e-02 7.54e-06 1.00e+03  -5.3 0.00e+00    -  0.00e+00 2.81e-07R 21
# 2009r-1.5101950e-02 1.06e-06 9.58e+02  -5.3 4.86e-01    -  4.76e-02 9.90e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2010 -2.2460098e-02 8.51e-07 4.77e+02  -7.0 6.15e-04    -  1.00e+00 1.95e-01h  1
# 2011 -3.2790793e-02 2.39e-05 7.95e+00  -7.0 1.95e-01    -  9.92e-01 8.79e-01f  1
# 2012 -3.1294019e-02 1.54e-03 1.99e+01  -7.0 1.27e+01    -  6.38e-01 2.19e-01f  3
# 2013 -2.5259351e-02 7.68e-04 2.90e+01  -7.0 3.65e-02  -5.1 1.00e+00 5.00e-01h  2
# 2014 -2.5215250e-02 7.65e-04 6.10e+01  -7.0 2.55e+01    -  9.86e-01 7.81e-03h  8
# 2015 -2.4393775e-02 6.69e-04 5.92e+01  -7.0 1.09e-01  -5.6 1.00e+00 1.25e-01h  4
# 2016 -2.4349668e-02 6.66e-04 6.66e+01  -7.0 2.52e+01    -  9.87e-01 7.81e-03h  8
# 2017 -2.4260424e-02 6.58e-04 6.58e+01  -7.0 1.41e+01    -  8.48e-02 1.44e-02h  4
# 2018 -2.4101878e-02 6.41e-04 6.66e+01  -7.0 8.43e-01  -6.1 1.00e+00 2.70e-02h  6
# 2019 -2.4058057e-02 6.37e-04 6.80e+01  -7.0 2.43e+01    -  1.00e+00 7.81e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020 -2.4042453e-02 6.36e-04 6.84e+01  -7.0 1.69e+01    -  7.26e-01 2.77e-03h  9
# 2021 -2.4031501e-02 6.35e-04 6.88e+01  -7.0 9.52e-02  -5.7 1.00e+00 1.95e-03h 10
# 2022 -1.8445658e-02 3.23e-02 3.31e+01  -7.0 2.42e+01    -  1.00e+00 1.00e+00w  1
# 2023 -1.8219641e-02 2.94e-02 3.02e+01  -7.0 1.73e+01    -  9.18e-02 8.96e-02w  1
# 2024 -1.7798821e-02 2.43e-02 4.07e+01  -7.0 9.50e-02  -6.2 8.21e-01 1.73e-01w  1
# 2025 -2.4030819e-02 6.34e-04 6.90e+01  -7.0 7.81e+01    -  1.00e+00 1.22e-04h 13
# 2026 -2.4030477e-02 6.34e-04 6.91e+01  -7.0 1.07e-01  -5.7 1.00e+00 6.10e-05h 15
# 2027 -1.8442651e-02 3.24e-02 3.25e+01  -7.0 2.42e+01    -  1.00e+00 1.00e+00s 22
# 2028 -1.8046786e-02 2.73e-02 2.78e+01  -7.0 1.44e+01    -  1.56e-01 1.56e-01s 22
# 2029 -1.5730069e-02 1.06e-04 6.22e+01  -7.0 1.02e-01  -6.2 1.00e+00 0.00e+00S 22
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2030 -1.5729516e-02 1.06e-04 5.83e+01  -7.0 6.67e+00    -  5.34e-01 4.17e-03h  8
# 2031 -1.4849110e-02 2.57e-05 2.69e+01  -7.0 5.16e-01  -6.7 4.58e-01 8.96e-01H  1
# 2032 -1.4802659e-02 3.40e-05 2.56e+01  -7.0 2.68e+00  -7.2 1.85e-01 9.16e-02f  3
# 2033 -1.4641135e-02 3.16e-05 2.35e+01  -7.0 2.25e-01  -3.1 1.21e-02 7.00e-02h  1
# 2034 -1.4636269e-02 2.51e-05 2.00e+01  -7.0 8.73e-03  -3.6 5.37e-01 2.06e-01f  2
# 2035 -1.4541221e-02 3.37e-06 3.73e+00  -7.0 9.48e-03  -4.1 6.64e-01 8.66e-01h  1
# 2036 -1.4529570e-02 4.16e-09 7.34e-02  -7.0 1.23e-02  -4.6 1.00e+00 1.00e+00f  1
# 2037 -1.4541867e-02 7.61e-08 7.79e-03  -7.0 6.21e-03  -5.0 1.00e+00 1.00e+00h  1
# 2038 -1.4542643e-02 4.23e-06 3.82e+00  -7.0 7.34e+00    -  6.05e-01 4.29e-02h  5
# 2039 -1.4541822e-02 3.56e-06 4.30e+00  -7.0 2.03e-02  -5.5 7.81e-01 1.59e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2040 -1.4548223e-02 3.38e-06 4.17e+00  -7.0 1.33e-02  -3.3 3.90e-01 4.98e-02h  3
# 2041 -1.4530665e-02 1.24e-09 1.65e-05  -7.0 8.94e-04  -3.8 1.00e+00 1.00e+00h  1
# 2042 -1.4530717e-02 1.11e-08 2.55e+00  -7.0 3.44e+01    -  7.56e-02 2.96e-04h  9
# 2043 -1.4529804e-02 8.29e-09 1.43e+00  -7.0 6.99e-03  -4.2 1.00e+00 2.50e-01h  3
# 2044 -1.4529854e-02 2.34e-08 3.30e+00  -7.0 8.74e+00    -  4.94e-01 1.97e-03h  9
# 2045 -1.4530078e-02 2.20e-08 1.56e+00  -7.0 2.67e-03  -4.7 1.00e+00 6.25e-02h  5
# 2046 -1.4530159e-02 2.16e-08 1.29e+00  -7.0 6.78e-03  -5.2 1.00e+00 1.56e-02h  7
# 2047 -1.4533780e-02 3.34e-05 1.51e+00  -7.0 2.68e+03    -  7.22e-04 1.98e-04h  3
# 2048 -1.4537868e-02 7.76e-07 4.67e-03  -7.0 2.02e-02  -5.7 1.00e+00 1.00e+00h  1
# 2049 -1.4542014e-02 5.24e-05 2.45e+00  -7.0 1.57e+01    -  2.47e-01 5.82e-02h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2050 -1.4540322e-02 2.62e-05 2.18e+00  -7.0 5.79e-02  -6.1 1.00e+00 5.00e-01h  2
# 2051 -1.4545933e-02 9.04e-05 2.81e+00  -7.0 1.09e+01    -  4.93e-01 1.32e-01h  3
# 2052 -1.4547406e-02 6.72e-05 1.81e+00  -7.0 1.43e-01  -6.6 1.00e+00 2.57e-01h  2
# 2053 -1.4554573e-02 1.75e-05 2.86e-01  -7.0 4.35e-01  -7.1 1.00e+00 1.00e+00h  1
# 2054 -1.4561154e-02 5.51e-05 4.10e+00  -7.0 2.25e+01    -  2.66e-01 6.69e-02h  3
# 2055 -1.4561315e-02 1.90e-05 1.10e+00  -7.0 1.53e+00  -7.6 1.00e+00 1.00e+00h  1
# 2056 -1.4584737e-02 1.88e-04 3.58e+00  -7.0 2.24e+01    -  3.98e-01 2.16e-01h  2
# 2057 -1.4592441e-02 1.29e-04 2.51e+00  -7.0 3.47e+00  -8.0 1.00e+00 3.04e-01h  2
# 2058 -1.4623592e-02 1.94e-04 8.33e+00  -7.0 7.54e+01    -  1.51e-01 7.15e-02h  2
# 2059 -1.4656859e-02 2.09e-03 4.83e+00  -7.0 1.38e+01  -8.5 4.87e-01 4.52e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2060 -1.4751787e-02 3.09e-02 1.09e+01  -7.0 1.69e+01  -9.0 1.00e+00 1.00e+00h  1
# 2061 -1.4803553e-02 8.57e-02 2.71e+01  -7.0 3.70e+02    -  1.12e-01 3.57e-02h  2
# 2062 -1.4838225e-02 2.45e-01 5.02e+01  -7.0 2.01e+02    -  2.22e-01 9.85e-02h  2
# 2063 -1.4912602e-02 1.40e+00 4.95e+01  -7.0 7.15e+01    -  9.54e-01 1.00e+00h  1
# 2064 -1.4899429e-02 2.36e-01 7.64e+00  -7.0 1.56e+01  -9.5 9.16e-01 1.00e+00h  1
# 2065 -1.4908107e-02 5.61e-01 4.42e+01  -7.0 4.13e+01    -  9.43e-01 1.00e+00h  1
# 2066 -1.4895873e-02 3.62e-01 2.11e+02  -7.0 3.38e+02    -  7.67e-01 1.00e+00h  1
# 2067 -1.4894399e-02 2.05e-03 7.10e+02  -7.0 5.56e+02    -  1.00e+00 1.00e+00h  1
# 2068 -1.4892885e-02 3.40e-04 1.23e+02  -7.0 1.48e+02    -  1.00e+00 1.00e+00h  1
# 2069 -1.4891887e-02 1.92e-04 2.90e+02  -7.0 1.13e+03    -  9.34e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2070 -1.4890956e-02 1.48e-05 2.59e+03  -7.0 6.10e+03    -  5.22e-01 1.00e+00h  1
# 2071 -1.4890604e-02 1.52e-06 3.94e+01  -7.0 1.30e+02    -  1.00e+00 1.00e+00h  1
# 2072 -1.4890253e-02 1.04e-07 1.04e+02  -7.0 7.55e+03    -  1.00e+00 1.00e+00h  1
# 2073 -1.4889954e-02 5.51e-07 2.23e+03  -7.0 8.20e+04    -  1.00e+00 1.00e+00h  1
# 2074 -1.4889737e-02 5.60e-08 7.44e+01  -7.0 3.38e+03    -  1.00e+00 1.00e+00h  1
# 2075 -1.4889552e-02 2.31e-08 4.56e+00  -7.0 5.31e+03    -  1.00e+00 1.00e+00h  1
# 2076 -1.4889397e-02 7.71e-09 1.42e-02  -7.0 3.19e+02    -  1.00e+00 1.00e+00h  1
# 2077 -1.4889266e-02 1.65e-09 6.30e-08  -7.0 5.25e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 2077
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.4889265768257550e-04   -1.4889265768257550e-02
# Dual infeasibility......:   6.2993684935008787e-08    6.2993684935008787e-06
# Constraint violation....:   1.0255626037751581e-09    1.6524813317433838e-09
# Complementarity.........:   9.0909090909334172e-08    9.0909090909334178e-06
# Overall NLP error.......:   9.0909090909334172e-08    9.0909090909334178e-06
#
#
# Number of objective function evaluations             = 2825
# Number of objective gradient evaluations             = 1991
# Number of equality constraint evaluations            = 2825
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2081
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 2077
# Total CPU secs in IPOPT (w/o function evaluations)   =    137.279
# Total CPU secs in NLP function evaluations           =     20.112
#
# EXIT: Optimal Solution Found.
# ok
# optimal
# --------------------------------
# GROUND:   7.426727766707409e-08
# GROUND2:  0.0
# CONTACTS: 3.0655240464453817e-06
# JOINT:    1.4905257510307088e-06
# FORCE:    0.0
# TORQUE:   0.0
# --------------------------------
# Elapsed Time: 2.712703812122345 mins

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 100  # Set Duration To 1000 ms == 1 second
if (str(results.solver.termination_condition) == "optimal"):
    winsound.Beep(frequency, duration)
    winsound.Beep(frequency, duration)
    winsound.Beep(frequency, duration)
else:
    winsound.Beep(500, 500)

# %%
# CALCULATE MAX VALUES
maxvalues = skaterlib_biped_with_body_new.get_max_values(m, N, ground_constraints, contact_constraints, joint_constraints, joints, 
                                           WDOFs, DOF_b, Fs, signs, GRFs, legs)
maxForce = maxvalues[0]
maxGRF   = maxvalues[1]
maxGRFbf = maxvalues[2]
maxF_a   = maxvalues[3]

# %%
reload(skaterlib_biped_with_body_new);
# maxForce = 1
# maxGRF   = 1
# maxGRFbf = 1
# maxF_a   = 1
# N = 38
# N = 60
# m.q.pprint()
# print(N)

# %%
# ANIMATE THE RESULTS
from IPython.display import HTML
# %matplotlib inline
Ns = [N,N1,N2,N3,Nhw]
animate = skaterlib_biped_with_body_new.make_animation(m, Ns, 'OU', X_step, Y_step, 0, 0, maxForce, maxGRF, maxGRFbf, maxF_a)
HTML(animate.to_html5_video()) #you need to convert the animation to HTML5 to embed it in the notebook
# Out:
# OU
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# m.pwheel.pprint()
# X_step

# %%
# m.ground_contact.pprint()

# %%
# ANIMATE THE RESULTS
from IPython.display import HTML
# %matplotlib inline

animate_realtime = skaterlib_biped_with_body_new.make_realtime_animation(m, N, hm)
HTML(animate_realtime.to_html5_video()) #you need to convert the animation to HTML5 to embed it in the notebook
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
import matplotlib.pyplot as plt

# Plot some of the variables
F_BFxar  = [BW*m.Fb_b_total[i,'BF','x_b']() for i in range(1,N+1)]
F_FFxar  = [BW*m.Fb_b_total[i,'FF','x_b']() for i in range (1,N+1)]
F_BFyar  = [BW*m.Fb_b_total[i,'BF','y_b']() for i in range(1,N+1)]
F_FFyar  = [BW*m.Fb_b_total[i,'FF','y_b']() for i in range (1,N+1)]
GRF_BWar = [BW*(m.GRF[i,'BW']()+m.GRF_s[i,'BW']()) for i in range(1,N+1)]
GRF_FWar = [BW*(m.GRF[i,'FW']()+m.GRF_s[i,'FW']()) for i in range(1,N+1)]
tau_bar = [BW*m.tau_b[i]() for i in range (1,N+1)]
tau_a_BLar = [BW*m.tau_a[i,'BL']() for i in range (1,N+1)]
tau_a_FLar = [BW*m.tau_a[i,'FL']() for i in range (1,N+1)]
GfuncBWY = [m.Gfunc[i,'BW','Y']() for i in range (1,N+1)]
GfuncBWX = [m.pwheel[i,'BW','X']() for i in range (1,N+1)]
GfuncFWY = [m.Gfunc[i,'FW','Y']() for i in range (1,N+1)]
GfuncFWX = [m.pwheel[i,'FW','X']() for i in range (1,N+1)]
OBSfuncBW = [m.OBSfunc[i,'BW','Y']() for i in range (1,N+1)]
OBSfuncFW = [m.OBSfunc[i,'FW','Y']() for i in range (1,N+1)]

# tarr = [m.h[i]() for i in range (1,N+1)]
# t = hm*np.cumsum(np.asarray(tarr))
# t -= t[0]

nar = np.linspace(1,N,N)

plt.figure(figsize=(15, 15))
plt.subplot(4,1,1)
plt.step(nar, F_BFxar,where='post')
plt.step(nar, F_FFxar,where='post')
plt.title('Friction Force (x)')
plt.xlabel('N')
plt.legend([r'$F_{BFx}$',r'$F_{FFx}$'])
plt.grid(True)

plt.subplot(4,1,2)
plt.step(nar, F_BFyar,where='post')
plt.step(nar, F_FFyar,where='post')
plt.title('Normal Force (y)')
plt.xlabel('N')
plt.legend([r'$F_{BFy}$',r'$F_{FFy}$'])
plt.grid(True)

plt.subplot(4,1,3)
plt.step(nar, GRF_BWar,where='post')
plt.step(nar, GRF_FWar,where='post')
plt.title('Ground Reaction Forces')
plt.xlabel('N')
plt.legend([r'$GRF_{BW}$',r'$GRF_{FW}$'])
plt.grid(True)

plt.subplot(4,1,4)
plt.step(GfuncBWX, GfuncBWY,where='post')
plt.step(GfuncFWX, GfuncFWY,where='post')
plt.step(GfuncBWX, OBSfuncBW,where='post')
plt.step(GfuncFWX, OBSfuncFW,where='post')
plt.title('Ground Function')
plt.xlabel('$x_{BW}$')
plt.ylabel('$y_{BW}$')
# plt.legend([r'$GRF_{BW}$',r'$GRF_{FW}$'])
plt.grid(True)


# plt.subplot(4,1,4)
# plt.step(nar,tau_bar,where ='post')
# plt.step(nar,tau_a_BLar,where ='post')
# plt.step(nar,tau_a_FLar,where ='post')
# plt.title('Applied Torques')
# plt.xlabel('N')
# plt.legend([r'$\tau_{body}$',r'$\tau_{BL}$',r'$\tau_{FL}$'])
# plt.grid(True)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-a76a5c77571d> in <module>
#      15 GfuncFWY = [m.Gfunc[i,'FW','Y']() for i in range (1,N+1)]
#      16 GfuncFWX = [m.pwheel[i,'FW','X']() for i in range (1,N+1)]
# ---> 17 OBSfuncBW = [m.OBSfunc[i,'BW','Y']() for i in range (1,N+1)]
#      18 OBSfuncFW = [m.OBSfunc[i,'FW','Y']() for i in range (1,N+1)]
#      19
#
# <ipython-input-59-a76a5c77571d> in <listcomp>(.0)
#      15 GfuncFWY = [m.Gfunc[i,'FW','Y']() for i in range (1,N+1)]
#      16 GfuncFWX = [m.pwheel[i,'FW','X']() for i in range (1,N+1)]
# ---> 17 OBSfuncBW = [m.OBSfunc[i,'BW','Y']() for i in range (1,N+1)]
#      18 OBSfuncFW = [m.OBSfunc[i,'FW','Y']() for i in range (1,N+1)]
#      19
#
# ~\AppData\Local\Continuum\anaconda3\envs\envCartPole\lib\site-packages\pyomo\core\base\block.py in __getattr__(self, val)
#     547         # throw the "normal" AttributeError
#     548         raise AttributeError("'%s' object has no attribute '%s'"
# --> 549                              % (self.__class__.__name__, val))
#     550
#     551     def __setattr__(self, name, val):
#
# AttributeError: 'ConcreteModel' object has no attribute 'OBSfunc'

# %%
m.OBSfunc.pprint()

# %%
# maxGRF

# %%
from datetime import datetime

now = datetime.now() # dd/mm/YY H:M:S
dt_string = now.strftime("%d_%m_%Y_%H_%M.pkl")

Ns = m.N.bounds()[1]

modelname = 'model_biped_OU_N'+str(Ns)+ '_' + dt_string 
filepath = 'saved_models\\'
filename = filepath+modelname
print(filename)

if (str(results.solver.termination_condition) == "optimal"):
    with open(filename, mode='wb') as file:
        cloudpickle.dump(m, file)
        print("model saved")
else:
    print("model not saved - not optimal solution.")
