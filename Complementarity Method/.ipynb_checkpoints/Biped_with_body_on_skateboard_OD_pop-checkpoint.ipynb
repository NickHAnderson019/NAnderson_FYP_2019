# %% [markdown]
# # Biped on Skateboard - OD

# %%
# import my libraries
import eomlib_biped_with_body
import skaterlib_biped_with_body_new
from importlib import reload
# import Python libraries
import cloudpickle
import numpy as np
import time
import winsound
from pyomo.environ import*
from pyomo.opt import SolverFactory
from pyomo.opt import SolverStatus, TerminationCondition

reload(eomlib_biped_with_body);
reload(skaterlib_biped_with_body_new);

# Open a model to initialize the trajectory
# model = 'model_biped_RO_N65_30_09_2019_08_17.pkl' # 0.5m, dq = 0 at N, correct objective
# model = 'model_biped_RO_N65_30_09_2019_10_00.pkl' # 0.5m, dq = 0 at N, correct objective
# model = 'model_biped_RO_N38_30_09_2019_23_25.pkl'
# model = 'model_biped_OU_N38_02_10_2019_16_18.pkl' # not working, but new stuff
model = 'model_biped_OD_N65_03_10_2019_08_47.pkl' # sort of working for OD from 0.2m
model = 'model_biped_OD_N65_03_10_2019_14_12.pkl' # almost, 0.36m
model = 'model_biped_OD_N65_03_10_2019_14_31.pkl' # working! But didn't tell it to land and then stand. Need to add that

filepath = 'saved_models\\'
filename = filepath+model
with open(filename, mode='rb') as file:
    m_saved = cloudpickle.load(file)

# %%
# SKATEBOARD
EOMs_board_lamb = eomlib_biped_with_body.get_EOMs_board()
EOMs_board = EOMs_board_lamb[0]
lambEOMx_board   = EOMs_board_lamb[1][0]
lambEOMy_board   = EOMs_board_lamb[1][1]
lambEOMth_board  = EOMs_board_lamb[1][2]

# BIPED WITH BODY
EOMs_biped_lamb = eomlib_biped_with_body.get_EOMs_biped_with_body()
EOMs_biped = EOMs_biped_lamb[0]
lambEOMxp_biped    = EOMs_biped_lamb[1][0]
lambEOMyp_biped    = EOMs_biped_lamb[1][1]
lambEOMthp_biped   = EOMs_biped_lamb[1][2]
lambEOMthb_biped   = EOMs_biped_lamb[1][3]
lambEOMthll_biped  = EOMs_biped_lamb[1][4]
lambEOMrl_biped    = EOMs_biped_lamb[1][5]
lambEOMthlr_biped  = EOMs_biped_lamb[1][6]
lambEOMrr_biped    = EOMs_biped_lamb[1][7]

# FOOT POSITIONS AND VELOCITIES
EOMs_foot_lamb = eomlib_biped_with_body.get_foot_v_and_p()
lambfootx_l        = EOMs_foot_lamb[1][0][0]
lambfooty_l        = EOMs_foot_lamb[1][0][1]
lambfootx_l_board  = EOMs_foot_lamb[1][0][2]
lambfooty_l_board  = EOMs_foot_lamb[1][0][3]
lambvfootx_l_board = EOMs_foot_lamb[1][0][4]
lambfootx_r        = EOMs_foot_lamb[1][1][0]
lambfooty_r        = EOMs_foot_lamb[1][1][1]
lambfootx_r_board  = EOMs_foot_lamb[1][1][2]
lambfooty_r_board  = EOMs_foot_lamb[1][1][3]
lambvfootx_r_board = EOMs_foot_lamb[1][1][4]

# %%
if 'm' in globals():
    del m # deletes the model
    
m = ConcreteModel()

# SETS-----------------------------------------------------------------------------------------------------------------------

N = 65
N1 = 20 # the "pop" 
N2 = 55 # landing
N3 = 60 # steady
N4 = 65 # end
Nhw = round(0.5*(N1+N2)) # node to reach max height
m.N = RangeSet(N)

# %%
DOFs = ['x','y','th','xp','yp','thp','thb','thl_l','r_l','thl_r','r_r'] # generalized coordinates
m.DOF = Set(initialize = DOFs) 

Fs = ['BF','FF'] # front foot, backfoot
m.Fs = Set(initialize = Fs) 

legs = ['BL','FL'] # front leg, back leg
m.Legs = Set(initialize = legs) 

bodies = ['board','BL','FL'] # board, back leg, front leg
m.Bodies = Set(initialize = bodies) 

GRFs = ['BW','FW'] # front wheel, back wheel
m.GRFs = Set(initialize = GRFs) 

links = [('pelvis',1),('body',1),('left_leg',1),('left_leg',2),('right_leg',1),('right_leg',2)]
m.L = Set(dimen=2, initialize = links)

WDOFs = ['X','Y'] # absolute coordinates
m.WDOF = Set(initialize = WDOFs)

DOF_b = ['x_b','y_b'] # coordinates in skateboard frame
m.DOF_b = Set(initialize = DOF_b)

DOF_g = ['x_g','y_g'] # coordinates in ground frame
m.DOF_g = Set(initialize = DOF_g)

DOF_o = ['x_o','y_o'] # coordinates in obstruction frame
m.DOF_o = Set(initialize = DOF_o)

Bd = ['nose','tail','BW','FW'] # front foot, backfoot
m.Bd = Set(initialize = Bd) 

# PARAMETERS-----------------------------------------------------------------------------------------------------------------

# general
m.g = Param(initialize = 9.81) # gravity

# board
m.mbd = Param(initialize = 2.0) # mass of board
m.lbd = Param(initialize = 0.80) # length of board
m.lbrd = Param(initialize = 0.45) # length between wheels lb-(14.3+3)*2
m.hbd = Param(initialize = 0.09) # board clearance
m.etail = Param(initialize = -0.6) #coefficient of restitution of tail
m.Inbd = Param(initialize = 1/12*m.mbd*m.lbd**2) # moment of inertia about centre

h_h = 1.7 # human height
h_m = 73.0  # human weight

l_pelvis = 0.4 #1.7*0.191
h_knee = 0.45
h_thigh = 0.45
hr_max = 0.45
h_body = h_h - h_knee - h_thigh

m_knee = 2.0/20.0*h_m
m_thigh = 2.0/20.0*h_m
m_pelvis = 2.0/20.0*h_m
m_body = h_m - 2*m_thigh - 2*m_knee - m_pelvis

X_step = 1.2 # 2m
Y_step = 0.36 #0.1 # 0.1m

# biped
def get_m(n, lb, ln):
    l = (lb,ln)
    if lb == 'body':
        return m_body
    if lb == 'pelvis':
        return m_pelvis
    if l == ('left_leg',1) or l == ('right_leg',1): 
        return m_thigh
    if l == ('left_leg',2) or l == ('right_leg',2):
        return m_knee
m.m = Param(m.L, initialize = get_m) # mass of links

def get_len(n, lb, ln):
    l = (lb,ln)
    if lb == 'body':
        return h_body
    if lb == 'pelvis':
        return l_pelvis
    if l == ('left_leg',1) or l == ('right_leg',1): 
        return h_thigh
    if l == ('left_leg',2) or l == ('right_leg',2):
        return h_knee
m.len = Param(m.L, initialize = get_len) # length of links

def calculate_In(m, lb, ln): 
    l = (lb,ln)
    return 1/12*m.m[l]*m.len[l]**2 
m.In = Param(m.L, initialize = calculate_In) # moment of inertia

m_biped = sum(m.m[l] for l in links)
BW = m_biped*m.g

# %%
# VARIABLES -----------------------------------------------------------------------------------------------------------------

# system coordinates
m.q = Var(m.N, m.DOF) # position
m.dq = Var(m.N, m.DOF) # velocity
m.ddq = Var(m.N, m.DOF) # acceleration

# applied and ground reaction forces and torques
# sign set for positive and negative components
signs = ['ps','ng'] 
m.sgn = Set(initialize = signs)

m.Fb_b = Var(m.N, m.Fs, m.DOF_b, m.sgn, bounds = (0.0,None)) # Forces from front and back feet, board frame
m.Fb_b_total = Var(m.N, m.Fs, m.DOF_b)
m.GRF = Var(m.N, m.GRFs, bounds = (0.0, None)) # Ground reaction force on front and back wheel
m.GRF_s = Var(m.N, m.GRFs, bounds = (0.0, None)) # Ground reaction force on front and back wheel from step
m.GRFbf = Var(m.N, m.Fs, m.WDOF)
m.tau_a = Var(m.N, m.Legs, bounds = (-1.0,1.0)) # actuator torque at hip
m.tau_b = Var(m.N, bounds = (-1.0,1.0)) # actuator torque at body
m.F_a = Var(m.N, m.Legs, bounds = (-3.0,3.0)) # actuator force at knee
m.F_r = Var(m.N, m.Legs, m.sgn, bounds = (0.0,None)) # rebound force (acts parallel to the leg)

# AUXILIARY VARIABLES

# skateboard
m.ptail = Var(m.N, m.WDOF) # back of board
m.pnose = Var(m.N, m.WDOF) # front of board
m.pwheel = Var(m.N, m.GRFs, m.WDOF) # position of wheels
m.vtail = Var(m.N, m.WDOF) # velocity of back of board

def def_ptail(m,n,dof):
    if dof == 'X':
        return m.ptail[n, 'X'] == m.q[n,'x'] - 0.5*m.lbd*cos(m.q[n,'th'])
    if dof == 'Y':
        return m.ptail[n, 'Y'] == m.q[n,'y'] - 0.5*m.lbd*sin(m.q[n,'th']) 
    else:
        return Constraint.Skip
m.def_ptail = Constraint(m.N, m.WDOF,rule = def_ptail)

def def_pnose(m,n,dof):
    if dof == 'X':
        return m.pnose[n, 'X'] == m.q[n,'x'] + 0.5*m.lbd*cos(m.q[n,'th'])
    if dof == 'Y':
        return m.pnose[n, 'Y'] == m.q[n,'y'] + 0.5*m.lbd*sin(m.q[n,'th']) 
    else:
        return Constraint.Skip
m.def_pnose = Constraint(m.N, m.WDOF,rule = def_pnose)

def def_pwheels(m,n,wheel,dof):
    if wheel == 'BW':
        if dof == 'X':
            return m.pwheel[n,'BW','X'] == m.q[n,'x']-0.5*m.lbrd*cos(m.q[n,'th'])+m.hbd*sin(m.q[n,'th'])
        if dof == 'Y':
            return m.pwheel[n,'BW','Y'] == m.q[n,'y']-0.5*m.lbrd*sin(m.q[n,'th'])-m.hbd*cos(m.q[n,'th'])
        else:
            return Constraint.Skip
    if wheel == "FW":
        if dof == 'X':
            return m.pwheel[n,'FW','X'] == m.q[n,'x']+0.5*m.lbrd*cos(m.q[n,'th'])+m.hbd*sin(m.q[n,'th'])
        if dof == 'Y':
            return m.pwheel[n,'FW','Y'] == m.q[n,'y']+0.5*m.lbrd*sin(m.q[n,'th'])-m.hbd*cos(m.q[n,'th'])
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_pwheels = Constraint(m.N, m.GRFs, m.WDOF,rule = def_pwheels)

def def_vtail(m,n,dof):
    if dof == 'Y':
        return m.vtail[n, 'Y'] == m.dq[n,'y']-m.dq[n,'th']*0.5*m.lbd*cos(m.q[n,'th'])
    else:
        return Constraint.Skip
m.def_vtail = Constraint(m.N, m.WDOF,rule = def_vtail)

# skateboard - bound variables
for n in range(1,N+1):
    m.q[n,'th'].setub(np.pi/2)
    m.q[n,'th'].setlb(-np.pi/2)

# %%
# Ground function stuff ------------------------------------------------------------------------------------------------------------
m.Gfunc = Var(m.N, m.Bd, m.WDOF, bounds = (0.0, Y_step)) # ground function
m.pwheel_sgn_g = Var(m.N, m.GRFs, m.DOF_g, m.sgn, bounds = (0.0, None)) # position of wheels - slack

def def_pwheel_sgn_g(m,n,grf):
    if grf == 'BW':
        return m.pwheel_sgn_g[n,'BW','x_g','ps'] - m.pwheel_sgn_g[n,'BW','x_g','ng'] == m.pwheel[n,'BW','X'] - X_step
    if grf == 'FW':
        return m.pwheel_sgn_g[n,'FW','x_g','ps'] - m.pwheel_sgn_g[n,'FW','x_g','ng'] == m.pwheel[n,'FW','X'] - X_step
    else:
        return Constraint.Skip
m.def_pwheel_sgn_g = Constraint(m.N, m.GRFs,rule = def_pwheel_sgn_g)

# penalty for handling the changing ground function
ground_func_constraints = ['contact_BW1','contact_FW1','contact_BW2','contact_FW2']
m.ground_func_constraints = Set(initialize = ground_func_constraints) # set for indexing ground-related penalties
m.ground_func_penalty = Var(m.N, m.ground_func_constraints, bounds = (0.0,None))

def def_Gfunc(m,n,gc):
    if gc == 'contact_BW1':
        return m.ground_func_penalty[n,'contact_BW1'] == m.Gfunc[n,'BW','Y']*m.pwheel_sgn_g[n,'BW','x_g','ps']
    if gc == 'contact_FW1':
        return m.ground_func_penalty[n,'contact_FW1'] == m.Gfunc[n,'FW','Y']*m.pwheel_sgn_g[n,'FW','x_g','ps']
    if gc == 'contact_BW2':
        return m.ground_func_penalty[n,'contact_BW2'] == (Y_step-m.Gfunc[n,'BW','Y'])*m.pwheel_sgn_g[n,'BW','x_g','ng']
    if gc == 'contact_FW2':
        return m.ground_func_penalty[n,'contact_FW2'] == (Y_step - m.Gfunc[n,'FW','Y'])*m.pwheel_sgn_g[n,'FW','x_g','ng']
    else:
        return Constraint.Skip
m.def_Gfunc = Constraint(m.N, m.ground_func_constraints, rule = def_Gfunc)

# %%
# Inequaliies for ground function ----------------------------------------------------------------------------------------

m.ptail_g = Var(m.N, m.DOF_g) # back of board
m.pnose_g = Var(m.N, m.DOF_g) # front of board
m.pwheel_g = Var(m.N, m.GRFs, m.DOF_g) # position of wheels

def board_g(m,n,bd):
#     if bd == 'nose':
#         return m.pnose_g[n,'y_g'] == m.pnose[n,'Y'] - m.Gfunc[n,'nose','Y']
    if bd == 'tail':
        return m.ptail_g[n,'y_g'] == m.ptail[n,'Y'] - m.Gfunc[n,'BW','Y']
    if bd == 'BW':
        return m.pwheel_g[n,'BW','y_g'] == m.pwheel[n,'BW','Y'] - m.Gfunc[n,'BW','Y']
    if bd == 'FW':
        return m.pwheel_g[n,'FW','y_g'] == m.pwheel[n,'FW','Y'] - m.Gfunc[n,'FW','Y']
    else: 
        return Constraint.Skip
m.board_g = Constraint(m.N, m.Bd, rule = board_g)

for n in range(1,N+1):
#     m.pnose_g[n,'y_g'].setlb(0.0)
    m.ptail_g[n,'y_g'].setlb(0.0)
    m.pnose[n,'Y'].setlb(0.0)
    m.pwheel_g[n,'BW','y_g'].setlb(0.0)
    m.pwheel_g[n,'FW','y_g'].setlb(0.0)

# %%
# biped - bound variables
for n in range(1,N+1):  
    m.q[n,'thb'].setlb(np.pi/4)
    m.q[n,'thb'].setub(np.pi-np.pi/4)
    m.q[n,'thp'].setlb(-np.pi/2)
    m.q[n,'thp'].setub(np.pi/2)
    m.q[n,'thl_l'].setlb(-np.pi/2)
    m.q[n,'thl_l'].setub(np.pi/2)
    m.q[n,'thl_r'].setlb(-np.pi/2)
    m.q[n,'thl_r'].setub(np.pi/2)
    #m.GRFbf[n,'Y'].setlb(0.0)

# biped 
m.pfoot = Var(m.N, m.Fs, m.WDOF) # foot position
m.pfoot_b = Var(m.N, m.Fs, m.DOF_b) # foot position in skateboard frame
m.vfoot_b = Var(m.N, m.Fs, m.DOF_b, m.sgn, bounds = (0.0,None)) # foot velocity

for n in range(1,N+1):  
    m.pfoot[n,'BF','Y'].setlb(0.0)
    m.pfoot_b[n,'BF','y_b'].setlb(0.0)
    m.pfoot_b[n,'BF','x_b'].setub(0.0)
    m.pfoot_b[n,'BF','x_b'].setlb(-0.5*m.lbd)
    m.pfoot[n,'FF','Y'].setlb(0.0)
    m.pfoot_b[n,'FF','y_b'].setlb(0.0)
    m.pfoot_b[n,'FF','x_b'].setlb(0.0)
    m.pfoot_b[n,'FF','x_b'].setub(0.5*m.lbd)

def def_pfoot(m,n,fs,dof):
    # world frame
    if fs == 'BF':
        var_list = [m.len[('pelvis',1)], m.len[('left_leg',1)],m.len[('left_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_l'], m.q[n,'r_l']]
        if dof == 'X':
            return m.pfoot[n,'BF','X'] == lambfootx_l(*var_list)
        if dof == 'Y':
            return m.pfoot[n,'BF','Y'] == lambfooty_l(*var_list)
        else:
            return Constraint.Skip
    if fs == 'FF':
        var_list = [m.len[('pelvis',1)], m.len[('right_leg',1)],m.len[('right_leg',2)],
                        m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_r'], m.q[n,'r_r']]
        if dof == 'X':
            return m.pfoot[n,'FF','X'] == lambfootx_r(*var_list)
        if dof == 'Y':
            return m.pfoot[n,'FF','Y'] == lambfooty_r(*var_list)
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_pfoot = Constraint(m.N, m.Fs, m.WDOF, rule = def_pfoot)    
    
def def_pfoot_b(m,n,fs,dof): # board frame
    if fs == 'BF':
        var_list = [m.len[('pelvis',1)],m.len[('left_leg',1)],m.len[('left_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_l'], m.q[n,'r_l']]
        if dof == 'x_b':
            return m.pfoot_b[n,'BF','x_b'] == lambfootx_l_board(*var_list)
        if dof == 'y_b':
            return m.pfoot_b[n,'BF','y_b'] == lambfooty_l_board(*var_list)
        else:
            return Constraint.Skip
    if fs == 'FF':
        var_list = [m.len[('pelvis',1)], m.len[('right_leg',1)],m.len[('right_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_r'], m.q[n,'r_r']]
        if dof == 'x_b':
            return m.pfoot_b[n,'FF','x_b'] == lambfootx_r_board(*var_list)
        if dof == 'y_b':
            return m.pfoot_b[n,'FF','y_b'] == lambfooty_r_board(*var_list)
        else:
            return Constraint.Skip
m.def_pfoot_b = Constraint(m.N, m.Fs, m.DOF_b, rule = def_pfoot_b)      

def def_vfoot_b(m,n,fs,dof): # board frame
    if fs == 'BF':
        var_list = [m.len[('pelvis',1)], m.len[('left_leg',1)],m.len[('left_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_l'], m.q[n,'r_l'],
                    m.dq[n,'x'], m.dq[n,'y'], m.dq[n,'th'], m.dq[n,'xp'], m.dq[n,'yp'], m.dq[n,'thp'], m.dq[n,'thl_l'], m.dq[n,'r_l']]
        if dof == 'x_b':
            return m.vfoot_b[n,'BF','x_b','ps'] - m.vfoot_b[n,'BF','x_b','ng'] == lambvfootx_l_board(*var_list)
        else:
            return Constraint.Skip
    if fs == 'FF':
        var_list = [m.len[('pelvis',1)], m.len[('right_leg',1)],m.len[('right_leg',2)],
                    m.q[n,'x'], m.q[n,'y'], m.q[n,'th'], m.q[n,'xp'], m.q[n,'yp'], m.q[n,'thp'], m.q[n,'thl_r'], m.q[n,'r_r'],
                    m.dq[n,'x'], m.dq[n,'y'], m.dq[n,'th'], m.dq[n,'xp'], m.dq[n,'yp'], m.dq[n,'thp'], m.dq[n,'thl_r'], m.dq[n,'r_r']]
        if dof == 'x_b':
            return m.vfoot_b[n,'FF','x_b','ps'] - m.vfoot_b[n,'FF','x_b','ng'] == lambvfootx_r_board(*var_list)
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_vfoot_b = Constraint(m.N, m.Fs, m.DOF_b, rule = def_vfoot_b)

def def_Fb_b_total(m,n,fs,dof):
    if fs == 'BF':
        if dof == 'x_b':
            return m.Fb_b_total[n,'BF','x_b'] == m.Fb_b[n,'BF','x_b','ps']-m.Fb_b[n,'BF','x_b','ng']
        if dof == 'y_b':
            return m.Fb_b_total[n,'BF','y_b'] == m.Fb_b[n,'BF','y_b','ps']
        else:
            return Constraint.Skip
    if fs == 'FF':
        if dof == 'x_b':
            return m.Fb_b_total[n,'FF','x_b'] == m.Fb_b[n,'FF','x_b','ps']-m.Fb_b[n,'FF','x_b','ng']
        if dof == 'y_b':
            return m.Fb_b_total[n,'FF','y_b'] == m.Fb_b[n,'FF','y_b','ps']
    else:
        return Constraint.Skip
m.def_Fb_b_total = Constraint(m.N, m.Fs, m.DOF_b, rule = def_Fb_b_total) 

# Constraints for foot and board contact --------------------------------------------------------------------------------------

m.rF = Var(m.N, m.Fs) # distance to applied force

def def_rF(m,n,fs): # contact point on board
    if fs == 'BF':
        return m.rF[n,'BF'] == -m.pfoot_b[n,'BF','x_b']
    if fs == 'FF':
        return m.rF[n,'FF'] == m.pfoot_b[n,'FF','x_b']
    else:
        return Constraint.Skip
m.def_rF = Constraint(m.N, m.Fs, rule = def_rF)

# %%
# TIME AND INTEGRATION --------------------------------------------------------------------------------------------------------

# variable timestep
hm  = 0.01 #master timestep
m.h = Var(m.N, bounds = (0.8,1.2))

# Integration constraints 
def BwEuler_p(m,n,dof): # for positions
    if n > 1:
        return m.q[n,dof] == m.q[n-1,dof] + hm*m.h[n]*m.dq[n,dof]
    else:
        return Constraint.Skip 
m.integrate_p = Constraint(m.N, m.DOF, rule = BwEuler_p)

def BwEuler_v(m,n,dof): # for velocities
    if n > 1:
        if n==N1 and dof == 'y':
            return m.dq[n,'y'] == m.etail*m.vtail[n-1,'Y'] +  m.dq[n-1,'y'] + hm*m.h[n]*m.ddq[n-1,'y'] #switching constraint at impact of tail and ground
        else:    
            return m.dq[n,dof] == m.dq[n-1,dof] + hm*m.h[n]*m.ddq[n-1,dof]
    else:
        return Constraint.Skip 
m.integrate_v = Constraint(m.N, m.DOF, rule = BwEuler_v)

m.h[1].fix(0.0) # fix un-used time step

# %%
# AUXILIARY TO RESOLVE FOOT AND BOARD FORCES
# The back and front foot applied forces on the board, and the applied force of the monopod are in their own frames
# Need to transform them into the global frame.

m.F = Var(m.N, m.Bodies, m.Fs, m.WDOF) # Forces, global frame
m.thA = Var(m.N, m.Legs) # absolute angle of monopod

def def_thA(m,n,leg):
    if leg == 'BL':
        return m.thA[n, 'BL'] == m.q[n,'thp'] + m.q[n,'thl_l']
    if leg == 'FL':
        return m.thA[n, 'FL'] == m.q[n,'thp'] + m.q[n,'thl_r']
    else:
        return Constraint.Skip
m.def_thA = Constraint(m.N, m.Legs, rule = def_thA)

def def_F(m,n,body,fs,dof):
    if fs == 'BF':
        if body == 'BL':
            if dof == 'X':
                return m.F[n,'BL','BF','X'] == m.GRFbf[n,'BF','X']
            if dof == 'Y':
                return m.F[n,'BL','BF','Y'] == m.GRFbf[n,'BF','Y']
            else:
                return Constraint.Skip
        if body == 'board':
            if dof == 'X':
                return m.F[n,'board','BF','X'] == m.Fb_b_total[n,'BF','x_b']*cos(m.q[n,'th']) + m.Fb_b_total[n,'BF','y_b']*sin(m.q[n,'th'])
            if dof == 'Y':
                return m.F[n,'board','BF','Y'] == m.Fb_b_total[n,'BF','x_b']*sin(m.q[n,'th']) - m.Fb_b_total[n,'BF','y_b']*cos(m.q[n,'th'])
            else:
                return Constraint.Skip
        else:
            return Constraint.Skip
    if fs == 'FF':
        if body == 'FL':
            if dof == 'X':
                return m.F[n,'FL','FF','X'] == m.GRFbf[n,'FF','X']
            if dof == 'Y':
                return m.F[n,'FL','FF','Y'] == m.GRFbf[n,'FF','Y'] 
            else:
                return Constraint.Skip
        if body == 'board':
            if dof == 'X':
                return m.F[n,'board','FF','X'] == m.Fb_b_total[n,'FF','x_b']*cos(m.q[n,'th']) + m.Fb_b_total[n,'FF','y_b']*sin(m.q[n,'th'])
            if dof == 'Y':
                return m.F[n,'board','FF','Y'] == m.Fb_b_total[n,'FF','x_b']*sin(m.q[n,'th']) - m.Fb_b_total[n,'FF','y_b']*cos(m.q[n,'th'])
            else:
                return Constraint.Skip
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_F = Constraint(m.N, m.Bodies, m.Fs, m.WDOF, rule = def_F)

def def_contact_forces(m,n,fs,dof): # resolve into X and Y - global frame
    if fs == 'BF':
        if dof == 'X':
            return m.F[n,'BL','BF','X'] == -m.F[n,'board','BF','X']
        if dof == 'Y':
            return m.F[n,'BL','BF','Y'] == -m.F[n,'board','BF','Y']
        else:
            return Constraint.Skip
    if fs == 'FF':
        if dof == 'X':
            return m.F[n,'FL','FF','X'] == -m.F[n,'board','FF','X']
        if dof == 'Y':
            return m.F[n,'FL','FF','Y'] == -m.F[n,'board','FF','Y']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.def_contact_forces = Constraint(m.N, m.Fs, m.WDOF, rule = def_contact_forces)

# %%
# -----------------------------------------------------------------------------------------------------------------------------
# Contact Forces
# -----------------------------------------------------------------------------------------------------------------------------
# paramters
m.mu = Param(initialize = 0.78) # friction coefficient

ground_constraints = ['contact_BW','contact_FW','step_BW','step_FW','GRF_BW_penalty',
                      'GRF_FW_penalty','GRFs_BW_penalty','GRFs_FW_penalty']
m.ground_constraints = Set(initialize = ground_constraints) # set for indexing ground-related penalties
m.ground_penalty = Var(m.N, m.ground_constraints, bounds = (0.0,None))

contact_constraints = ['contact_Fy', 'friction','slip_x_ps','slip_x_ng','foot_velocity']
m.contact_constraints = Set(initialize = contact_constraints) # set for indexing ground-related penalties
m.contact_penalty = Var(m.N, m.Fs, m.contact_constraints, bounds = (0.0,None))

m.friction_cone = Var(m.N, m.Fs, bounds = (0.0,None))

# ground contact complemetarity  
def ground_contact(m,n,gc):
    if n < N: 
        if gc == 'contact_BW':
            return m.ground_penalty[n,'contact_BW'] == m.pwheel[n+1,'BW','Y']*m.GRF[n,'BW']
        if gc == 'contact_FW':
            return m.ground_penalty[n,'contact_FW'] == m.pwheel[n+1,'FW','Y']*m.GRF[n,'FW']
        if gc == 'step_BW':
            return m.ground_penalty[n,'step_BW'] == (m.pwheel[n+1,'BW','Y']-Y_step)*m.GRF_s[n,'BW']
        if gc == 'step_FW':
            return m.ground_penalty[n,'step_FW'] == (m.pwheel[n+1,'FW','Y']-Y_step)*m.GRF_s[n,'FW']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.ground_contact = Constraint(m.N, m.ground_constraints, rule = ground_contact)

# compliment GRF and GRF_s  
def GRF_penalty(m,n,gc):
    if n < N:
        if gc == 'GRF_BW_penalty':
            return m.ground_penalty[n,'GRF_BW_penalty']  == m.pwheel_sgn_g[n,'BW','x_g','ng']*m.GRF[n,'BW']
        if gc == 'GRFs_BW_penalty':
            return m.ground_penalty[n,'GRFs_BW_penalty'] == m.pwheel_sgn_g[n,'BW','x_g','ps']*m.GRF_s[n,'BW']
        if gc == 'GRF_FW_penalty':
            return m.ground_penalty[n,'GRF_FW_penalty']  == m.pwheel_sgn_g[n,'FW','x_g','ng']*m.GRF[n,'FW']
        if gc == 'GRFs_FW_penalty':
            return m.ground_penalty[n,'GRFs_FW_penalty'] == m.pwheel_sgn_g[n,'FW','x_g','ps']*m.GRF_s[n,'FW']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.GRF_penalty = Constraint(m.N,m.ground_constraints, rule = GRF_penalty)

# foot on board contact complemetarity  
def foot_board_contact(m,n,fs,cc):
    if n < N:
        if fs == 'BF':
            if cc == 'contact_Fy':
                return m.contact_penalty[n,'BF','contact_Fy'] == m.pfoot_b[n+1,'BF','y_b']*m.Fb_b[n,'BF','y_b','ps']
            else:
                return Constraint.Skip
        if fs == 'FF':
            if cc == 'contact_Fy':
                return m.contact_penalty[n,'FF','contact_Fy'] == m.pfoot_b[n+1,'FF','y_b']*m.Fb_b[n,'FF','y_b','ps']
            else:
                return Constraint.Skip
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.foot_board_contact = Constraint(m.N, m.Fs, m.contact_constraints, rule = foot_board_contact)

# Friction
def def_friction_cone(m,n,fs):
    if fs == 'BF':
        return m.friction_cone[n,'BF'] == m.mu*m.Fb_b[n,'BF','y_b','ps'] - (m.Fb_b[n,'BF','x_b','ps']+m.Fb_b[n,'BF','x_b','ng'])
    if fs == 'FF':
        return m.friction_cone[n,'FF'] == m.mu*m.Fb_b[n,'FF','y_b','ps'] - (m.Fb_b[n,'FF','x_b','ps']+m.Fb_b[n,'FF','x_b','ng'])
    else:
        return Constraint.Skip
m.def_friction_cone = Constraint(m.N, m.Fs, rule = def_friction_cone)

def board_friction(m,n,fs): # the foot can't move if not over max static friction, and no normal force means no friction force.
    if fs == 'BF':
        return m.contact_penalty[n,'BF','friction'] == (m.vfoot_b[n,'BF','x_b','ps']+m.vfoot_b[n,'BF','x_b','ng'])*m.friction_cone[n,'BF']
    if fs == 'FF':
        return m.contact_penalty[n,'FF','friction'] == (m.vfoot_b[n,'FF','x_b','ps']+m.vfoot_b[n,'FF','x_b','ng'])*m.friction_cone[n,'FF']
    else:
        return Constraint.Skip
m.board_friction = Constraint(m.N, m.Fs, rule = board_friction)

# slipping of foot on board
def board_slip(m,n,fs,cc): # the friction force must be applied in opposite direction to velocity of foot.
    if fs == 'BF':
        if cc == 'slip_x_ps':
            return m.contact_penalty[n,'BF','slip_x_ps'] == m.vfoot_b[n,'BF','x_b','ps']*m.Fb_b[n,'BF','x_b','ng']
        if cc == 'slip_x_ng':
            return m.contact_penalty[n,'BF','slip_x_ng'] == m.vfoot_b[n,'BF','x_b','ng']*m.Fb_b[n,'BF','x_b','ps']
        else:
            return Constraint.Skip
    if fs == 'FF':
        if cc == 'slip_x_ps':
            return m.contact_penalty[n,'FF','slip_x_ps'] == m.vfoot_b[n,'FF','x_b','ps']*m.Fb_b[n,'FF','x_b','ng']
        if cc == 'slip_x_ng':
            return m.contact_penalty[n,'FF','slip_x_ng'] == m.vfoot_b[n,'FF','x_b','ng']*m.Fb_b[n,'FF','x_b','ps']
        else:
            return Constraint.Skip
    else:
        return Constraint.Skip
m.board_slip = Constraint(m.N, m.Fs, m.contact_constraints, rule = board_slip)

# foot velocity - only vf+ or vf- must be non-zero, not both.
def vfoot_b_penalty(m,n,fs):
    if fs == 'BF':
        return m.contact_penalty[n,'BF','foot_velocity'] == m.vfoot_b[n,'BF','x_b','ps']*m.vfoot_b[n,'BF','x_b','ng']
    if fs == 'FF':
        return m.contact_penalty[n,'FF','foot_velocity'] == m.vfoot_b[n,'FF','x_b','ps']*m.vfoot_b[n,'FF','x_b','ng']
    else:
        return Constraint.Skip
m.vfoot_b_penalty = Constraint(m.N, m.Fs, rule = vfoot_b_penalty)

for leg in legs:
    m.tau_a[N,leg].fix(0.0)
    m.tau_b[N].fix(0.0)
for grf in GRFs:
    m.GRF[N, grf].fix(0.0)
    m.GRF_s[N, grf].fix(0.0)
for fs in Fs:
    for dof in DOF_b:
        for sgn in signs:
            m.Fb_b[N, fs, dof, sgn].fix(0.0)
    for cc in contact_constraints:
        m.contact_penalty[N, fs, cc].fix(0.0)
for gnd in ground_constraints:
    m.ground_penalty[N, gnd].fix(0.0)

# %%
# Reaction force at knee

# sets
joints = ['knee']
m.J = Set(initialize = joints)

joint_constraints = ['up','lo'] # set of joint penalties
m.joint_constraints = Set(initialize = joint_constraints)

knee_bound = [0.0,hr_max]
m.knee_bound = Param(m.joint_constraints, initialize = {'up':knee_bound[1],'lo':knee_bound[0]})

# we can bound the joint coordinates directly
for n in range(1,N+1):
    m.q[n,'r_l'].setlb(knee_bound[0])
    m.q[n,'r_l'].setub(knee_bound[1])
    m.q[n,'r_r'].setlb(knee_bound[0])
    m.q[n,'r_r'].setub(knee_bound[1])
    
m.joint_penalty = Var(m.N, m.Legs, m.J, m.joint_constraints, bounds = (0.0,None))

def knee_limits(m,n,leg,jc):
    if n < N:
        if leg == 'BL':
            if jc == 'up':
                # NEXT distance
                return m.joint_penalty[n,'BL','knee',jc] == (m.knee_bound['up'] - m.q[n+1,'r_l'])*m.F_r[n,'BL','ng']
            else: # jc =='low'
                return m.joint_penalty[n,'BL','knee',jc] == (m.q[n+1,'r_l'] - m.knee_bound['lo'])*m.F_r[n,'BL','ps']
        if leg == 'FL':
            if jc == 'up':
                # NEXT distance
                return m.joint_penalty[n,'FL','knee',jc] == (m.knee_bound['up'] - m.q[n+1,'r_r'])*m.F_r[n,'FL','ng']
            else: # jc =='low'
                return m.joint_penalty[n,'FL','knee',jc] == (m.q[n+1,'r_r'] - m.knee_bound['lo'])*m.F_r[n,'FL','ps']
        else: 
            return Constraint.Skip
    else:
        return Constraint.Skip
m.knee_limits = Constraint(m.N, m.Legs, m.joint_constraints, rule = knee_limits)

# bound contact forces at last node
for sgn in signs:
    for leg in legs:
        m.F_r[N,leg,sgn].fix(0.0)
    
for jc in joint_constraints:
    for leg in legs:
        for j in joints:
            m.joint_penalty[N,leg,j,jc].fix(0.0)

# %%
# EOMs --------------------------------------------------------------------------------------------------------------------------

skaterlib_biped_with_body_new.define_EOMs(m,BW,lambEOMx_board,lambEOMy_board,lambEOMth_board,lambEOMxp_biped,lambEOMyp_biped,
                            lambEOMthp_biped,lambEOMthb_biped,lambEOMthll_biped,lambEOMthlr_biped,lambEOMrl_biped,lambEOMrr_biped)

# %%
# COST FUNCTION ---------------------------------------------------------------------------------------------------------------

# New cost function
# minimum force and penalties
def CostFun(m):
    penalty_sum = 0
    force_sum = 0
    torque_sum = 0
    for n in range(1,N+1):
        for gc in ground_constraints:
            penalty_sum += 10*m.ground_penalty[n,gc]
        for gfc in ground_func_constraints:
            penalty_sum += 10*m.ground_func_penalty[n,gfc]
        for cc in contact_constraints:
            for fs in Fs:
                penalty_sum += m.contact_penalty[n,fs,cc]
        for jc in joint_constraints:
            for leg in legs:
                for j in joints:
                    penalty_sum += m.joint_penalty[n,leg,j,jc]
        
        force_sum  += (m.F_a[n,'BL']**2 + m.F_a[n,'FL']**2)*hm*m.h[n]
        torque_sum += (m.tau_a[n,'BL']**2 + m.tau_a[n,'FL']**2 + m.tau_b[n]**2)*hm*m.h[n]
#     return penalty_sum
    return force_sum + torque_sum + 1000*penalty_sum

m.Cost = Objective(rule = CostFun)

# %%
# ROLL TOWARDS RAMP
m.pwheel[1,'BW','X'].fix(0.0)
m.pwheel_g[1,'BW','y_g'].fix(0.0)
m.q[1,'th'].fix(0.0)

m.pfoot_b[1,'BF','x_b'].setub(-0.5*m.lbrd)
m.pfoot_b[1,'BF','y_b'].fix(0.0)
m.pfoot_b[1,'FF','y_b'].fix(0.0)

m.q[1,'thp'].fix(0.0)
m.q[1,'thb'].fix(np.pi/2)
m.q[1,'thl_l'].fix(0.0)
m.q[1,'thl_r'].fix(0.0)

# both
for dof in DOFs:
    m.dq[1,dof].fix(0.0)
m.dq[1,'x'].fixed = False
m.dq[1,'xp'].fixed = False

m.dq[1,'x'].setub(5.0)
m.dq[1,'xp'].setub(5.0)

# the "POP"
m.ptail_g[N1-1,'y_g'].fix(0.0)
m.pwheel[N1-1,'BW','X'].setub(X_step-0.01)
print("N>=N1-1, N =", N)

if N>=Nhw:
    # the apex
    m.pwheel_g[Nhw,'BW','y_g'].setlb(0.5)
    m.pwheel_g[Nhw,'FW','y_g'].setlb(0.5)
#     m.pwheel[Nhw,'FW','X'].fix(X_step)
    print("N>=Nhw, N =", N)

# Landing
m.pwheel_g[N3,'BW','y_g'].fix(0.0)
m.pwheel_g[N3,'FW','y_g'].fix(0.0)
m.pfoot_b[N3,'BF','x_b'].fix(-0.5*m.lbrd)
m.pfoot_b[N3,'FF','x_b'].fix(0.5*m.lbrd)
m.pfoot_b[N3,'BF','y_b'].fix(0.0)
m.pfoot_b[N3,'FF','y_b'].fix(0.0)
m.pwheel[N3,'BW','X'].setlb(X_step)

# Final Conditions - standing
m.pwheel_g[N,'BW','y_g'].fix(0.0)
m.pwheel_g[N,'FW','y_g'].fix(0.0)
m.q[N,'thp'].fix(0.0)
m.q[N,'thb'].fix(np.pi/2)
m.q[N,'thl_l'].fix(0.0)
#     m.q[N,'thl_r'].fix(0.0)
m.pfoot_b[N,'BF','x_b'].fix(-0.5*m.lbrd)
m.pfoot_b[N,'FF','x_b'].fix(0.5*m.lbrd)
m.pfoot_b[N,'BF','y_b'].fix(0.0)
m.pfoot_b[N,'FF','y_b'].fix(0.0)

m.dq[N,'thl_l'].fix(0.0)
m.dq[N,'thl_r'].fix(0.0)
m.dq[N,'thp'].fix(0.0)
m.dq[N,'thb'].fix(0.0)
m.dq[N,'r_l'].fix(0.0)
m.dq[N,'r_r'].fix(0.0)    

m.pwheel[N,'BW','X'].setlb(2.0) 

if 'm_saved' in globals():
    print("Loading previous model:", model, "results as initialization.")
    N_saved = m_saved.N.bounds()[1]
    if N_saved > N: N_count = N
    else: N_count = N_saved
    for n in range(1,N_count+1):
        
        for dof in DOFs:
            if not m.q[n,dof].fixed:
                m.q[n,dof] = m_saved.q[n,dof].value
            if not m.dq[n,dof].fixed:
                m.dq[n,dof] = m_saved.dq[n,dof].value
        
        for leg in legs:
            if not m.F_a[n,leg].fixed:
                m.F_a[n,leg] = m_saved.F_a[n,leg].value
            if not m.tau_a[n,leg].fixed:
                m.tau_a[n,leg] = m_saved.tau_a[n,leg].value
        
        m.tau_b[n] = m_saved.tau_b[n].value
        
        for fs in Fs:
            for dof in DOF_b:
                for sgn in signs:
                    if (not m.Fb_b[n,fs,dof,sgn].fixed) and (m_saved.Fb_b[n,fs,dof,sgn].value is not None):
                        m.Fb_b[n,fs,dof,sgn] = m_saved.Fb_b[n,fs,dof,sgn].value
                
        for grf in GRFs:
            if (not m.GRF[n, grf].fixed) and (m_saved.GRF[n, grf].value is not None):
                m.GRF[n, grf] = m_saved.GRF[n, grf].value
            if (not m.GRF_s[n, grf].fixed) and (m_saved.GRF_s[n, grf].value is not None):
                m.GRF_s[n, grf] = m_saved.GRF_s[n, grf].value
        
        m.h[n] = m_saved.h[n].value
    
# for i in range(1,N+1):
#     m.F_a[i,'BL'].fix(0.0)
#     m.F_a[i,'FL'].fix(0.0)
#     m.tau_a[i,'BL'].fix(0.0)
#     m.tau_a[i,'FL'].fix(0.0)
#     m.tau_b[i].fix(0.0)

# eps = 1e-6
# for n in range(1,N+1):
#     for gc in ground_constraints:
#         m.ground_penalty[n,gc].setub(eps)
#     for gfc in ground_func_constraints:
#         m.ground_func_penalty[n,gfc].setub(eps)
#     for cc in contact_constraints:
#         for fs in Fs:
#             m.contact_penalty[n,fs,cc].setub(eps)
#     for jc in joint_constraints:
#         for leg in legs:
#             for j in joints:
#                 m.joint_penalty[n,leg,j,jc].setub(eps)
# Out:
# N>=N1-1, N = 65
# N>=Nhw, N = 65
# Loading previous model: model_biped_OD_N65_03_10_2019_14_31.pkl results as initialization.

# %%
# # PATH CONSTRAINTS
# m.pwheel[1,'BW','X'].fix(0.0)
# m.pwheel_g[1,'BW','y_g'].fix(0.0)
# m.q[1,'th'].fix(0.0)

# m.pfoot_b[1,'BF','x_b'].setub(-0.5*m.lbrd)
# m.pfoot_b[1,'BF','y_b'].fix(0.0)
# m.pfoot_b[1,'FF','y_b'].fix(0.0)

# m.q[1,'thp'].fix(0.0)
# m.q[1,'thb'].fix(np.pi/2)
# m.q[1,'thl_l'].fix(0.0)
# m.q[1,'thl_r'].fix(0.0)

# # both
# for dof in DOFs:
#     m.dq[1,dof].fix(0.0)
# m.dq[1,'x'].fixed = False
# m.dq[1,'xp'].fixed = False

# if N>=N1-1:
#     # the "POP"
#     m.pwheel[N1-1,'BW','X'].setub(X_step-0.05)
#     m.ptail_g[N1-1,'y_g'].fix(0.0)
#     print("N>=N1-1, N =", N)

# if N>=Nhw:
#     # the apex
#     m.pwheel[Nhw,'BW','Y'].setlb(0.5)
#     m.pwheel[Nhw,'FW','Y'].setlb(0.5)
# #     m.pwheel[Nhw,'BW','X'].setlb(1.0)
#     print("N>=Nhw, N =", N)   

# if N>=N2:
#     # board landing
#     m.pwheel_g[N2,'BW','y_g'].fix(0.0)
#     m.pwheel_g[N2,'FW','y_g'].fix(0.0)
#     print("N>=N2, N =", N)    

# if N>=N3:
#     # board and biped landing
#     m.pwheel_g[N3,'BW','y_g'].fix(0.0)
#     m.pwheel_g[N3,'FW','y_g'].fix(0.0)
# #     m.q[N3,'thp'].fix(0.0)
# #     m.q[N3,'thb'].fix(np.pi/2)
# #     m.q[N3,'thl_l'].fix(0.0)
# #     m.q[N3,'thl_r'].fix(0.0)
#     m.pfoot_b[N3,'BF','x_b'].fix(-0.5*m.lbrd)
#     m.pfoot_b[N3,'FF','x_b'].fix(0.5*m.lbrd)
#     m.pfoot_b[N3,'BF','y_b'].fix(0.0)
#     m.pfoot_b[N3,'FF','y_b'].fix(0.0)
#     print("N>=N3, N =",N)
    
# if N==N4:
#     # Final Conditions - standing
#     m.pwheel_g[N,'BW','y_g'].fix(0.0)
#     m.pwheel_g[N,'FW','y_g'].fix(0.0)
#     m.q[N,'thp'].fix(0.0)
#     m.q[N,'thb'].fix(np.pi/2)
#     m.q[N,'thl_l'].fix(0.0)
# #     m.q[N,'thl_r'].fix(0.0)
#     m.pfoot_b[N,'BF','x_b'].fix(-0.5*m.lbrd)
#     m.pfoot_b[N,'FF','x_b'].fix(0.5*m.lbrd)
#     m.pfoot_b[N,'BF','y_b'].fix(0.0)
#     m.pfoot_b[N,'FF','y_b'].fix(0.0)

#     m.dq[N,'thl_l'].fix(0.0)
#     m.dq[N,'thl_r'].fix(0.0)
#     m.dq[N,'thp'].fix(0.0)
#     m.dq[N,'thb'].fix(0.0)
#     m.dq[N,'r_l'].fix(0.0)
#     m.dq[N,'r_r'].fix(0.0)    

#     m.pwheel[N,'BW','X'].setlb(2.0)  

# #INITIALIZE
# if 'm_saved' in globals():
#     print("Loading previous model:", model, "results as initialization.")
#     N_saved = m_saved.N.bounds()[1]
#     if N_saved > N: N_count = N
#     else: N_count = N_saved
#     for n in range(1,N_count+1):
        
#         for dof in DOFs:
#             if not m.q[n,dof].fixed:
#                 m.q[n,dof] = m_saved.q[n,dof].value
#             if not m.dq[n,dof].fixed:
#                 m.dq[n,dof] = m_saved.dq[n,dof].value
        
#         for leg in legs:
#             if not m.F_a[n,leg].fixed:
#                 m.F_a[n,leg] = m_saved.F_a[n,leg].value
#             if not m.tau_a[n,leg].fixed:
#                 m.tau_a[n,leg] = m_saved.tau_a[n,leg].value
        
#         m.tau_b[n] = m_saved.tau_b[n].value
        
#         for fs in Fs:
#             for dof in DOF_b:
#                 for sgn in signs:
#                     if (not m.Fb_b[n,fs,dof,sgn].fixed) and (m_saved.Fb_b[n,fs,dof,sgn].value is not None):
#                         m.Fb_b[n,fs,dof,sgn] = m_saved.Fb_b[n,fs,dof,sgn].value
                
#         for grf in GRFs:
#             if (not m.GRF[n, grf].fixed) and (m_saved.GRF[n, grf].value is not None):
#                 m.GRF[n, grf] = m_saved.GRF[n, grf].value
#             if (not m.GRF_s[n, grf].fixed) and (m_saved.GRF_s[n, grf].value is not None):
#                 m.GRF_s[n, grf] = m_saved.GRF_s[n, grf].value
        
#         m.h[n] = m_saved.h[n].value

# %%
# SOLVE --------------------------------------------------------------------------------------------------------------------  
t = time.time()
results = skaterlib_biped_with_body_new.solve(m, display_results = True, expect_infeasible = 'yes')
skaterlib_biped_with_body_new.print_results(m, N, hm, ground_constraints, contact_constraints, joint_constraints, ground_func_constraints, joints, Fs, legs)
print("Elapsed Time:", (time.time() - t)/60.0, "mins")
# Out:
# Ipopt 3.12.9: linear_solver=ma86
# expect_infeasible_problem=yes
# halt_on_ampl_error=yes
# print_level=5
# max_iter=100000
# max_cpu_time=1800
# Tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.9, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    33005
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    11768
#
# Total number of variables............................:     8435
#                      variables with only lower bounds:     3725
#                 variables with lower and upper bounds:     1089
#                      variables with only upper bounds:        2
# Total number of equality constraints.................:     6789
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.6159955e+04 3.79e+03 9.90e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.2142388e+04 3.76e+03 9.82e+01  -1.0 3.50e+03    -  1.09e-02 9.01e-03f  1
#    2  7.5928142e+04 3.68e+03 9.64e+01  -1.0 4.13e+03    -  1.65e-02 1.89e-02f  1
#    3  7.4482187e+04 3.66e+03 9.56e+01  -1.0 3.08e+03    -  8.04e-03 7.31e-03f  1
#    4  7.0843796e+04 3.57e+03 9.34e+01  -1.0 2.60e+03    -  3.43e-02 2.34e-02f  1
#    5  6.8689400e+04 3.36e+03 9.27e+01  -1.0 2.55e+03    -  1.73e-02 5.90e-02f  1
#    6  6.9047340e+04 3.13e+03 9.09e+01  -1.0 2.82e+03    -  3.93e-02 6.88e-02f  1
#    7  6.9267900e+04 2.93e+03 8.30e+01  -1.0 6.32e+03    -  7.75e-02 6.43e-02f  1
#    8  6.9655231e+04 2.86e+03 7.93e+01  -1.0 2.44e+02  -4.0 4.53e-02 2.49e-02h  1
#    9  7.0878344e+04 2.61e+03 7.32e+01  -1.0 3.59e+02  -4.5 7.67e-02 8.52e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.1875538e+04 2.35e+03 8.19e+01  -1.0 3.36e+02  -4.1 2.51e-02 1.00e-01f  1
#   11  7.2154440e+04 2.21e+03 8.51e+01  -1.0 2.12e+02  -3.6 3.62e-02 6.12e-02h  1
#   12  7.1892317e+04 2.17e+03 8.74e+01  -1.0 3.03e+03  -4.1 1.19e-02 1.78e-02f  1
#   13  7.1785894e+04 2.16e+03 6.62e+01  -1.0 4.13e+02  -3.7 4.97e-02 3.35e-03h  1
#   14  7.1229223e+04 2.07e+03 7.29e+01  -1.0 2.23e+02  -3.3 1.24e-02 4.11e-02f  1
#   15  7.0985425e+04 2.06e+03 6.68e+01  -1.0 8.02e+02  -3.7 1.92e-02 7.01e-03h  1
#   16  7.0166935e+04 1.99e+03 6.55e+01  -1.0 3.26e+02  -3.3 3.16e-02 3.35e-02f  1
#   17  6.9652237e+04 1.96e+03 6.19e+01  -1.0 1.52e+02  -2.9 4.73e-02 1.50e-02h  1
#   18  6.8963709e+04 1.93e+03 6.10e+01  -1.0 6.08e+02  -3.4 9.10e-03 1.20e-02f  1
#   19  6.7563052e+04 1.87e+03 6.15e+01  -1.0 1.61e+02  -2.9 9.60e-03 3.09e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  6.6448105e+04 1.80e+03 7.02e+01  -1.0 3.13e+01  -1.6 2.12e-02 3.83e-02f  1
#   21  6.5815655e+04 1.77e+03 7.24e+01  -1.0 5.46e+01  -2.1 5.79e-02 1.86e-02f  1
#   22  6.3626951e+04 1.65e+03 5.21e+01  -1.0 9.56e+01  -2.6 4.55e-02 6.78e-02f  1
#   23  6.3097698e+04 1.63e+03 7.96e+01  -1.0 1.26e+02  -3.0 4.80e-02 1.30e-02h  1
#   24  6.1265087e+04 1.52e+03 6.65e+01  -1.0 9.51e+01  -2.6 1.36e-02 6.61e-02f  1
#   25  5.9934580e+04 1.47e+03 5.75e+01  -1.0 2.93e+02  -3.1 4.04e-02 3.44e-02f  1
#   26  5.8628916e+04 1.42e+03 6.29e+01  -1.0 3.03e+02  -3.6 2.83e-02 3.41e-02f  1
#   27  5.8146177e+04 1.40e+03 8.72e+01  -1.0 6.00e+02  -3.1 2.77e-03 1.52e-02f  1
#   28  5.5596736e+04 1.30e+03 1.41e+02  -1.0 3.13e+02  -3.6 1.50e-01 6.94e-02f  1
#   29  5.4603920e+04 1.25e+03 8.40e+01  -1.0 2.49e+02  -3.2 5.73e-03 3.80e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  5.4486530e+04 1.24e+03 1.73e+02  -1.0 2.83e+02  -2.8 2.38e-02 4.26e-03h  1
#   31  5.3370184e+04 1.18e+03 8.87e+01  -1.0 1.17e+02  -2.3 2.20e-02 5.40e-02f  1
#   32  5.1956778e+04 1.11e+03 7.90e+01  -1.0 9.93e+01  -2.8 6.89e-02 6.15e-02f  1
#   33  5.1000730e+04 1.05e+03 5.51e+01  -1.0 7.42e+01  -2.4 6.23e-02 5.01e-02h  1
#   34  4.9632639e+04 9.78e+02 6.56e+01  -1.0 9.27e+01  -2.9 4.53e-02 6.83e-02f  1
#   35  4.6436069e+04 7.87e+02 1.11e+02  -1.0 3.67e+01  -2.4 8.95e-02 1.96e-01f  1
#   36  4.5890874e+04 7.62e+02 1.10e+02  -1.0 2.43e+02  -2.9 2.21e-02 3.08e-02h  1
#   37  4.5093496e+04 7.08e+02 1.13e+02  -1.0 5.25e+01  -2.5 3.42e-02 7.10e-02h  1
#   38  4.4134844e+04 6.39e+02 1.06e+02  -1.0 6.78e+01  -2.1 8.60e-02 9.83e-02f  1
#   39  4.2426331e+04 5.12e+02 1.15e+02  -1.0 2.86e+01  -1.6 7.91e-02 1.98e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  4.2375266e+04 5.11e+02 1.12e+02  -1.0 8.13e+02  -2.1 4.15e-03 1.16e-03h  1
#   41  4.1777851e+04 4.74e+02 2.29e+02  -1.0 1.31e+01  -1.7 2.45e-01 7.40e-02h  1
#   42  4.0040766e+04 3.67e+02 1.45e+02  -1.0 3.08e+01  -2.2 1.71e-01 2.26e-01f  1
#   43  3.9189925e+04 3.38e+02 1.31e+02  -1.0 6.85e+01  -2.6 6.93e-02 7.79e-02h  1
#   44  3.7502051e+04 2.62e+02 1.17e+02  -1.0 2.93e+01  -2.2 3.00e-01 2.24e-01h  1
#   45  3.5197213e+04 1.86e+02 8.99e+01  -1.0 4.16e+01  -2.7 1.67e-01 2.91e-01f  1
#   46  3.4493014e+04 1.57e+02 7.51e+01  -1.0 1.19e+01  -2.3 1.49e-01 1.59e-01h  1
#   47  3.2611526e+04 1.01e+02 4.82e+01  -1.0 2.68e+01  -2.7 4.05e-01 3.58e-01f  1
#   48  3.1597666e+04 7.93e+01 4.21e+02  -1.0 5.85e+01  -3.2 1.07e-01 2.11e-01f  1
#   49  3.1344204e+04 6.45e+01 3.99e+02  -1.0 1.30e+00  -0.1 1.57e-01 1.87e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  3.1195992e+04 5.04e+01 3.19e+02  -1.0 1.30e+00   0.3 2.53e-01 2.18e-01h  1
#   51  3.1186579e+04 4.76e+01 2.84e+02  -1.0 1.55e+00  -0.1 2.44e-01 5.63e-02h  1
#   52  3.1184567e+04 4.59e+01 5.06e+03  -1.0 1.02e+01  -0.6 2.52e-01 3.63e-02h  1
#   53  3.1178166e+04 3.02e+01 4.45e+03  -1.0 1.33e+01  -1.1 5.67e-01 3.41e-01h  1
#   54  3.1448589e+04 2.65e+01 3.42e+03  -1.0 4.48e+00   0.2 1.14e-01 1.21e-01h  1
#   55  3.1932821e+04 2.05e+01 5.66e+03  -1.0 6.96e+00  -0.2 3.38e-01 2.27e-01h  1
#   56  3.2182663e+04 1.57e+01 4.03e+03  -1.0 9.27e+00  -0.7 3.13e-01 2.33e-01h  1
#   57  3.2564271e+04 1.28e+01 3.29e+03  -1.0 6.46e+00  -0.3 1.88e-01 1.87e-01h  1
#   58  3.2590185e+04 1.21e+01 4.98e+04  -1.0 1.66e-01   1.9 3.64e-01 5.06e-02h  1
#   59  3.2763206e+04 8.46e+00 3.40e+04  -1.0 4.76e-01   1.5 2.96e-01 3.04e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  3.7415634e+04 3.75e+00 2.59e+04  -1.0 1.57e+00   1.0 2.37e-02 5.57e-01h  1
#   61  3.8149073e+04 9.73e-01 3.74e+04  -1.0 1.18e-01   2.3 1.00e+00 7.40e-01h  1
#   62  3.3059755e+04 3.61e-01 1.06e+04  -1.0 6.14e-01   1.8 4.20e-01 6.29e-01f  1
#   63  3.2999350e+04 3.44e-01 3.16e+04  -1.0 2.18e+00   1.4 3.39e-01 4.80e-02h  1
#   64  3.2970089e+04 2.67e-01 1.97e+04  -1.0 6.06e+00   0.9 1.62e-01 2.25e-01h  1
#   65  3.2884653e+04 2.35e-01 2.13e+04  -1.0 1.72e+01   0.4 2.22e-01 1.20e-01H  1
#   66  3.2903882e+04 2.34e-01 1.93e+04  -1.0 8.58e+01  -0.1 1.96e-02 2.81e-03f  4
#   67  3.2965675e+04 2.47e-01 2.74e+04  -1.0 1.88e+01   0.4 4.53e-01 6.06e-02h  3
#   68  3.3021027e+04 2.67e-01 3.86e+04  -1.0 1.06e+02  -0.1 1.43e-02 3.92e-03f  3
#   69  3.3134713e+04 2.90e-01 4.05e+04  -1.0 2.09e+01   0.3 2.54e-01 6.16e-02h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  3.3209873e+04 2.74e-01 6.17e+04  -1.0 8.18e+00   0.7 1.00e+00 1.06e-01h  1
#   71  3.3295687e+04 2.80e-01 5.90e+04  -1.0 2.39e+01   0.3 4.38e-02 2.90e-02h  3
#   72  3.3279664e+04 2.37e-01 7.24e+04  -1.0 1.28e+00   1.6 7.51e-01 1.55e-01h  1
#   73  3.3284104e+04 2.31e-01 7.67e+04  -1.0 3.82e+00   1.1 6.20e-01 2.87e-02h  5
#   74  3.3496414e+04 3.09e-01 5.47e+04  -1.0 1.07e+01   0.6 3.11e-01 2.83e-01H  1
#   75  3.3510729e+04 2.99e-01 6.06e+04  -1.0 4.29e+00   1.1 7.71e-01 3.53e-02f  5
#   76  3.3645255e+04 5.24e-02 9.35e+03  -1.0 1.66e+00   1.5 4.39e-01 1.00e+00h  1
#   77  3.3693167e+04 5.89e-02 2.99e+03  -1.0 5.31e+00   1.0 4.67e-01 4.21e-01H  1
#   78  3.3694317e+04 5.53e-02 6.02e+04  -1.0 2.72e-01   2.3 1.00e+00 6.25e-02h  5
#   79  3.3751102e+04 1.34e-02 1.12e+03  -1.0 8.14e-01   1.9 7.33e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  3.3944268e+04 7.00e-03 2.39e+04  -1.0 2.60e+00   1.4 1.00e+00 8.32e-01H  1
#   81  3.3949699e+04 7.02e-03 1.96e+04  -1.0 8.72e+00   0.9 2.42e-01 5.72e-03h  7
#   82  3.3982685e+04 8.91e-03 2.05e+04  -1.0 3.56e+01   0.4 2.57e-03 1.09e-02f  5
#   83  3.3986532e+04 8.91e-03 1.84e+04  -1.0 1.04e+01   0.9 8.98e-02 4.36e-03h  8
#   84  3.3971471e+04 8.87e-03 1.86e+04  -1.0 9.98e+01   0.4 7.53e-04 1.48e-03f  6
#   85  3.3970544e+04 9.28e-03 1.62e+04  -1.0 1.26e+01   0.8 8.18e-02 1.72e-02f  6
#   86r 3.3970544e+04 9.28e-03 1.00e+03  -1.0 0.00e+00   0.3 0.00e+00 1.68e-03R  1
#   87r 3.4405608e+04 2.69e-03 1.14e+03  -1.0 9.78e+00    -  5.78e-01 1.73e-02f  1
#   88r 7.0513083e+04 1.62e+00 8.60e+02  -1.0 1.37e+01    -  4.38e-01 6.28e-01f  1
#   89r 1.3957005e+05 1.81e+00 7.17e+02  -1.0 6.46e+00    -  2.75e-01 8.37e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90r 1.7382706e+05 1.41e-02 2.48e+02  -1.0 9.91e-02   2.0 6.15e-01 1.00e+00f  1
#   91r 2.3173387e+05 1.58e-02 8.81e+01  -1.0 6.26e-02   1.5 7.86e-01 1.00e+00f  1
#   92r 3.2418415e+05 3.69e-02 2.36e+02  -1.0 1.44e-01   1.0 4.96e-01 7.62e-01f  1
#   93r 3.8434571e+05 2.12e-01 1.97e+02  -1.0 2.65e+01    -  2.37e-01 1.93e-01f  1
#   94r 3.9295378e+05 3.50e-01 1.93e+02  -1.0 1.05e+02    -  2.39e-02 2.09e-02f  1
#   95r 4.4265888e+05 1.37e+00 1.72e+02  -1.0 4.05e+01    -  5.49e-03 1.15e-01f  1
#   96r 4.4753967e+05 2.15e+00 1.70e+02  -1.0 3.58e+02    -  2.26e-04 1.17e-02f  1
#   97r 4.4756884e+05 3.08e+00 1.70e+02  -1.0 1.99e+05    -  2.11e-07 2.08e-05f  1
#   98r 4.7727083e+05 2.62e+00 2.51e+02  -1.0 5.78e-01   0.6 4.26e-01 1.53e-01f  1
#   99r 4.9029535e+05 2.59e+00 1.59e+02  -1.0 8.94e+01    -  7.37e-03 1.49e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100r 7.9663978e+05 1.42e+00 5.90e+02  -1.0 8.15e+00    -  1.08e-01 6.13e-01f  1
#  101r 8.4374644e+05 1.14e+00 5.14e+02  -1.0 3.27e-01   0.1 8.81e-02 2.02e-01f  1
#  102r 8.9836627e+05 9.57e-01 4.28e+02  -1.0 7.24e-01  -0.4 2.66e-01 1.74e-01f  1
#  103r 1.0453832e+06 1.22e+00 2.29e+02  -1.0 1.10e+01    -  4.37e-01 4.62e-01f  1
#  104r 1.2091506e+06 1.35e+00 1.08e+02  -1.0 5.61e+00    -  4.90e-01 5.27e-01f  1
#  105r 1.3702939e+06 5.84e-01 1.11e+02  -1.0 5.10e+00    -  4.54e-01 7.12e-01f  1
#  106r 1.4320115e+06 1.19e-01 1.50e+02  -1.0 2.28e-01  -0.9 6.12e-01 7.96e-01f  1
#  107r 1.4368238e+06 7.35e-02 9.05e+01  -1.0 1.83e-01   0.5 3.75e-01 3.85e-01f  1
#  108r 1.4393108e+06 7.61e-02 1.35e+02  -1.0 1.86e+01    -  4.94e-02 8.02e-02f  1
#  109r 1.4799079e+06 6.22e-01 1.79e+02  -1.0 4.26e+00    -  5.36e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110r 1.4820587e+06 3.60e-01 1.80e+02  -1.0 1.25e-01  -0.0 6.94e-01 4.21e-01f  1
#  111r 1.4879380e+06 7.48e-02 5.41e+02  -1.0 2.62e-01  -0.5 2.97e-01 1.00e+00f  1
#  112r 1.4900137e+06 2.37e-02 1.70e+02  -1.0 5.60e-01  -0.1 4.00e-01 6.49e-01h  1
#  113r 1.4901521e+06 2.03e-02 3.15e+02  -1.0 1.87e+01    -  4.51e-02 2.23e-02f  1
#  114r 1.4944866e+06 2.80e-03 3.01e+02  -1.0 4.07e-01   0.4 1.43e-01 1.00e+00F  1
#  115r 1.4957705e+06 2.89e-02 1.93e+02  -1.0 7.43e-01  -0.1 2.08e-01 3.46e-01f  2
#  116r 1.4931694e+06 2.38e-02 1.63e+02  -1.0 1.97e+00  -0.6 6.37e-01 4.17e-01F  1
#  117r 1.4902954e+06 3.45e-01 3.31e+02  -1.0 4.88e+00    -  2.76e-01 1.00e+00f  1
#  118r 1.4916509e+06 1.67e-01 1.93e+02  -1.0 4.42e-02   0.7 8.13e-01 5.15e-01f  1
#  119r 1.4948541e+06 1.18e-01 1.47e+02  -1.0 5.77e-01   0.3 2.22e-01 2.84e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120r 1.4989182e+06 4.51e-03 1.44e+02  -1.0 8.88e-02   0.7 5.43e-01 1.00e+00f  1
#  121r 1.5020051e+06 1.14e-03 5.35e+01  -1.0 6.67e-02   1.1 1.00e+00 8.62e-01f  1
#  122r 1.5069277e+06 2.06e-03 9.08e+01  -1.0 2.83e-01   0.6 2.14e-01 3.10e-01F  1
#  123r 1.5139367e+06 2.38e-03 3.87e+02  -1.0 6.43e-02   1.1 5.51e-01 1.00e+00f  1
#  124r 1.5188944e+06 3.37e-03 3.64e+02  -1.0 4.11e-01   0.6 2.62e-01 1.15e-01f  1
#  125r 1.5268352e+06 3.14e-03 1.89e+01  -1.0 1.01e-01   1.0 1.00e+00 1.00e+00f  1
#  126r 1.5285074e+06 8.36e-02 5.68e+01  -1.0 1.32e+02    -  8.97e-03 6.97e-03f  2
#  127r 1.5308550e+06 1.67e-01 5.19e+01  -1.0 1.18e+01    -  1.09e-01 1.19e-01f  1
#  128r 1.5326530e+06 1.79e-01 1.70e+02  -1.0 6.80e+00    -  7.02e-01 3.97e-01f  1
#  129r 1.5609539e+06 1.59e-01 1.46e+02  -1.0 5.61e+00    -  4.19e-01 6.58e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130r 1.5667300e+06 4.14e-02 9.31e+00  -1.0 1.39e+00    -  1.00e+00 1.00e+00f  1
#  131r 1.5646887e+06 9.45e-03 1.05e+00  -1.0 3.40e-01    -  1.00e+00 1.00e+00h  1
#  132r 1.5416321e+06 3.76e-02 3.20e+02  -1.7 4.08e+01    -  2.51e-01 4.22e-02f  1
#  133r 1.5034123e+06 1.09e-01 2.54e+02  -1.7 2.34e+01    -  1.97e-01 1.57e-01f  1
#  134r 1.3628805e+06 3.91e-01 1.78e+02  -1.7 5.70e+00    -  1.00e+00 6.00e-01f  1
#  135r 1.1886945e+06 4.46e-01 4.28e+01  -1.7 5.80e+00    -  1.00e+00 7.77e-01f  1
#  136r 1.1848532e+06 5.53e-04 3.89e+00  -1.7 2.34e-02   0.5 1.00e+00 1.00e+00f  1
#  137r 1.1206765e+06 7.73e-05 1.08e+00  -1.7 1.16e+00    -  1.00e+00 1.00e+00H  1
#  138r 1.1221081e+06 3.39e-04 2.34e-02  -1.7 2.60e-01    -  1.00e+00 1.00e+00h  1
#  139r 9.8766839e+05 2.60e-01 3.93e+00  -3.8 9.72e+00    -  3.12e-01 3.13e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140r 9.8127225e+05 5.73e-02 9.04e+00  -3.8 5.87e-02   0.1 8.21e-01 7.79e-01f  1
#  141r 9.6638385e+05 1.62e-02 5.26e+01  -3.8 1.15e-01  -0.4 8.87e-01 7.17e-01f  1
#  142r 9.5844272e+05 1.20e-04 1.31e+00  -3.8 4.71e-02   0.0 9.92e-01 1.00e+00f  1
#  143r 9.4859887e+05 2.42e-04 4.57e+01  -3.8 8.36e-02  -0.5 7.46e-01 4.77e-01h  1
#  144r 9.4113980e+05 8.90e-05 2.07e-01  -3.8 3.23e-02  -0.0 1.00e+00 1.00e+00f  1
#  145r 9.2994497e+05 2.29e-04 5.72e+01  -3.8 5.96e-02  -0.5 1.00e+00 5.28e-01h  1
#  146r 8.9877277e+05 1.82e-02 5.39e+01  -3.8 1.09e+01    -  5.98e-02 6.26e-02f  1
#  147r 8.0038198e+05 2.02e-01 3.93e+01  -3.8 9.80e+00    -  5.43e-01 2.13e-01f  1
#  148r 5.9823872e+05 9.76e-01 1.56e+01  -3.8 7.38e+00    -  6.60e-01 6.08e-01h  1
#  149r 5.6652629e+05 6.76e-01 1.02e+01  -3.8 2.68e+00    -  2.80e-01 3.40e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150r 5.1082649e+05 1.22e-01 2.38e+01  -3.8 1.75e+00    -  7.35e-01 1.00e+00h  1
#  151r 5.1535737e+05 2.55e-03 4.65e+01  -3.8 1.11e-01    -  6.29e-01 1.00e+00h  1
#  152r 5.1555160e+05 2.28e-03 3.81e+01  -3.8 3.17e-01    -  1.01e-01 1.32e-01h  1
#  153r 5.1571400e+05 2.21e-04 2.21e+01  -3.8 1.10e-01    -  1.00e+00 1.00e+00f  1
#  154r 5.1561938e+05 4.29e-05 2.52e-01  -3.8 5.40e-02    -  1.00e+00 1.00e+00h  1
#  155r 5.1532270e+05 1.59e-05 1.52e+00  -3.8 5.07e-02    -  1.00e+00 1.00e+00h  1
#  156  5.1172387e+05 2.50e-03 3.04e+02  -1.0 1.17e+04    -  1.02e-03 2.37e-04f  3
#  157  5.0967082e+05 3.35e-03 3.49e+02  -1.0 1.02e+04    -  7.05e-04 1.42e-04f  5
#  158  5.0811750e+05 3.84e-03 4.17e+02  -1.0 9.55e+03    -  1.03e-03 1.11e-04f  6
#  159  4.4955279e+05 6.88e-01 2.55e+02  -1.0 8.92e+03    -  1.31e-03 4.34e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  3.0158656e+05 4.93e+00 2.45e+02  -1.0 6.76e+03    -  1.34e-02 1.39e-02f  1
#  161  2.3124256e+05 6.26e+00 7.99e+02  -1.0 4.27e+03    -  6.40e-03 1.77e-02f  1
#  162  2.2759785e+05 6.25e+00 9.51e+02  -1.0 5.15e+03    -  8.26e-04 1.46e-03f  1
#  163  2.1950993e+05 6.24e+00 5.41e+02  -1.0 6.66e+03    -  6.31e-03 3.36e-03f  1
#  164  2.0406663e+05 6.14e+00 5.06e+02  -1.0 3.76e+03    -  7.09e-03 7.89e-03f  1
#  165  1.9017898e+05 6.20e+00 7.66e+02  -1.0 3.64e+03    -  5.43e-03 8.70e-03f  1
#  166  1.7788562e+05 6.35e+00 3.41e+03  -1.0 4.78e+03    -  2.48e-02 9.18e-03f  1
#  167  1.7036632e+05 6.52e+00 1.27e+04  -1.0 3.78e+03    -  4.82e-02 7.78e-03f  1
#  168  1.3306396e+05 2.20e+01 1.48e+04  -1.0 3.81e+03    -  6.91e-02 5.50e-02f  1
#  169  1.2160268e+05 2.88e+01 1.93e+04  -1.0 3.19e+03    -  6.33e-02 3.23e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  1.1182847e+05 3.85e+01 1.95e+04  -1.0 7.13e+03    -  4.39e-02 3.79e-02f  1
#  171  9.6289989e+04 8.53e+01 1.78e+04  -1.0 2.72e+03    -  7.51e-02 7.69e-02f  1
#  172  8.7240965e+04 1.06e+02 1.67e+04  -1.0 3.59e+03    -  6.17e-02 6.10e-02f  1
#  173  7.8614430e+04 1.05e+02 1.38e+04  -1.0 1.43e+03    -  4.93e-02 7.69e-02f  1
#  174  7.7913638e+04 1.04e+02 1.30e+04  -1.0 2.18e+00  -0.2 1.14e-01 1.62e-02f  1
#  175  7.7444005e+04 1.03e+02 1.36e+04  -1.0 3.94e+05    -  1.70e-04 9.28e-04f  1
#  176  6.8036661e+04 7.78e+01 1.17e+04  -1.0 3.99e+00  -0.6 8.00e-02 2.46e-01f  1
#  177  5.7017983e+04 4.78e+01 7.17e+03  -1.0 6.13e+00  -1.1 3.87e-01 3.84e-01f  1
#  178  5.6927978e+04 4.77e+01 1.49e+04  -1.0 6.05e+01  -1.6 2.64e-02 1.89e-03h  1
#  179  5.1067156e+04 3.27e+01 1.05e+04  -1.0 1.36e+01  -2.1 2.80e-01 3.13e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  4.7368685e+04 1.37e+01 3.96e+03  -1.0 4.96e-01   0.2 1.65e-01 5.81e-01f  1
#  181  4.6918859e+04 9.66e+00 5.64e+03  -1.0 1.75e-01   2.4 6.27e-01 2.93e-01f  1
#  182  4.5943312e+04 7.50e-03 5.20e+03  -1.0 1.26e-01   1.9 2.58e-01 1.00e+00f  1
#  183  4.5664636e+04 2.14e-03 2.34e+03  -1.0 6.21e-02   1.5 8.18e-01 1.00e+00f  1
#  184  4.5234103e+04 1.18e-02 5.67e+00  -1.0 1.39e-01   1.0 1.00e+00 1.00e+00f  1
#  185  4.4762443e+04 5.02e-02 4.83e+00  -1.0 2.97e-01   0.5 1.00e+00 1.00e+00f  1
#  186  4.4200313e+04 9.74e-02 1.29e+01  -1.0 6.11e-01   0.0 1.00e+00 1.00e+00f  1
#  187  4.3519528e+04 2.94e-01 1.36e+01  -1.0 1.18e+00  -0.5 1.00e+00 1.00e+00f  1
#  188  4.2746137e+04 8.44e-01 5.52e+01  -1.0 1.51e+00  -0.9 1.00e+00 9.93e-01f  1
#  189  4.2402705e+04 7.03e-01 1.12e+03  -1.0 4.37e+00  -1.4 5.73e-01 3.17e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  4.2435146e+04 3.84e-01 1.67e+03  -1.0 3.57e-01   0.8 1.00e+00 4.52e-01h  1
#  191  4.2347007e+04 2.27e-03 8.54e+00  -1.0 2.04e-01   0.3 1.00e+00 1.00e+00f  1
#  192  4.2325227e+04 1.84e-03 5.40e+02  -1.0 2.22e-01  -0.1 7.11e-01 5.89e-01H  1
#  193  4.2186470e+04 9.35e-04 6.72e+00  -1.0 5.23e-01  -0.6 1.00e+00 1.00e+00F  1
#  194  4.2133041e+04 1.30e-04 2.19e+00  -1.0 2.06e-01  -0.2 1.00e+00 1.00e+00H  1
#  195  3.0938882e+04 2.09e-01 4.55e+01  -1.7 8.42e-01  -0.7 5.54e-01 5.54e-01f  1
#  196  2.7023044e+04 3.46e-01 2.68e+03  -1.7 2.70e+00  -1.1 6.13e-01 3.81e-01f  1
#  197  2.5087666e+04 3.42e-01 2.78e+03  -1.7 7.06e+00  -1.6 7.95e-01 2.52e-01f  1
#  198  2.2106089e+04 1.27e+00 3.14e+03  -1.7 1.96e+01  -2.1 2.89e-01 4.03e-01f  1
#  199  1.9346753e+04 8.37e-01 5.53e+02  -1.7 7.04e+00  -1.7 1.00e+00 7.07e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.8532254e+04 1.25e+00 1.53e+03  -1.7 2.19e+01  -2.1 5.07e-01 2.69e-01f  1
#  201  1.7108860e+04 1.16e+00 1.07e+01  -1.7 7.87e+00  -1.7 1.00e+00 1.00e+00f  1
#  202  1.6153006e+04 3.12e+00 8.05e+01  -1.7 2.92e+01  -2.2 3.98e-01 3.80e-01f  1
#  203  1.5138777e+04 2.13e+00 4.84e+02  -1.7 1.03e+01  -1.8 8.88e-01 1.00e+00f  1
#  204  1.4515571e+04 3.05e+00 4.83e+02  -1.7 5.82e+01  -2.2 8.81e-02 1.16e-01f  1
#  205  1.4134507e+04 2.94e+00 3.77e+02  -1.7 1.68e+01  -1.8 3.37e-01 2.01e-01f  1
#  206  1.3424510e+04 3.55e+00 2.00e+01  -1.7 5.50e+00  -1.4 1.00e+00 1.00e+00f  1
#  207  1.3084129e+04 4.52e+00 7.83e+02  -1.7 2.43e+01  -1.9 2.83e-01 1.10e-01f  1
#  208  1.3069123e+04 3.95e+00 1.39e+03  -1.7 1.40e+00  -1.4 1.00e+00 1.26e-01h  1
#  209  1.2872287e+04 9.54e-01 3.94e+02  -1.7 3.77e+00  -1.9 1.00e+00 7.51e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.2721057e+04 6.99e-01 1.48e+03  -1.7 9.74e+00  -2.4 6.78e-01 2.53e-01f  1
#  211  1.2727287e+04 7.17e-04 1.03e+00  -1.7 6.32e-02  -0.2 1.00e+00 1.00e+00h  1
#  212  1.0232808e+04 2.26e-02 1.38e+02  -2.5 3.87e-01  -0.6 6.05e-01 5.59e-01f  1
#  213  9.4646671e+03 2.95e-02 7.60e+02  -2.5 6.76e-01  -1.1 7.82e-01 3.95e-01f  1
#  214  8.5853864e+03 1.37e-01 5.25e+02  -2.5 1.96e+00  -1.6 1.00e+00 6.55e-01f  1
#  215  8.3348611e+03 1.31e-01 4.84e+02  -2.5 5.29e+00  -2.1 4.79e-01 3.00e-01f  1
#  216  8.0000604e+03 3.34e-01 3.47e+02  -2.5 1.41e+01  -2.6 3.29e-01 2.65e-01f  1
#  217  7.7531901e+03 3.11e-01 5.55e+02  -2.5 5.23e+00  -2.1 1.00e+00 4.54e-01f  1
#  218  7.6387585e+03 2.97e-01 4.86e+02  -2.5 1.44e+01  -2.6 1.01e-01 1.24e-01f  1
#  219  7.4957954e+03 3.08e-01 3.50e+02  -2.5 5.55e+00  -2.2 7.61e-01 3.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  7.4515927e+03 3.11e-01 3.31e+02  -2.5 1.89e+01  -2.7 3.42e-02 4.86e-02f  1
#  221  7.2698507e+03 3.87e-01 1.70e+02  -2.5 5.75e+00  -2.2 4.64e-01 4.81e-01f  1
#  222  7.2273720e+03 3.97e-01 1.65e+02  -2.5 2.58e+01  -2.7 4.96e-02 4.24e-02f  1
#  223  6.9761875e+03 8.29e-01 9.84e+01  -2.5 6.31e+00  -2.3 6.09e-01 6.94e-01f  1
#  224  6.9064968e+03 8.26e-01 6.09e+01  -2.5 2.16e+01  -2.8 1.03e-01 7.61e-02f  1
#  225  6.8097516e+03 7.13e-01 1.19e+02  -2.5 7.39e+00  -2.3 1.95e-01 2.78e-01f  1
#  226  6.6949721e+03 7.83e-01 9.84e+01  -2.5 2.35e+01  -2.8 1.92e-01 1.18e-01f  1
#  227  6.5903667e+03 7.16e-01 1.23e+02  -2.5 8.26e+00  -2.4 3.66e-01 3.05e-01f  1
#  228  6.4064102e+03 1.08e+00 1.43e+02  -2.5 2.54e+01  -2.9 2.24e-01 1.96e-01f  1
#  229  6.2935853e+03 9.64e-01 1.29e+02  -2.5 9.61e+00  -2.4 3.64e-01 3.09e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  6.1926002e+03 1.04e+00 1.05e+02  -2.5 3.46e+01  -2.9 7.22e-02 8.65e-02f  1
#  231  6.1155789e+03 9.47e-01 1.75e+02  -2.5 1.10e+01  -2.5 2.48e-01 1.82e-01f  1
#  232  5.9726365e+03 4.31e-01 3.25e+02  -2.5 4.04e+00  -2.1 6.37e-01 8.87e-01f  1
#  233  5.9092114e+03 2.01e-01 5.10e+02  -2.5 1.52e+00  -1.6 5.43e-01 1.00e+00h  1
#  234  5.7764464e+03 3.08e-01 7.33e+02  -2.5 4.29e+00  -2.1 3.87e-01 7.75e-01f  1
#  235  5.7075187e+03 3.64e-01 4.29e+02  -2.5 1.36e+01  -2.6 2.27e-01 1.47e-01f  1
#  236  5.5856240e+03 6.27e-01 4.60e+02  -2.5 4.72e+01  -3.1 1.39e-01 8.62e-02f  1
#  237  5.3973362e+03 1.00e+00 4.28e+02  -2.5 1.31e+01  -2.6 5.56e-01 3.83e-01f  1
#  238  5.2728584e+03 6.29e-01 1.91e+02  -2.5 4.97e+00  -2.2 3.91e-01 7.15e-01h  1
#  239  5.2691176e+03 2.77e-04 1.31e+00  -2.5 2.90e-02   0.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  5.2668990e+03 2.35e-04 2.00e-01  -2.5 9.00e-02  -0.5 1.00e+00 1.00e+00f  1
#  241  5.2691672e+03 4.75e-06 1.63e+02  -2.5 1.29e-02   0.9 8.69e-01 1.00e+00h  1
#  242  5.2664335e+03 3.50e-05 4.57e+00  -2.5 1.48e-02   0.4 1.00e+00 1.00e+00f  1
#  243  5.2673795e+03 2.61e-05 1.36e+02  -2.5 1.48e-01  -0.1 4.80e-02 1.10e-01f  3
#  244  5.2688556e+03 3.70e-06 2.51e+00  -2.5 1.77e-03   3.1 1.00e+00 1.00e+00h  1
#  245  5.2687763e+03 2.09e-06 3.32e-01  -2.5 4.89e-04   2.6 1.00e+00 1.00e+00h  1
#  246  5.2684024e+03 1.15e-06 1.40e-01  -2.5 9.50e-04   2.1 1.00e+00 1.00e+00h  1
#  247  4.9281754e+03 1.72e-04 1.27e+02  -3.8 1.07e-02   1.6 5.15e-01 6.32e-01f  1
#  248  4.8026724e+03 3.96e-04 1.07e+02  -3.8 1.62e-02   1.1 7.06e-01 4.73e-01f  1
#  249  4.7179404e+03 1.10e-03 3.17e+02  -3.8 5.39e-02   0.7 7.65e-01 5.07e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  4.6908423e+03 1.05e-03 2.24e+02  -3.8 9.47e-02   0.2 6.70e-01 2.68e-01f  1
#  251  4.6746963e+03 9.77e-04 4.20e+02  -3.8 1.98e-01  -0.3 9.47e-01 1.77e-01f  1
#  252  4.6548385e+03 9.35e-04 6.64e+02  -3.8 2.83e-01  -0.8 8.86e-01 2.20e-01f  1
#  253  4.6393839e+03 2.69e-03 7.21e+02  -3.8 7.29e-01  -1.2 1.00e+00 1.64e-01f  1
#  254  4.6046212e+03 1.01e-02 5.11e+02  -3.8 2.06e+00  -1.7 5.71e-01 2.55e-01f  1
#  255  4.5542792e+03 4.23e-02 3.75e+02  -3.8 5.83e+00  -2.2 4.09e-01 1.98e-01f  1
#  256  4.5162844e+03 4.16e-02 2.60e+02  -3.8 2.14e+00  -1.8 1.00e+00 3.92e-01f  1
#  257  4.4438469e+03 1.15e-01 1.59e+02  -3.8 6.23e+00  -2.2 5.56e-01 3.19e-01f  1
#  258  4.4084662e+03 8.83e-02 1.81e+02  -3.8 2.34e+00  -1.8 1.00e+00 4.02e-01f  1
#  259  4.3830896e+03 9.09e-02 1.97e+02  -3.8 6.63e+00  -2.3 2.17e-01 1.10e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  4.3352855e+03 8.24e-02 1.05e+02  -3.8 2.36e+00  -1.9 6.76e-01 5.36e-01f  1
#  261  4.2955042e+03 9.53e-02 1.30e+02  -3.8 6.98e+00  -2.3 2.24e-01 1.60e-01f  1
#  262  4.2705285e+03 1.10e-01 9.20e+01  -3.8 2.11e+01  -2.8 1.82e-02 3.17e-02f  1
#  263  4.2651781e+03 9.46e-02 2.44e+02  -3.8 9.89e-01  -1.5 9.06e-01 1.45e-01h  1
#  264  4.2069156e+03 6.06e-02 1.74e+02  -3.8 3.10e+00  -2.0 7.54e-01 6.16e-01f  1
#  265  4.1577618e+03 7.76e-02 1.96e+02  -3.8 9.39e+00  -2.5 2.27e-01 1.78e-01f  1
#  266  4.1157050e+03 9.21e-02 1.85e+02  -3.8 3.02e+01  -2.9 5.72e-02 4.81e-02f  1
#  267  4.1060483e+03 8.78e-02 1.66e+02  -3.8 7.67e+00  -2.5 1.45e-01 4.85e-02h  1
#  268  4.0715593e+03 8.51e-02 2.25e+02  -3.8 2.64e+01  -3.0 1.92e-01 5.76e-02f  1
#  269  4.0405469e+03 7.80e-02 1.82e+02  -3.8 9.89e+00  -2.6 6.92e-03 1.33e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  3.9854672e+03 8.29e-02 1.73e+02  -3.8 3.03e+01  -3.0 7.32e-02 8.25e-02f  1
#  271  3.9723053e+03 7.93e-02 1.50e+02  -3.8 9.91e+00  -2.6 6.65e-02 5.18e-02f  1
#  272  3.9631064e+03 7.21e-02 1.36e+02  -3.8 3.69e+00  -2.2 9.42e-02 9.62e-02h  1
#  273  3.9581934e+03 7.09e-02 1.41e+02  -3.8 7.49e+00  -2.7 5.74e-02 1.90e-02f  1
#  274  3.9439095e+03 6.41e-02 1.23e+02  -3.8 2.68e+00  -2.2 6.02e-02 1.53e-01f  1
#  275  3.9239712e+03 5.90e-02 9.57e+01  -3.8 8.78e+00  -2.7 1.02e-02 7.86e-02f  1
#  276  3.9231690e+03 5.89e-02 9.45e+01  -3.8 3.14e+01  -3.2 4.50e-04 1.01e-03h  1
#  277  3.9231690e+03 5.89e-02 9.45e+01  -3.8 1.11e+03  -2.8 6.24e-08 1.79e-07f  2
#  278  3.9231693e+03 5.89e-02 8.46e+01  -3.8 5.16e+01  -1.4 5.90e-03 2.00e-06f  2
#  279  3.9071610e+03 3.69e-02 1.17e+02  -3.8 1.34e+00  -1.9 7.25e-01 3.75e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  3.8750640e+03 2.71e-02 7.10e+01  -3.8 4.10e+00  -2.4 2.46e-01 2.66e-01f  1
#  281  3.7977960e+03 7.41e-02 2.74e+02  -3.8 1.28e+01  -2.9 8.07e-02 2.26e-01f  1
#  282  3.7902725e+03 7.05e-02 2.65e+03  -3.8 4.56e+00  -2.4 2.56e-01 5.53e-02h  1
#  283  3.7574755e+03 7.40e-02 2.21e+03  -3.8 1.30e+01  -2.9 1.69e-01 8.52e-02f  1
#  284  3.7388302e+03 3.24e-03 4.44e+02  -3.8 6.01e-01  -1.6 7.98e-01 1.00e+00f  1
#  285  3.6963339e+03 1.93e-02 3.66e+02  -3.8 1.79e+00  -2.1 4.16e-01 8.02e-01f  1
#  286  3.6385178e+03 4.39e-02 6.39e+02  -3.8 5.26e+00  -2.5 2.58e-01 3.67e-01f  1
#  287  3.6323063e+03 4.00e-02 6.91e+02  -3.8 2.41e+00  -2.1 2.68e-01 9.37e-02f  1
#  288  3.6261526e+03 3.92e-02 6.84e+02  -3.8 1.33e+01  -2.6 7.62e-02 2.38e-02f  1
#  289  3.5738998e+03 6.10e-02 6.24e+02  -3.8 1.77e+01  -3.1 8.53e-02 1.06e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  3.5410248e+03 6.09e-02 4.98e+02  -3.8 6.58e+00  -2.6 2.05e-01 1.78e-01f  1
#  291  3.5033462e+03 6.93e-02 4.73e+02  -3.8 2.31e+01  -3.1 4.43e-02 7.07e-02f  1
#  292  3.4816847e+03 6.62e-02 3.60e+02  -3.8 7.84e+00  -2.7 2.93e-01 1.12e-01f  1
#  293  3.4533702e+03 7.05e-02 3.39e+02  -3.8 3.34e+01  -3.2 6.94e-02 4.89e-02f  1
#  294  3.4291436e+03 6.86e-02 2.89e+02  -3.8 9.39e+00  -2.7 1.85e-01 1.20e-01f  1
#  295  3.3987169e+03 5.23e-02 1.58e+02  -3.8 3.47e+00  -2.3 5.88e-01 4.00e-01f  1
#  296  3.3860607e+03 5.07e-02 2.33e+02  -3.8 1.07e+01  -2.8 2.45e-01 5.88e-02f  1
#  297  3.3514224e+03 5.81e-02 1.63e+02  -3.8 3.99e+01  -3.3 9.85e-03 5.84e-02f  1
#  298  3.3453991e+03 5.65e-02 2.23e+02  -3.8 1.17e+01  -2.8 1.76e-01 3.09e-02f  1
#  299  3.3274110e+03 6.65e-02 1.86e+02  -3.8 5.22e+01  -3.3 1.10e-02 3.02e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  3.3042097e+03 6.85e-02 1.67e+02  -3.8 1.51e+01  -2.9 1.18e-01 1.20e-01f  1
#  301  3.2643918e+03 5.47e-02 3.81e+02  -3.8 5.49e+00  -2.5 2.39e-01 5.64e-01f  1
#  302  3.2542963e+03 3.45e-02 2.94e+02  -3.8 2.00e+00  -2.0 5.56e-01 4.10e-01f  1
#  303  3.2542403e+03 2.74e-02 2.10e+02  -3.8 3.42e-03   3.8 1.90e-01 2.06e-01h  1
#  304  3.2544236e+03 1.58e-02 4.73e+02  -3.8 6.50e-04   3.3 6.38e-01 4.22e-01f  1
#  305  3.2548784e+03 8.12e-03 9.17e+02  -3.8 3.00e-04   3.7 9.68e-01 4.87e-01h  1
#  306  3.2550425e+03 2.05e-06 6.12e-01  -3.8 3.27e-04   3.3 1.00e+00 1.00e+00f  1
#  307  3.2544834e+03 2.03e-06 8.52e+02  -3.8 3.60e-04   2.8 1.00e+00 5.30e-01h  1
#  308  3.2541677e+03 1.97e-06 7.66e+02  -3.8 5.01e-04   2.3 1.74e-01 1.00e+00f  1
#  309  3.2538903e+03 1.81e-06 3.25e+02  -3.8 1.32e-03   1.8 7.49e-01 8.32e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  3.2539055e+03 1.19e-06 5.66e+02  -3.8 1.88e-03   1.4 2.45e-01 1.00e+00f  1
#  311  3.2538550e+03 1.29e-06 1.45e-01  -3.8 3.29e-03   0.9 1.00e+00 1.00e+00h  1
#  312  3.2536327e+03 3.87e-06 3.55e-02  -3.8 1.03e-02   0.4 1.00e+00 1.00e+00h  1
#  313  3.2531044e+03 1.14e-05 2.53e-02  -3.8 2.96e-02  -0.1 1.00e+00 1.00e+00f  1
#  314  3.2518128e+03 4.08e-05 1.78e+01  -3.8 8.51e-02  -0.5 1.00e+00 8.69e-01f  1
#  315  3.2496657e+03 1.73e-04 2.65e-02  -3.8 1.90e-01  -1.0 1.00e+00 1.00e+00f  1
#  316  3.2485639e+03 1.95e-05 1.95e-02  -3.8 7.68e-02  -0.6 1.00e+00 1.00e+00h  1
#  317  3.2458421e+03 1.46e-04 3.45e-02  -3.8 2.21e-01  -1.1 1.00e+00 1.00e+00f  1
#  318  3.2377350e+03 1.36e-03 7.66e-02  -3.8 6.56e-01  -1.6 1.00e+00 1.00e+00f  1
#  319  3.2346311e+03 1.95e-04 2.71e-02  -3.8 2.45e-01  -1.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  3.2255066e+03 1.73e-03 1.18e-01  -3.8 7.39e-01  -1.6 1.00e+00 1.00e+00f  1
#  321  3.2101012e+03 5.58e-03 8.69e+01  -3.8 2.22e+00  -2.1 8.87e-01 5.61e-01f  1
#  322  3.2088501e+03 3.40e-05 5.63e-02  -3.8 1.04e-01  -0.7 1.00e+00 1.00e+00f  1
#  323  3.2050070e+03 3.05e-04 2.21e-02  -3.8 3.13e-01  -1.2 1.00e+00 1.00e+00f  1
#  324  3.1934904e+03 2.72e-03 4.55e-02  -3.8 9.38e-01  -1.7 1.00e+00 1.00e+00f  1
#  325  3.1891318e+03 3.85e-04 1.85e-02  -3.8 3.51e-01  -1.3 1.00e+00 1.00e+00h  1
#  326  3.1761041e+03 3.42e-03 3.97e-02  -3.8 1.06e+00  -1.8 1.00e+00 1.00e+00f  1
#  327  3.1364590e+03 3.37e-02 1.75e-01  -3.8 3.17e+00  -2.2 1.00e+00 1.00e+00f  1
#  328  3.1358937e+03 4.70e-06 4.65e-02  -3.8 1.50e-02   0.0 1.00e+00 1.00e+00h  1
#  329  3.1352188e+03 1.13e-05 1.84e-02  -3.8 5.51e-02  -0.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  3.1331002e+03 9.66e-05 1.85e-02  -3.8 1.67e-01  -1.0 1.00e+00 1.00e+00f  1
#  331  3.1322533e+03 1.36e-05 1.84e-02  -3.8 6.20e-02  -0.5 1.00e+00 1.00e+00h  1
#  332  3.1298520e+03 1.21e-04 1.84e-02  -3.8 1.87e-01  -1.0 1.00e+00 1.00e+00f  1
#  333  3.1226240e+03 1.11e-03 3.02e-02  -3.8 5.61e-01  -1.5 1.00e+00 1.00e+00f  1
#  334  3.1141911e+03 2.25e-03 1.09e+02  -3.8 1.70e+00  -2.0 1.00e+00 3.89e-01f  1
#  335  3.0818113e+03 2.68e-02 5.95e+01  -3.8 5.21e+00  -2.4 5.19e-01 5.05e-01f  1
#  336  3.0787316e+03 2.14e-04 2.66e-02  -3.8 2.38e-01  -1.1 1.00e+00 1.00e+00f  1
#  337  3.0775244e+03 2.79e-05 1.87e-02  -3.8 8.98e-02  -0.7 1.00e+00 1.00e+00h  1
#  338  3.0741182e+03 2.52e-04 1.88e-02  -3.8 2.71e-01  -1.2 1.00e+00 1.00e+00f  1
#  339  3.0638588e+03 2.33e-03 2.62e-02  -3.8 8.15e-01  -1.6 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340  3.0410008e+03 1.29e-02 6.62e+01  -3.8 2.46e+00  -2.1 1.00e+00 7.42e-01f  1
#  341  3.0404897e+03 8.88e-03 6.65e+01  -3.8 1.12e-01  -0.8 1.00e+00 3.13e-01f  1
#  342  3.0362064e+03 4.36e-04 2.34e-02  -3.8 3.43e-01  -1.3 1.00e+00 1.00e+00f  1
#  343  3.0345942e+03 5.96e-05 1.88e-02  -3.8 1.29e-01  -0.8 1.00e+00 1.00e+00h  1
#  344  3.0297884e+03 5.37e-04 1.88e-02  -3.8 3.86e-01  -1.3 1.00e+00 1.00e+00f  1
#  345  3.0154367e+03 5.05e-03 6.11e-02  -3.8 1.16e+00  -1.8 1.00e+00 1.00e+00f  1
#  346  2.9719614e+03 4.97e-02 3.72e+01  -3.8 3.53e+00  -2.3 8.96e-01 1.00e+00f  1
#  347  2.9697103e+03 1.31e-04 7.72e-02  -3.8 1.61e-01  -0.9 1.00e+00 1.00e+00h  1
#  348  2.9688774e+03 1.61e-05 1.89e-02  -3.8 6.13e-02  -0.5 1.00e+00 1.00e+00h  1
#  349  2.9665603e+03 1.40e-04 1.90e-02  -3.8 1.85e-01  -1.0 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350  2.9595639e+03 1.27e-03 8.50e-02  -3.8 5.51e-01  -1.5 1.00e+00 1.00e+00f  1
#  351  2.9388246e+03 1.22e-02 4.11e-02  -3.8 1.68e+00  -1.9 1.00e+00 1.00e+00f  1
#  352  2.8999717e+03 4.99e-02 1.30e+02  -3.8 5.09e+00  -2.4 3.51e-01 6.22e-01f  1
#  353  2.8985017e+03 2.45e-02 7.03e+01  -3.8 2.39e-01  -1.1 4.62e-01 5.10e-01f  1
#  354  2.8898965e+03 3.49e-03 2.53e+01  -3.8 7.02e-01  -1.6 8.42e-01 9.44e-01f  1
#  355  2.8866494e+03 3.25e-04 2.50e+02  -3.8 2.64e-01  -1.1 1.13e-01 1.00e+00f  1
#  356  2.8774182e+03 2.45e-03 1.78e+01  -3.8 7.87e-01  -1.6 1.00e+00 9.08e-01f  1
#  357  2.8651201e+03 5.90e-03 2.60e+01  -3.8 2.37e+00  -2.1 2.83e-01 4.08e-01f  1
#  358  2.8639508e+03 1.15e-04 2.44e+02  -3.8 1.02e-01  -0.8 2.02e-01 1.00e+00f  1
#  359  2.8599919e+03 2.32e-03 6.41e+02  -3.8 3.20e-01  -1.2 5.31e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360  2.8471279e+03 4.53e-03 5.67e-01  -3.8 9.99e-01  -1.7 1.00e+00 1.00e+00f  1
#  361  2.8449071e+03 6.45e-03 1.12e+03  -3.8 9.59e+00  -2.2 1.42e-02 6.09e-02h  1
#  362  2.8316612e+03 2.56e-02 9.86e+02  -3.8 9.80e+00  -2.7 1.22e-01 1.06e-01f  1
#  363  2.8095164e+03 6.26e-02 7.18e+02  -3.8 3.40e+00  -2.2 2.23e-01 5.13e-01f  1
#  364  2.8079498e+03 2.84e-04 9.44e+03  -3.8 1.56e-01  -0.9 9.94e-02 1.00e+00f  1
#  365  2.8075852e+03 2.55e-04 8.46e+03  -3.8 6.11e-01  -0.5 4.51e-01 1.06e-01h  1
#  366  2.8076678e+03 1.11e-03 4.22e+03  -3.8 6.41e-01  -1.0 1.84e-01 5.09e-01f  1
#  367  2.8044390e+03 1.24e-03 3.28e+03  -3.8 5.77e-01  -1.4 2.56e-01 2.22e-01f  1
#  368  2.7904322e+03 5.84e-03 1.51e+03  -3.8 1.66e+00  -1.9 1.56e-01 6.65e-01f  1
#  369  2.7718676e+03 2.66e-02 1.07e+03  -3.8 5.04e+00  -2.4 2.92e-01 2.89e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370  2.7581382e+03 2.83e-02 8.81e+02  -3.8 1.87e+00  -2.0 2.47e-01 5.74e-01f  1
#  371  2.7527084e+03 2.73e-02 7.84e+02  -3.8 6.08e+00  -2.5 9.30e-02 6.99e-02f  1
#  372  2.7436973e+03 2.80e-02 7.42e+02  -3.8 1.80e+01  -2.9 4.89e-02 3.73e-02f  1
#  373  2.7355931e+03 2.52e-02 6.74e+02  -3.8 6.43e+00  -2.5 1.00e+00 9.64e-02f  1
#  374  2.6846983e+03 1.34e-01 4.95e+02  -3.8 2.04e+01  -3.0 1.71e-01 1.98e-01f  1
#  375  2.6776478e+03 1.27e-01 4.43e+02  -3.8 7.41e+00  -2.6 3.96e-02 7.35e-02h  1
#  376  2.6754227e+03 1.27e-01 4.46e+02  -3.8 2.71e+01  -3.0 9.70e-03 6.82e-03h  1
#  377  2.6754168e+03 1.27e-01 4.46e+02  -3.8 1.03e+00  -1.7 8.57e-04 3.68e-04f  2
#  378  2.6754095e+03 1.26e-01 4.12e+02  -3.8 1.03e+00  -0.4 7.62e-02 3.55e-03h  1
#  379  2.6740747e+03 6.96e-02 1.42e+02  -3.8 1.27e-01  -0.9 1.00e+00 4.48e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380  2.6681182e+03 1.43e-03 6.83e-01  -3.8 4.17e-01  -1.3 1.00e+00 1.00e+00f  1
#  381  2.6521832e+03 1.70e-02 1.03e+00  -3.8 1.28e+00  -1.8 1.00e+00 1.00e+00f  1
#  382  2.6436607e+03 2.26e-02 7.89e+01  -3.8 3.85e+00  -2.3 3.81e-01 1.80e-01f  1
#  383  2.6415176e+03 1.15e-03 9.01e-02  -3.8 1.76e-01  -1.0 1.00e+00 1.00e+00f  1
#  384  2.6349311e+03 6.09e-03 1.12e-01  -3.8 5.36e-01  -1.4 1.00e+00 1.00e+00f  1
#  385  2.6324755e+03 1.05e-03 7.13e-02  -3.8 2.02e-01  -1.0 1.00e+00 1.00e+00h  1
#  386  2.6252094e+03 1.30e-02 1.42e-01  -3.8 6.07e-01  -1.5 1.00e+00 1.00e+00f  1
#  387  2.6218605e+03 1.67e-02 5.24e+01  -3.8 1.82e+00  -2.0 3.85e-01 1.51e-01h  1
#  388  2.6136489e+03 3.77e-03 7.01e-02  -3.8 6.84e-01  -1.5 1.00e+00 1.00e+00f  1
#  389  2.5955447e+03 1.18e-02 2.39e+01  -3.8 2.06e+00  -2.0 8.61e-01 7.41e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390  2.5925580e+03 1.18e-02 1.36e+01  -3.8 6.36e+00  -2.5 1.53e-02 3.89e-02f  1
#  391  2.5923611e+03 4.64e-05 5.58e+01  -3.8 4.45e-02  -0.3 1.70e-01 1.00e+00f  1
#  392  2.5923118e+03 7.48e-06 2.20e+01  -3.8 4.52e-03   1.1 7.30e-01 8.34e-01h  1
#  393  2.5923527e+03 7.44e-06 1.66e+02  -3.8 2.49e-03   3.3 4.53e-02 4.66e-03f  8
#  394  2.5971797e+03 4.66e-06 3.67e+03  -3.8 2.10e-02   2.8 1.39e-02 3.74e-01H  1
#  395  2.5972466e+03 4.51e-06 4.30e+03  -3.8 1.26e-03   3.3 1.00e+00 3.12e-02f  6
#  396  2.5920822e+03 2.51e-06 3.00e+03  -3.8 8.13e-03   2.8 2.34e-01 4.45e-01H  1
#  397  2.5921989e+03 2.43e-06 2.94e+03  -3.8 6.72e-03   2.3 2.33e-03 3.12e-02f  6
#  398  2.5940761e+03 1.24e-06 2.99e+02  -3.8 4.40e-03   2.7 8.67e-01 1.00e+00H  1
#  399  2.5921712e+03 1.23e-07 8.83e+00  -3.8 5.88e-04   2.2 1.00e+00 9.30e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400  2.5922914e+03 1.83e-06 1.64e+03  -3.8 1.14e-03   1.8 3.88e-03 5.00e-01f  2
#  401  2.5926921e+03 6.72e-07 4.77e+02  -3.8 7.06e-03   1.3 3.60e-01 1.00e+00H  1
#  402  2.5930509e+03 7.04e-07 2.94e+02  -3.8 8.94e-04   2.6 8.69e-01 1.00e+00H  1
#  403  2.5930536e+03 7.26e-07 1.73e-01  -3.8 1.23e-03   2.1 1.00e+00 1.00e+00h  1
#  404  2.5926335e+03 3.30e-07 7.36e-02  -3.8 1.97e-04   2.6 1.00e+00 1.00e+00f  1
#  405  2.5925498e+03 2.40e-07 6.09e-02  -3.8 8.11e-04   2.1 1.00e+00 1.00e+00H  1
#  406  2.5924835e+03 1.95e-07 1.51e-01  -3.8 2.38e-03   1.6 1.00e+00 1.00e+00H  1
#  407  2.5925043e+03 2.02e-07 2.84e+02  -3.8 8.24e-03   1.1 7.80e-01 6.25e-02h  5
#  408  2.5923331e+03 2.04e-07 7.43e+01  -3.8 2.95e-04   2.5 1.00e+00 7.99e-01H  1
#  409  2.5925198e+03 2.14e-07 1.34e+02  -3.8 6.07e-04   2.0 5.69e-01 1.00e+00F  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410  2.5925232e+03 2.16e-07 2.09e+02  -3.8 2.13e-03   1.5 1.00e+00 6.25e-02h  5
#  411  2.5927758e+03 4.34e-06 1.00e+02  -3.8 1.25e-02   1.0 5.21e-01 5.21e-01s 22
#  412  2.5937179e+03 3.43e-06 2.65e+01  -3.8 9.04e-03   1.5 7.36e-01 7.36e-01s 22
#  413  2.5941929e+03 4.22e-05 6.43e+00  -3.8 2.02e-02   1.0 1.00e+00 1.00e+00s 22
#  414r 2.5941929e+03 4.22e-05 1.00e+03  -3.8 0.00e+00   0.5 0.00e+00 0.00e+00R  1
#  415r 2.5944033e+03 1.46e-05 8.36e+02  -3.8 1.59e+00    -  6.44e-01 5.74e-03f  1
#  416r 2.6381878e+03 4.73e-03 1.01e+03  -3.8 1.37e+00    -  1.56e-01 3.88e-01f  1
#  417r 2.7482951e+03 1.80e-02 5.10e+02  -3.8 1.27e+00    -  2.61e-01 8.43e-01f  1
#  418r 2.8256413e+03 1.05e-02 3.34e+02  -3.8 1.34e-01  -2.0 3.18e-01 4.71e-01h  1
#  419r 2.8461159e+03 8.55e-03 3.10e+02  -3.8 1.64e+00  -2.5 6.95e-02 7.58e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420r 3.0686438e+03 2.38e-02 2.79e+02  -3.8 2.99e-01  -3.0 4.06e-01 8.27e-01f  1
#  421r 3.4440826e+03 3.92e-02 5.06e+02  -3.8 1.14e+00    -  2.64e-01 8.17e-01f  1
#  422r 3.5374158e+03 3.38e-02 4.29e+02  -3.8 1.60e+00    -  1.49e-01 1.57e-01h  1
#  423r 4.2465525e+03 3.12e-02 3.16e+02  -3.8 1.52e+00    -  5.19e-01 1.00e+00h  1
#  424r 4.6427597e+03 2.42e-02 2.35e+02  -3.8 7.08e-01  -3.4 2.23e-01 2.79e-01h  1
#  425r 5.2341445e+03 1.86e-02 1.65e+02  -3.8 8.68e-01  -3.9 2.40e-01 3.26e-01h  1
#  426r 7.5027121e+03 3.41e-02 3.46e+02  -3.8 1.52e+00    -  4.68e-01 1.00e+00h  1
#  427r 8.5538619e+03 3.27e-06 2.90e+01  -3.8 1.54e-03   1.9 6.72e-01 1.00e+00h  1
#  428r 1.0457367e+04 9.67e-06 1.61e+01  -3.8 2.06e-03   1.5 6.77e-01 1.00e+00f  1
#  429r 1.4019691e+04 3.89e-05 1.65e+01  -3.8 3.77e-03   1.0 4.95e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430r 1.9199023e+04 1.40e-04 4.76e+00  -3.8 9.78e-03   0.5 7.93e-01 9.30e-01f  1
#  431r 4.0015515e+04 1.73e-01 7.63e+01  -3.8 1.67e+00    -  2.94e-01 1.00e+00f  1
#  432r 4.9492018e+04 3.23e-04 2.11e+01  -3.8 1.23e-02   0.0 8.67e-01 1.00e+00h  1
#  433r 9.7025535e+04 2.71e-01 2.50e+02  -3.8 2.53e+00    -  1.19e-01 1.00e+00f  1
#  434r 1.0871680e+05 1.96e-01 1.64e+02  -3.8 1.67e+00    -  3.46e-01 3.07e-01h  1
#  435r 1.1837270e+05 3.57e-04 3.73e+02  -3.8 1.41e-02  -0.4 5.78e-01 1.00e+00h  1
#  436r 1.3097158e+05 8.47e-03 2.95e+02  -3.8 1.97e+00    -  1.64e-01 1.98e-01h  1
#  437r 1.8903755e+05 1.55e-01 9.32e+02  -3.8 1.62e+00    -  3.34e-01 1.00e+00h  1
#  438r 1.9521329e+05 6.40e-04 4.54e+02  -3.8 1.79e-02  -0.9 5.01e-01 1.00e+00h  1
#  439r 1.9980325e+05 4.94e-03 4.01e+02  -3.8 2.43e+00    -  1.25e-01 1.13e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440r 2.1598850e+05 6.57e-02 2.97e+02  -3.8 4.08e+00    -  4.30e-02 3.37e-01h  1
#  441r 2.1598075e+05 6.39e-02 2.73e+02  -3.8 4.07e-01  -1.4 1.26e-01 2.77e-02h  1
#  442r 2.3083908e+05 6.74e-02 2.50e+02  -3.8 8.78e-01    -  3.90e-01 1.00e+00h  1
#  443r 2.3335036e+05 1.08e-02 2.69e+02  -3.8 1.64e-01    -  4.96e-01 8.59e-01h  1
#  444r 2.3429749e+05 2.03e-03 1.04e+02  -3.8 1.10e-01    -  6.44e-01 1.00e+00h  1
#  445r 2.3464280e+05 1.53e-03 1.37e+02  -3.8 8.83e-02    -  5.21e-01 1.00e+00h  1
#  446r 2.3419032e+05 1.61e-03 1.57e+01  -3.8 1.17e-01    -  6.03e-01 1.00e+00h  1
#  447r 2.3435615e+05 1.31e-04 1.99e+01  -3.8 6.38e-03  -0.1 6.67e-01 9.19e-01h  1
#  448r 2.3507931e+05 1.83e-04 1.90e+02  -3.8 8.88e-03  -0.6 7.07e-01 1.00e+00h  1
#  449r 2.3523372e+05 8.32e-04 2.37e+02  -3.8 1.72e-01    -  6.75e-01 5.10e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450r 2.3570435e+05 8.83e-05 4.63e+01  -3.8 5.60e-03  -0.1 3.21e-01 1.00e+00h  1
#  451r 2.3599576e+05 1.09e-03 2.73e+01  -3.8 9.96e-02    -  5.02e-01 1.00e+00h  1
#  452r 2.3563925e+05 1.21e-04 2.74e+00  -3.8 2.46e-02  -0.6 4.99e-01 1.00e+00h  1
#  453r 2.3598114e+05 4.98e-05 4.21e-02  -3.8 1.05e-02  -1.1 1.00e+00 1.00e+00h  1
#  454r 2.3641802e+05 9.76e-04 1.58e-03  -3.8 7.51e-02    -  1.00e+00 1.00e+00h  1
#  455r 2.2083084e+05 9.31e-03 6.52e+01  -5.7 3.10e+00    -  8.50e-01 1.36e-01f  1
#  456r 1.9623516e+05 3.58e-02 2.26e+00  -5.7 1.48e+00    -  9.81e-01 9.60e-01f  1
#  457r 1.6122475e+05 7.25e-02 1.00e+02  -5.7 3.54e+00    -  7.82e-01 4.98e-01h  1
#  458r 1.2382636e+05 9.57e-02 1.19e+02  -5.7 2.53e+00    -  1.00e+00 6.79e-01h  1
#  459r 1.0293183e+05 4.98e-02 8.23e+01  -5.7 1.25e+00    -  1.00e+00 7.16e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460r 9.2138015e+04 6.32e-03 2.27e+00  -5.7 4.75e-01    -  1.00e+00 1.00e+00h  1
#  461r 9.1978895e+04 3.97e-05 1.73e-01  -5.7 1.17e-02    -  1.00e+00 1.00e+00h  1
#  462r 9.1987559e+04 1.49e-06 2.24e-04  -5.7 1.99e-03    -  1.00e+00 1.00e+00h  1
#  463  9.1971749e+04 1.49e-06 1.03e+02  -3.8 2.33e+03    -  6.96e-03 4.92e-06f  4
#  464  9.1960120e+04 1.49e-06 1.68e+02  -3.8 1.85e+03    -  9.34e-04 4.73e-06f  9
#  465  9.1956521e+04 1.49e-06 8.36e+02  -3.8 1.84e+03    -  7.34e-03 1.51e-06f 11
#  466  9.1953785e+04 1.49e-06 9.73e+02  -3.8 1.76e+03    -  1.61e-03 1.38e-06f 13
#  467  9.1950431e+04 1.49e-06 2.71e+03  -3.8 1.74e+03    -  2.07e-02 1.75e-06f 13
#  468  6.6680566e+04 1.25e+00 1.74e+03  -3.8 1.55e+03    -  5.90e-03 1.89e-02f  1
#  469  4.5370222e+04 2.37e+00 5.82e+02  -3.8 9.66e+02    -  1.54e-02 2.46e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470  4.3590198e+04 2.36e+00 2.91e+03  -3.8 1.32e+00   0.0 1.86e-02 4.41e-03f  1
#  471  3.7517839e+04 2.32e+00 1.29e+03  -3.8 2.00e+00  -0.4 1.03e-02 1.81e-02f  1
#  472  3.5982644e+04 2.30e+00 2.51e+03  -3.8 7.42e-01   0.9 1.49e-02 6.45e-03f  1
#  473  3.5047525e+04 2.29e+00 5.95e+03  -3.8 1.49e+00   0.4 2.84e-02 4.11e-03f  1
#  474  3.0750942e+04 2.24e+00 5.16e+03  -3.8 1.79e+00  -0.1 1.82e-02 2.25e-02f  1
#  475  2.8683497e+04 2.21e+00 5.93e+03  -3.8 2.72e+00  -0.5 3.39e-02 1.33e-02f  1
#  476  2.6837600e+04 2.18e+00 5.89e+03  -3.8 2.46e+00  -1.0 1.68e-02 1.54e-02f  1
#  477  2.4668065e+04 2.13e+00 7.62e+03  -3.8 2.48e+00  -1.5 1.15e-01 2.15e-02f  1
#  478  2.3498750e+04 2.09e+00 7.67e+03  -3.8 4.30e+00  -2.0 5.01e-02 1.89e-02f  1
#  479  2.1815796e+04 2.02e+00 1.14e+04  -3.8 1.03e+01  -2.5 1.52e-01 3.23e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480  2.0895786e+04 1.98e+00 2.34e+04  -3.8 3.17e+01  -2.9 1.90e-01 2.44e-02f  1
#  481  2.0545625e+04 1.95e+00 3.81e+04  -3.8 1.29e+00  -0.7 1.23e-01 1.20e-02f  1
#  482  1.8875090e+04 1.82e+00 3.37e+04  -3.8 1.07e+00  -1.2 1.77e-01 6.56e-02f  1
#  483  1.8249167e+04 1.77e+00 3.13e+04  -3.8 2.85e+00  -1.7 7.10e-02 3.03e-02f  1
#  484  1.5596692e+04 1.53e+00 2.83e+04  -3.8 8.03e+00  -2.1 9.53e-02 1.37e-01f  1
#  485  1.4351789e+04 1.41e+00 2.52e+04  -3.8 2.20e+01  -2.6 1.11e-01 7.94e-02f  1
#  486  1.3708569e+04 1.36e+00 2.32e+04  -3.8 5.24e+01  -3.1 8.06e-02 4.37e-02f  1
#  487  1.2957559e+04 1.29e+00 2.02e+04  -3.8 2.33e+01  -2.7 1.32e-01 5.71e-02f  1
#  488  1.2747208e+04 1.27e+00 1.55e+04  -3.8 5.20e+01  -3.1 2.42e-01 1.70e-02f  1
#  489  1.0939343e+04 1.09e+00 1.52e+04  -3.8 2.23e+01  -2.7 1.43e-02 1.64e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490  1.0215293e+04 1.02e+00 1.10e+04  -3.8 4.41e+01  -3.2 2.81e-01 7.44e-02f  1
#  491  9.4958729e+03 9.36e-01 9.71e+03  -3.8 1.73e+01  -2.8 1.15e-01 8.64e-02f  1
#  492  9.0786991e+03 8.88e-01 8.85e+03  -3.8 3.53e+01  -3.2 8.90e-02 5.12e-02f  1
#  493  8.6922353e+03 8.41e-01 7.88e+03  -3.8 2.82e-01  -0.1 1.11e-01 5.31e-02f  1
#  494  8.6107390e+03 8.32e-01 7.83e+03  -3.8 8.41e-01   0.3 5.28e-03 1.12e-02f  1
#  495  8.5158893e+03 8.21e-01 1.66e+04  -3.8 4.36e-01  -0.2 1.56e-01 1.32e-02f  1
#  496  7.7408865e+03 7.19e-01 1.41e+04  -3.8 1.96e-01  -0.6 1.49e-01 1.24e-01f  1
#  497  7.5484734e+03 6.95e-01 1.30e+04  -3.8 2.14e-01   1.6 8.36e-02 3.39e-02f  1
#  498  6.9636090e+03 6.02e-01 1.09e+04  -3.8 3.93e-02   2.0 1.61e-01 1.33e-01f  1
#  499  6.9237399e+03 5.97e-01 1.66e+04  -3.8 5.10e-01   1.5 1.12e-01 8.32e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500  6.7368494e+03 5.71e-01 1.60e+04  -3.8 1.31e-01   1.1 3.47e-02 4.31e-02f  1
#  501  6.6690333e+03 5.64e-01 1.59e+04  -3.8 1.09e+00   0.6 8.41e-03 1.27e-02f  1
#  502  6.6468717e+03 5.63e-01 2.26e+05  -3.8 8.34e+00   0.1 5.69e-02 1.73e-03f  1
#  503  6.1435950e+03 4.96e-01 1.72e+05  -3.8 1.53e-01  -0.4 2.39e-01 1.20e-01f  1
#  504  5.5963535e+03 3.86e-01 1.56e+05  -3.8 9.53e-03   2.8 9.41e-02 2.21e-01f  1
#  505  5.4155299e+03 3.57e-01 1.07e+05  -3.8 3.78e-02   2.3 3.10e-01 7.62e-02f  1
#  506  5.2278977e+03 3.30e-01 9.26e+04  -3.8 8.76e-02   1.8 1.38e-01 7.46e-02f  1
#  507  5.0685000e+03 3.11e-01 7.80e+04  -3.8 2.80e-01   1.3 1.58e-01 5.88e-02f  1
#  508  4.8756190e+03 2.84e-01 5.17e+04  -3.8 5.47e-02   1.8 3.37e-01 8.68e-02f  1
#  509  4.6146982e+03 2.43e-01 3.24e+04  -3.8 2.88e-02   2.2 3.74e-01 1.44e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510  4.5311300e+03 2.33e-01 3.02e+04  -3.8 2.72e-01   1.7 6.65e-02 3.90e-02f  1
#  511  4.0519812e+03 1.61e-01 2.32e+04  -3.8 2.22e-02   2.1 2.34e-01 3.08e-01f  1
#  512  4.0129162e+03 1.58e-01 2.11e+04  -3.8 3.15e-01   1.7 8.75e-02 2.24e-02f  1
#  513  3.9313702e+03 1.46e-01 1.37e+04  -3.8 2.12e-02   2.1 3.54e-01 7.27e-02f  1
#  514  3.6801520e+03 1.18e-01 1.36e+04  -3.8 7.20e-02   1.6 2.15e-03 1.97e-01f  1
#  515  3.6099917e+03 1.08e-01 5.06e+03  -3.8 3.95e-02   2.0 6.29e-01 7.98e-02f  1
#  516  3.5478361e+03 1.01e-01 4.04e+03  -3.8 5.22e-02   1.6 5.75e-01 6.73e-02f  1
#  517  3.4331697e+03 8.98e-02 9.29e+03  -3.8 9.17e-02   1.1 5.02e-01 1.09e-01f  1
#  518  3.3300646e+03 7.66e-02 7.97e+03  -3.8 5.88e-02   1.5 3.91e-01 1.47e-01f  1
#  519  3.2531441e+03 6.93e-02 7.47e+03  -3.8 1.49e-01   1.0 3.51e-01 9.51e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520  3.1971185e+03 6.35e-02 5.88e+03  -3.8 1.34e-01   0.6 2.47e-01 8.44e-02f  1
#  521  3.1362025e+03 5.68e-02 3.06e+03  -3.8 1.81e-01   0.1 4.87e-01 1.06e-01f  1
# ...
# 1745  4.3292451e+02 6.79e-03 1.16e-02  -5.7 1.44e+00  -6.6 1.00e+00 1.00e+00h  1
# 1746  4.3292440e+02 1.31e-03 8.09e-03  -5.7 5.60e-01  -6.2 1.00e+00 1.00e+00h  1
# 1747  4.3292432e+02 3.24e-03 5.15e+00  -5.7 3.77e+00  -6.7 4.02e-01 2.01e-01h  2
# 1748  4.3292452e+02 3.29e-03 6.99e+00  -5.7 1.35e+01  -5.4 4.38e-02 1.15e-02h  3
# 1749  4.3292380e+02 1.74e-06 1.03e-03  -5.7 1.48e-02  -4.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1750  4.3292433e+02 1.06e-06 7.47e-04  -5.7 1.56e-02  -4.5 1.00e+00 1.00e+00h  1
# 1751  4.3292435e+02 9.47e-06 1.50e-03  -5.7 4.53e-02  -5.0 1.00e+00 1.00e+00h  1
# 1752  4.3292432e+02 1.42e-04 1.10e-02  -5.7 1.90e-01  -5.5 1.00e+00 1.00e+00h  1
# 1753  4.3292432e+02 3.53e-05 9.56e-03  -5.7 9.97e-02  -5.0 1.00e+00 1.00e+00h  1
# 1754  4.3292431e+02 7.82e-06 5.21e-03  -5.7 4.90e-02  -4.6 1.00e+00 1.00e+00h  1
# 1755  4.3292431e+02 1.38e-06 1.63e-03  -5.7 2.08e-02  -4.2 1.00e+00 1.00e+00h  1
# 1756  4.3292399e+02 3.86e-05 8.75e-03  -5.7 1.20e-01  -4.7 1.00e+00 1.00e+00H  1
# 1757  4.3292401e+02 2.24e-05 3.24e+01  -5.7 1.93e-01  -5.1 1.00e+00 2.98e-01h  2
# 1758  4.3292418e+02 2.11e-04 6.84e-03  -5.7 2.72e-01  -5.6 1.00e+00 1.00e+00h  1
# 1759  4.3292402e+02 3.99e-04 3.39e-03  -5.7 3.97e-01  -6.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1760  4.3292377e+02 2.83e-03 8.71e-03  -5.7 1.18e+00  -6.6 1.00e+00 1.00e+00h  1
# 1761  4.3292301e+02 1.11e-02 1.58e-02  -5.7 3.48e+00  -7.1 1.00e+00 1.00e+00h  1
# 1762  4.3292101e+02 8.54e-02 8.69e-02  -5.7 9.84e+00  -7.5 1.00e+00 1.00e+00h  1
# 1763  4.3292095e+02 1.07e-03 2.08e-03  -5.7 8.61e-01  -6.2 1.00e+00 1.00e+00h  1
# 1764  4.3292103e+02 4.83e-03 1.03e+01  -5.7 9.57e+01  -6.7 2.70e-02 1.34e-02h  2
# 1765  4.3292130e+02 4.85e-03 1.16e+01  -5.7 6.43e+03  -5.4 4.92e-05 2.59e-05h  3
# 1766  4.3292185e+02 1.01e-05 4.93e-04  -5.7 5.42e-02  -4.0 1.00e+00 1.00e+00h  1
# 1767  4.3292099e+02 9.16e-06 6.56e-04  -5.7 5.04e-02  -4.5 1.00e+00 1.00e+00h  1
# 1768  4.3292101e+02 3.53e-05 2.06e-03  -5.7 1.69e-01  -5.0 1.00e+00 1.00e+00h  1
# 1769  4.3292102e+02 1.15e-04 3.72e+00  -5.7 1.83e+00  -5.5 2.96e-01 1.49e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1770  4.3292132e+02 6.82e-05 1.27e+01  -5.7 1.38e-01  -4.1 1.00e+00 5.00e-01h  2
# 1771  4.3292103e+02 4.22e-05 1.18e+01  -5.7 1.93e-01  -4.6 9.32e-01 5.00e-01h  2
# 1772  4.3292110e+02 3.40e-05 1.80e+01  -5.7 3.66e-01  -4.2 1.00e+00 2.92e-01h  2
# 1773  4.3292085e+02 6.74e-05 5.20e-04  -5.7 7.33e-02  -4.7 1.00e+00 1.00e+00h  1
# 1774  4.3292097e+02 3.69e-05 3.52e-04  -5.7 1.71e-01  -5.1 1.00e+00 1.00e+00h  1
# 1775  4.3292095e+02 1.41e-04 8.92e-04  -5.7 2.66e-01  -5.6 1.00e+00 1.00e+00h  1
# 1776  4.3292088e+02 5.31e-04 2.75e-03  -5.7 3.48e-01  -6.1 1.00e+00 1.00e+00h  1
# 1777  4.3292060e+02 2.35e-03 4.49e-03  -5.7 1.05e+00  -6.6 1.00e+00 1.00e+00h  1
# 1778  4.3291977e+02 8.06e-03 6.97e-03  -5.7 3.08e+00  -7.0 1.00e+00 1.00e+00h  1
# 1779  4.3291758e+02 7.18e-02 4.24e-02  -5.7 8.87e+00  -7.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1780  4.3291707e+02 6.89e-02 2.97e+00  -5.7 3.19e+01  -8.0 1.89e-01 9.47e-02h  2
# 1781  4.3291754e+02 9.90e-04 3.23e-02  -5.7 4.32e-01  -5.8 1.00e+00 1.00e+00h  1
# 1782  4.3291689e+02 5.25e-04 4.64e-02  -5.7 8.44e-01  -6.2 1.00e+00 1.00e+00h  1
# 1783  4.3291689e+02 4.73e-05 4.28e-03  -5.7 1.73e-01  -5.8 1.00e+00 1.00e+00h  1
# 1784  4.3291677e+02 2.80e-04 4.13e-02  -5.7 5.54e-01  -6.3 1.00e+00 1.00e+00h  1
# 1785  4.3291671e+02 2.48e-04 4.85e-02  -5.7 3.58e-01  -5.9 1.00e+00 1.00e+00h  1
# 1786  4.3291624e+02 2.58e-04 1.70e+01  -5.7 4.63e-01  -5.4 6.55e-01 1.00e+00H  1
# 1787  4.3291672e+02 8.70e-05 3.87e+01  -5.7 8.55e-02  -4.1 4.22e-01 1.00e+00H  1
# 1788  4.3291631e+02 8.11e-05 2.88e+01  -5.7 9.56e-02  -3.7 3.30e-01 4.44e-01h  1
# 1789  4.3291627e+02 5.07e-05 3.15e+01  -5.7 4.11e-02  -4.2 1.69e-01 4.68e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1790  4.3291656e+02 6.20e-05 3.06e+01  -5.7 9.12e-02  -3.7 2.02e-01 4.19e-01f  1
# 1791  4.3291622e+02 2.41e-06 4.00e-03  -5.7 7.29e-03  -3.3 1.00e+00 1.00e+00f  1
# 1792  4.3291651e+02 1.55e-05 1.14e-03  -5.7 1.29e-02  -3.8 1.00e+00 1.00e+00h  1
# 1793  4.3291650e+02 4.12e-05 4.82e-04  -5.7 3.34e-02  -4.3 1.00e+00 1.00e+00h  1
# 1794  4.3291650e+02 9.60e-05 4.52e-04  -5.7 8.40e-02  -4.7 1.00e+00 1.00e+00h  1
# 1795  4.3291648e+02 1.00e-04 4.51e-04  -5.7 2.00e-01  -5.2 1.00e+00 1.00e+00h  1
# 1796  4.3291644e+02 1.62e-04 4.26e-04  -5.7 4.50e-01  -5.7 1.00e+00 1.00e+00h  1
# 1797  4.3291631e+02 5.30e-04 6.15e-04  -5.7 9.55e-01  -6.2 1.00e+00 1.00e+00h  1
# 1798  4.3291597e+02 3.01e-03 2.52e-03  -5.7 2.05e+00  -6.6 1.00e+00 1.00e+00h  1
# 1799  4.3291498e+02 1.94e-02 1.19e-02  -5.7 4.63e+00  -7.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1800  4.3291231e+02 1.24e-01 6.59e-02  -5.7 1.12e+01  -7.6 1.00e+00 1.00e+00h  1
# 1801  4.3290583e+02 1.44e+00 3.26e+00  -5.7 2.82e+01  -8.1 8.69e-01 1.00e+00h  1
# 1802  4.3290288e+02 4.54e-01 1.38e-01  -5.7 1.17e+01  -7.7 1.00e+00 1.00e+00h  1
# 1803  4.3289836e+02 7.84e-01 2.07e-01  -5.7 3.70e+01  -8.1 7.36e-01 7.38e-01h  1
# 1804  4.3289848e+02 7.83e-01 1.31e+02  -5.7 1.18e+00  -2.3 8.16e-03 1.54e-03h  1
# 1805  4.3290362e+02 2.68e-04 1.30e+02  -5.7 9.08e-02  -2.8 1.09e-01 1.00e+00f  1
# 1806  4.3290012e+02 9.01e-05 5.22e+01  -5.7 8.58e-03  -0.5 1.51e-01 6.63e-01h  1
# 1807  4.3290292e+02 3.67e-07 4.41e+01  -5.7 3.90e-03  -1.0 2.16e-01 1.00e+00f  1
# 1808  4.3289914e+02 7.57e-07 1.56e+01  -5.7 8.96e-03  -1.5 6.47e-01 4.64e-01h  1
# 1809  4.3289866e+02 4.35e-07 3.15e+01  -5.7 3.83e-03  -2.0 9.44e-01 6.32e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1810  4.3289916e+02 2.53e-06 1.22e+01  -5.7 7.38e-03  -2.4 8.73e-01 1.00e+00f  1
# 1811  4.3289891e+02 4.45e-06 1.85e-03  -5.7 9.08e-03  -2.9 1.00e+00 1.00e+00h  1
# 1812  4.3289865e+02 8.14e-06 1.61e-04  -5.7 7.99e-03  -3.4 1.00e+00 1.00e+00h  1
# 1813  4.3289864e+02 7.55e-06 1.06e-04  -5.7 9.02e-03  -3.9 1.00e+00 1.00e+00h  1
# 1814  4.3289859e+02 4.48e-06 4.38e-04  -5.7 1.75e-02  -4.3 1.00e+00 1.00e+00h  1
# 1815  4.3289854e+02 4.20e-06 9.07e-04  -5.7 2.79e-02  -4.8 1.00e+00 1.00e+00h  1
# 1816  4.3289853e+02 2.81e-07 3.59e-05  -5.7 5.22e-03  -4.4 1.00e+00 1.00e+00h  1
# 1817  4.3289853e+02 1.09e-06 9.40e-05  -5.7 1.52e-02  -4.9 1.00e+00 1.00e+00h  1
# 1818  4.3289853e+02 1.20e-07 6.31e-06  -5.7 5.81e-03  -4.4 1.00e+00 1.00e+00h  1
# 1819  4.3269718e+02 6.66e-04 4.92e+00  -7.0 2.18e-01  -4.9 4.78e-01 4.21e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1820  4.3257396e+02 1.58e-03 3.04e+01  -7.0 3.40e-01  -5.4 8.02e-01 4.43e-01h  1
# 1821  4.3247502e+02 5.48e-04 2.72e+01  -7.0 9.16e-03  -2.3 1.00e+00 6.53e-01f  1
# 1822  4.3243668e+02 1.41e-04 1.06e+01  -7.0 2.98e-03  -1.8 8.43e-01 7.44e-01f  1
# 1823  4.3242659e+02 4.48e-06 6.02e-03  -7.0 8.06e-03  -2.3 1.00e+00 1.00e+00f  1
# 1824  4.3243907e+02 4.04e-08 4.79e+01  -7.0 1.71e-02  -2.8 6.18e-01 1.00e+00H  1
# 1825  4.3243997e+02 4.29e-08 3.92e+01  -7.0 2.27e-02  -3.3 4.18e-01 4.50e-02h  4
# 1826  4.3244012e+02 4.62e-08 4.07e+01  -7.0 5.79e-02  -3.7 5.48e-01 8.47e-03h  7
# 1827  4.3244016e+02 4.62e-08 4.40e+01  -7.0 1.03e-01  -4.2 4.69e-01 2.15e-03h  9
# 1828  4.3244017e+02 4.62e-08 4.98e+01  -7.0 1.54e-01  -4.7 3.65e-01 7.38e-04h 10
# 1829  4.3244018e+02 4.62e-08 5.03e+01  -7.0 4.48e-01  -5.2 5.29e-02 5.04e-04h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1830  4.3245029e+02 3.56e-07 7.67e+01  -7.0 4.56e-02  -3.9 4.06e-01 1.00e+00H  1
# 1831  4.3245027e+02 3.41e-07 3.69e+01  -7.0 4.51e-02  -4.3 4.09e-01 2.66e-02h  6
# 1832  4.3245027e+02 3.40e-07 6.62e+01  -7.0 1.28e-01  -4.8 1.00e+00 5.72e-03h  8
# 1833  4.3244996e+02 5.29e-07 9.82e+01  -7.0 4.99e-02  -4.4 4.52e-01 1.00e+00H  1
# 1834  4.3244996e+02 5.89e-07 7.10e+01  -7.0 1.37e-01  -4.9 1.76e-01 1.03e-02h  5
# 1835  4.3244992e+02 8.59e-07 3.14e-03  -7.0 8.71e-03  -3.5 1.00e+00 1.00e+00H  1
# 1836  4.3244981e+02 7.70e-08 7.41e-03  -7.0 2.05e-02  -4.0 1.00e+00 1.00e+00H  1
# 1837  4.3244958e+02 7.11e-07 3.09e-03  -7.0 5.89e-02  -4.5 1.00e+00 1.00e+00H  1
# 1838  4.3244957e+02 9.76e-07 5.79e+01  -7.0 1.60e-01  -5.0 1.00e+00 2.65e-02h  6
# 1839  4.3244957e+02 1.09e-06 5.78e+01  -7.0 4.40e-01  -5.4 1.26e-01 5.27e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1840  4.3244957e+02 1.13e-06 5.76e+01  -7.0 2.41e-02  -4.1 1.00e+00 3.12e-02h  6
# 1841  4.3244937e+02 1.51e-04 4.68e-03  -7.0 6.98e-02  -4.6 1.00e+00 1.00e+00h  1
# 1842  4.3244890e+02 4.90e-04 1.34e-02  -7.0 1.93e-01  -5.1 1.00e+00 1.00e+00h  1
# 1843  4.3244837e+02 4.83e-04 1.73e-01  -7.0 5.00e-01  -5.5 5.60e-01 5.57e-01h  1
# 1844  4.3244718e+02 2.63e-03 1.33e-01  -7.0 1.10e+00  -6.0 6.07e-01 6.06e-01f  1
# 1845  4.3244636e+02 3.56e-03 1.03e-01  -7.0 2.10e+00  -6.5 2.09e-01 2.09e-01f  1
# 1846  4.3244535e+02 6.17e-03 3.83e-01  -7.0 4.69e+00  -7.0 1.60e-01 1.55e-01f  1
# 1847  4.3244536e+02 6.00e-03 7.72e+00  -7.0 1.79e-01  -2.9 1.52e-01 2.77e-02h  1
# 1848  4.3244536e+02 3.77e-06 5.33e-04  -7.0 1.27e-02  -3.4 1.00e+00 1.00e+00f  1
# 1849  4.3244535e+02 6.88e-07 2.85e-04  -7.0 5.20e-03  -3.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1850  4.3244533e+02 2.80e-06 3.59e-04  -7.0 1.31e-02  -4.4 1.00e+00 1.00e+00h  1
# 1851  4.3244528e+02 1.33e-05 1.89e-03  -7.0 4.01e-02  -4.8 1.00e+00 1.00e+00h  1
# 1852  4.3244524e+02 2.85e-05 2.94e+01  -7.0 1.10e-01  -5.3 9.89e-01 4.94e-01h  2
# 1853  4.3244528e+02 1.59e-07 4.71e-04  -7.0 2.13e-03  -3.1 1.00e+00 1.00e+00h  1
# 1854  4.3244527e+02 5.80e-08 1.23e-04  -7.0 2.07e-03  -3.6 1.00e+00 1.00e+00h  1
# 1855  4.3244525e+02 3.05e-07 2.44e-04  -7.0 5.44e-03  -4.0 1.00e+00 1.00e+00h  1
# 1856  4.3244523e+02 2.35e-06 5.95e-04  -7.0 1.71e-02  -4.5 1.00e+00 1.00e+00h  1
# 1857  4.3244522e+02 2.32e-06 4.04e+00  -7.0 5.42e-02  -5.0 1.37e-01 6.92e-02h  2
# 1858  4.3244523e+02 1.15e-06 3.09e+01  -7.0 3.58e-03  -2.8 1.00e+00 4.79e-01h  2
# 1859  4.3244522e+02 2.16e-08 7.04e-05  -7.0 1.15e-03  -3.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1860  4.3244522e+02 8.27e-08 1.18e-04  -7.0 2.34e-03  -3.7 1.00e+00 1.00e+00h  1
# 1861  4.3244520e+02 4.93e-07 2.20e-04  -7.0 7.58e-03  -4.2 1.00e+00 1.00e+00h  1
# 1862  4.3244516e+02 1.94e-08 2.98e+00  -7.0 2.23e-02  -4.7 9.75e-01 1.00e+00H  1
# 1863  4.3244516e+02 6.33e-07 9.65e-04  -7.0 9.16e-03  -4.2 1.00e+00 1.00e+00h  1
# 1864  4.3244512e+02 5.25e-06 5.02e-04  -7.0 2.38e-02  -4.7 1.00e+00 1.00e+00h  1
# 1865  4.3244503e+02 4.17e-05 7.37e-04  -7.0 7.08e-02  -5.2 1.00e+00 1.00e+00h  1
# 1866  4.3244479e+02 3.32e-04 6.73e+00  -7.0 2.01e-01  -5.7 8.85e-01 1.00e+00h  1
# 1867  4.3244447e+02 7.82e-04 1.06e+01  -7.0 6.27e-01  -6.2 7.12e-01 4.96e-01h  1
# 1868  4.3244452e+02 2.64e-06 2.91e+01  -7.0 1.09e-02  -3.9 3.86e-01 1.00e+00f  1
# 1869  4.3244447e+02 2.44e-07 3.72e-04  -7.0 1.14e-03  -2.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1870  4.3244447e+02 5.35e-08 7.80e-05  -7.0 6.93e-04  -3.1 1.00e+00 1.00e+00h  1
# 1871  4.3244447e+02 6.77e-08 5.73e-05  -7.0 1.45e-03  -3.5 1.00e+00 1.00e+00h  1
# 1872  4.3244447e+02 1.76e-07 1.01e-04  -7.0 4.31e-03  -4.0 1.00e+00 1.00e+00h  1
# 1873  4.3244446e+02 1.33e-06 2.69e-04  -7.0 1.28e-02  -4.5 1.00e+00 1.00e+00h  1
# 1874  4.3244446e+02 1.06e-05 1.99e+00  -7.0 3.80e-02  -5.0 9.35e-01 1.00e+00h  1
# 1875  4.3244442e+02 1.07e-04 1.49e-03  -7.0 1.12e-01  -5.5 1.00e+00 1.00e+00h  1
# 1876  4.3244442e+02 1.05e-04 1.19e-01  -7.0 8.30e-02  -4.1 3.78e-02 1.66e-02h  2
# 1877  4.3244437e+02 5.42e-07 9.38e-05  -7.0 4.89e-03  -3.7 1.00e+00 1.00e+00h  1
# 1878  4.3244438e+02 3.04e-10 8.96e-06  -7.0 5.87e-03  -4.2 1.00e+00 1.00e+00H  1
# 1879  4.3244436e+02 2.37e-06 1.90e-05  -7.0 1.77e-02  -4.7 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1880  4.3244429e+02 7.81e-07 1.12e-03  -7.0 5.23e-02  -5.1 1.00e+00 1.00e+00H  1
# 1881  4.3244427e+02 1.12e-05 3.55e+00  -7.0 2.24e-01  -5.6 1.00e+00 1.34e-01h  2
# 1882  4.3244381e+02 1.54e-03 5.04e-01  -7.0 4.45e-01  -6.1 8.75e-01 1.00e+00h  1
# 1883  4.3244363e+02 2.38e-04 4.84e-03  -7.0 1.70e-01  -5.7 1.00e+00 1.00e+00h  1
# 1884  4.3244312e+02 1.90e-03 5.82e-02  -7.0 5.06e-01  -6.1 8.87e-01 1.00e+00h  1
# 1885  4.3244246e+02 3.91e-03 1.96e-02  -7.0 1.62e+00  -6.6 4.51e-01 4.41e-01h  1
# 1886  4.3244215e+02 1.86e-02 8.91e-02  -7.0 2.13e+01  -7.1 4.82e-02 5.37e-02h  1
# 1887  4.3244196e+02 6.49e-03 2.40e-02  -7.0 4.30e-01  -5.8 7.30e-01 7.30e-01f  1
# 1888  4.3244139e+02 2.26e-03 6.24e-03  -7.0 5.92e-01  -6.2 1.00e+00 1.00e+00h  1
# 1889  4.3244063e+02 4.18e-03 3.42e-01  -7.0 1.60e+00  -6.7 1.00e+00 5.34e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1890  4.3244026e+02 1.36e-03 3.33e-03  -7.0 5.82e-01  -6.3 1.00e+00 1.00e+00f  1
# 1891  4.3243921e+02 1.25e-02 1.02e-02  -7.0 1.66e+00  -6.8 1.00e+00 1.00e+00h  1
# 1892  4.3243884e+02 1.34e-03 1.15e-03  -7.0 6.18e-01  -6.3 1.00e+00 1.00e+00h  1
# 1893  4.3243789e+02 1.07e-02 3.23e-02  -7.0 1.77e+00  -6.8 1.00e+00 9.64e-01h  1
# 1894  4.3243536e+02 8.50e-02 4.20e-02  -7.0 5.12e+00  -7.3 1.00e+00 1.00e+00f  1
# 1895  4.3243309e+02 1.32e-01 2.60e-01  -7.0 1.41e+01  -7.8 4.40e-01 3.74e-01h  1
# 1896  4.3243095e+02 2.16e-01 3.37e-01  -7.0 3.54e+01  -8.2 1.56e-01 1.44e-01h  1
# 1897  4.3243041e+02 2.15e-01 2.84e-01  -7.0 9.67e+01  -8.7 1.38e-02 1.74e-02h  1
# 1898  4.3243041e+02 2.15e-01 2.84e-01  -7.0 3.37e+00  -4.7 7.65e-06 4.77e-06h  2
# 1899  4.3243041e+02 2.15e-01 6.80e-01  -7.0 1.82e+02  -3.4 1.10e-04 7.34e-08h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1900  4.3243040e+02 5.25e-02 4.81e-01  -7.0 2.68e-02  -3.8 5.79e-01 7.56e-01h  1
# 1901  4.3243037e+02 4.39e-05 4.89e-04  -7.0 1.50e-02  -4.3 1.00e+00 1.00e+00f  1
# 1902  4.3243036e+02 2.84e-06 2.39e-04  -7.0 3.06e-02  -4.8 1.00e+00 1.00e+00h  1
# 1903  4.3243035e+02 5.62e-06 2.29e-05  -7.0 5.03e-02  -5.3 1.00e+00 1.00e+00h  1
# 1904  4.3243034e+02 7.53e-06 9.03e-02  -7.0 1.38e-01  -5.7 4.89e-01 2.46e-01h  2
# 1905  4.3243034e+02 6.52e-07 2.59e-04  -7.0 5.81e-03  -3.5 1.00e+00 1.00e+00h  1
# 1906  4.3243034e+02 1.01e-07 7.26e-06  -7.0 2.44e-03  -4.0 1.00e+00 1.00e+00h  1
# 1907  4.3243033e+02 1.59e-07 1.56e-05  -7.0 7.30e-03  -4.5 1.00e+00 1.00e+00h  1
# 1908  4.3243033e+02 1.53e-06 6.28e-07  -7.0 2.19e-02  -4.9 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1908
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3243032816374170e+00    4.3243032816374171e+02
# Dual infeasibility......:   6.2785315230922192e-07    6.2785315230922192e-05
# Constraint violation....:   2.8920387198338295e-07    1.5279614444807521e-06
# Complementarity.........:   9.0909091913651463e-08    9.0909091913651454e-06
# Overall NLP error.......:   6.2785315230922192e-07    6.2785315230922192e-05
#
#
# Number of objective function evaluations             = 2520
# Number of objective gradient evaluations             = 1793
# Number of equality constraint evaluations            = 2520
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1910
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1908
# Total CPU secs in IPOPT (w/o function evaluations)   =    420.450
# Total CPU secs in NLP function evaluations           =     35.050
#
# EXIT: Optimal Solution Found.
# ok
# optimal
# --------------------------------
# GROUND:   0.043197618278356845
# GROUND2:  1.5496080360832893e-08
# CONTACTS: 5.069313164795661e-06
# JOINT:    3.211485173913339e-06
# FORCE:    0.41739511074024743
# TORQUE:   0.05364642544505595
# --------------------------------
# Elapsed Time: 7.741925084590912 mins

# %%
# m.ptail_g.pprint()

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 100  # Set Duration To 1000 ms == 1 second
if (str(results.solver.termination_condition) == "optimal"):
    winsound.Beep(frequency, duration)
    winsound.Beep(frequency, duration)
    winsound.Beep(frequency, duration)
else:
    winsound.Beep(500, 500)

# %%
# CALCULATE MAX VALUES
maxvalues = skaterlib_biped_with_body_new.get_max_values(m, N, ground_constraints, contact_constraints, joint_constraints, joints, 
                                           WDOFs, DOF_b, Fs, signs, GRFs, legs)
maxForce = maxvalues[0]
maxGRF   = maxvalues[1]
maxGRFbf = maxvalues[2]
maxF_a   = maxvalues[3]

# %%
# reload(skaterlib_biped_with_body_new);
# m.q.pprint()
# m.dq.pprint()

# %%
# ANIMATE THE RESULTS
from IPython.display import HTML
# %matplotlib inline
Ns = [N,N1,N2,N3,Nhw]
animate = skaterlib_biped_with_body_new.make_animation(m, Ns, 'OD', X_step, Y_step, 0, 0, maxForce, maxGRF, maxGRFbf, maxF_a)
HTML(animate.to_html5_video()) #you need to convert the animation to HTML5 to embed it in the notebook
# Out:
# OD
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# m.dq.pprint()
m.pwheel.pprint()
# Out:
# pwheel : Size=260, Index=pwheel_index
#     Key             : Lower : Value                   : Upper : Fixed : Stale : Domain
#      (1, 'BW', 'X') :  None :                     0.0 :  None :  True :  True :  Reals
#      (1, 'BW', 'Y') :  None :      0.3600000073772887 :  None : False : False :  Reals
#      (1, 'FW', 'X') :  None :                    0.45 :  None : False : False :  Reals
#      (1, 'FW', 'Y') :  None :     0.36000000737730703 :  None : False : False :  Reals
#      (2, 'BW', 'X') :  None :      0.0701729008382082 :  None : False : False :  Reals
#      (2, 'BW', 'Y') :  None :     0.35999999784835024 :  None : False : False :  Reals
#      (2, 'FW', 'X') :  None :      0.5201729008382082 :  None : False : False :  Reals
#      (2, 'FW', 'Y') :  None :      0.3599999986965236 :  None : False : False :  Reals
#      (3, 'BW', 'X') :  None :      0.1388051023547202 :  None : False : False :  Reals
#      (3, 'BW', 'Y') :  None :      0.3599999939774757 :  None : False : False :  Reals
#      (3, 'FW', 'X') :  None :      0.5888043704992019 :  None : False : False :  Reals
#      (3, 'FW', 'Y') :  None :       0.360811578497509 :  None : False : False :  Reals
#      (4, 'BW', 'X') :  None :      0.1843865914931717 :  None : False : False :  Reals
#      (4, 'BW', 'Y') :  None :      0.3599999952867623 :  None : False : False :  Reals
#      (4, 'FW', 'X') :  None :      0.6343842263161513 :  None : False : False :  Reals
#      (4, 'FW', 'Y') :  None :      0.3614589859422827 :  None : False : False :  Reals
#      (5, 'BW', 'X') :  None :      0.2469297299063684 :  None : False : False :  Reals
#      (5, 'BW', 'Y') :  None :      0.3599999951401814 :  None : False : False :  Reals
#      (5, 'FW', 'X') :  None :      0.6969062480097122 :  None : False : False :  Reals
#      (5, 'FW', 'Y') :  None :      0.3645970763499056 :  None : False : False :  Reals
#      (6, 'BW', 'X') :  None :       0.309066892868999 :  None : False : False :  Reals
#      (6, 'BW', 'Y') :  None :       0.359999993279467 :  None : False : False :  Reals
#      (6, 'FW', 'X') :  None :      0.7589785309198465 :  None : False : False :  Reals
#      (6, 'FW', 'Y') :  None :      0.3689172768683521 :  None : False : False :  Reals
#      (7, 'BW', 'X') :  None :      0.3747656275387901 :  None : False : False :  Reals
#      (7, 'BW', 'Y') :  None :      0.3599999928952318 :  None : False : False :  Reals
#      (7, 'FW', 'X') :  None :      0.8245272651004507 :  None : False : False :  Reals
#      (7, 'FW', 'Y') :  None :       0.374644765968871 :  None : False : False :  Reals
#      (8, 'BW', 'X') :  None :      0.4209010610166658 :  None : False : False :  Reals
#      (8, 'BW', 'Y') :  None :      0.3599999928246971 :  None : False : False :  Reals
#      (8, 'FW', 'X') :  None :      0.8705064917882048 :  None : False : False :  Reals
#      (8, 'FW', 'Y') :  None :     0.37884028532832426 :  None : False : False :  Reals
#      (9, 'BW', 'X') :  None :      0.4942648181969448 :  None : False : False :  Reals
#      (9, 'BW', 'Y') :  None :       0.359999994315626 :  None : False : False :  Reals
#      (9, 'FW', 'X') :  None :       0.943361978912311 :  None : False : False :  Reals
#      (9, 'FW', 'Y') :  None :       0.388491049740192 :  None : False : False :  Reals
#     (10, 'BW', 'X') :  None :      0.5697968437310001 :  None : False : False :  Reals
#     (10, 'BW', 'Y') :  None :      0.3599999917467686 :  None : False : False :  Reals
#     (10, 'FW', 'X') :  None :      1.0179740108761812 :  None : False : False :  Reals
#     (10, 'FW', 'Y') :  None :     0.40046265172591206 :  None : False : False :  Reals
#     (11, 'BW', 'X') :  None :      0.6721256903861306 :  None : False : False :  Reals
#     (11, 'BW', 'Y') :  None :     0.35999998940246414 :  None : False : False :  Reals
#     (11, 'FW', 'X') :  None :      1.1185443602355722 :  None : False : False :  Reals
#     (11, 'FW', 'Y') :  None :      0.4166601271960262 :  None : False : False :  Reals
#     (12, 'BW', 'X') :  None :      0.7588447359608712 :  None : False : False :  Reals
#     (12, 'BW', 'Y') :  None :      0.3599999869916392 :  None : False : False :  Reals
#     (12, 'FW', 'X') :  None :      1.2023483968652333 :  None : False : False :  Reals
#     (12, 'FW', 'Y') :  None :     0.43618727444805944 :  None : False : False :  Reals
#     (13, 'BW', 'X') :  None :      0.8207754925427632 :  None : False : False :  Reals
#     (13, 'BW', 'Y') :  None :     0.35999998483437257 :  None : False : False :  Reals
#     (13, 'FW', 'X') :  None :      1.2611194242966524 :  None : False : False :  Reals
#     (13, 'FW', 'Y') :  None :     0.45272118944456946 :  None : False : False :  Reals
#     (14, 'BW', 'X') :  None :      0.8722970803167642 :  None : False : False :  Reals
#     (14, 'BW', 'Y') :  None :      0.3599999864273624 :  None : False : False :  Reals
#     (14, 'FW', 'X') :  None :      1.3091693860573521 :  None : False : False :  Reals
#     (14, 'FW', 'Y') :  None :     0.46790081355490376 :  None : False : False :  Reals
#     (15, 'BW', 'X') :  None :      0.9515490746201182 :  None : False : False :  Reals
#     (15, 'BW', 'Y') :  None :      0.3599999852539096 :  None : False : False :  Reals
#     (15, 'FW', 'X') :  None :      1.3796511646061222 :  None : False : False :  Reals
#     (15, 'FW', 'Y') :  None :      0.4986672148335624 :  None : False : False :  Reals
#     (16, 'BW', 'X') :  None :      1.0049546364874782 :  None : False : False :  Reals
#     (16, 'BW', 'Y') :  None :      0.3600001816670608 :  None : False : False :  Reals
#     (16, 'FW', 'X') :  None :      1.4260556554528474 :  None : False : False :  Reals
#     (16, 'FW', 'Y') :  None :      0.5186631320731124 :  None : False : False :  Reals
#     (17, 'BW', 'X') :  None :       1.085429348969509 :  None : False : False :  Reals
#     (17, 'BW', 'Y') :  None :     0.36000010206629074 :  None : False : False :  Reals
#     (17, 'FW', 'X') :  None :      1.4945928182416672 :  None : False : False :  Reals
#     (17, 'FW', 'Y') :  None :      0.5473106874958158 :  None : False : False :  Reals
#     (18, 'BW', 'X') :  None :       1.139511741676566 :  None : False : False :  Reals
#     (18, 'BW', 'Y') :  None :      0.3600001853388436 :  None : False : False :  Reals
#     (18, 'FW', 'X') :  None :      1.5396948140230735 :  None : False : False :  Reals
#     (18, 'FW', 'Y') :  None :      0.5657998661143755 :  None : False : False :  Reals
#     (19, 'BW', 'X') :  1.19 :      1.1999999740807827 :  None : False : False :  Reals
#     (19, 'BW', 'Y') :  None :      0.3258230559662326 :  None : False : False :  Reals
#     (19, 'FW', 'X') :  None :      1.6001774325696796 :  None : False : False :  Reals
#     (19, 'FW', 'Y') :  None :      0.5316336526743943 :  None : False : False :  Reals
#     (20, 'BW', 'X') :  None :      1.2374567772976957 :  None : False : False :  Reals
#     (20, 'BW', 'Y') :  None :      0.2705456121301018 :  None : False : False :  Reals
#     (20, 'FW', 'X') :  None :       1.651749925804649 :  None : False : False :  Reals
#     (20, 'FW', 'Y') :  None :     0.44621913631686777 :  None : False : False :  Reals
#     (21, 'BW', 'X') :  None :        1.26811779867573 :  None : False : False :  Reals
#     (21, 'BW', 'Y') :  None :     0.20276355197166662 :  None : False : False :  Reals
#     (21, 'FW', 'X') :  None :       1.697866492040687 :  None : False : False :  Reals
#     (21, 'FW', 'Y') :  None :       0.336240368502162 :  None : False : False :  Reals
#     (22, 'BW', 'X') :  None :      1.3006527801257608 :  None : False : False :  Reals
#     (22, 'BW', 'Y') :  None :        0.13509740320993 :  None : False : False :  Reals
#     (22, 'FW', 'X') :  None :      1.7415706250418614 :  None : False : False :  Reals
#     (22, 'FW', 'Y') :  None :      0.2250499130945781 :  None : False : False :  Reals
#     (23, 'BW', 'X') :  None :       1.335207924629469 :  None : False : False :  Reals
#     (23, 'BW', 'Y') :  None :     0.06734419041772888 :  None : False : False :  Reals
#     (23, 'FW', 'X') :  None :      1.7828987297209284 :  None : False : False :  Reals
#     (23, 'FW', 'Y') :  None :      0.1128737746084034 :  None : False : False :  Reals
#     (24, 'BW', 'X') :  None :      1.3717729618045111 :  None : False : False :  Reals
#     (24, 'BW', 'Y') :  None :  -1.529913501017606e-08 :  None : False : False :  Reals
#     (24, 'FW', 'X') :  None :       1.821772961804511 :  None : False : False :  Reals
#     (24, 'FW', 'Y') :  None :  -1.602550397555184e-08 :  None : False : False :  Reals
#     (25, 'BW', 'X') :  None :       1.412324135237015 :  None : False : False :  Reals
#     (25, 'BW', 'Y') :  None :  -1.224145742824328e-08 :  None : False : False :  Reals
#     (25, 'FW', 'X') :  None :       1.862324135237015 :  None : False : False :  Reals
#     (25, 'FW', 'Y') :  None :  -7.142435768169162e-09 :  None : False : False :  Reals
#     (26, 'BW', 'X') :  None :      1.4435453942805532 :  None : False : False :  Reals
#     (26, 'BW', 'Y') :  None :    0.018939257007065637 :  None : False : False :  Reals
#     (26, 'FW', 'X') :  None :       1.893545394280435 :  None : False : False :  Reals
#     (26, 'FW', 'Y') :  None :    0.018938930584185564 :  None : False : False :  Reals
#     (27, 'BW', 'X') :  None :      1.4903773770702622 :  None : False : False :  Reals
#     (27, 'BW', 'Y') :  None :     0.06679719862198664 :  None : False : False :  Reals
#     (27, 'FW', 'X') :  None :      1.9403773770701607 :  None : False : False :  Reals
#     (27, 'FW', 'Y') :  None :     0.06679689611853411 :  None : False : False :  Reals
#     (28, 'BW', 'X') :  None :      1.5372093528718576 :  None : False : False :  Reals
#     (28, 'BW', 'Y') :  None :     0.11324249812926818 :  None : False : False :  Reals
#     (28, 'FW', 'X') :  None :      1.9872093528717696 :  None : False : False :  Reals
#     (28, 'FW', 'Y') :  None :      0.1132422164271009 :  None : False : False :  Reals
#     (29, 'BW', 'X') :  None :      1.5840413283885326 :  None : False : False :  Reals
#     (29, 'BW', 'Y') :  None :     0.15827515699226444 :  None : False : False :  Reals
#     (29, 'FW', 'X') :  None :      2.0340413283884566 :  None : False : False :  Reals
#     (29, 'FW', 'Y') :  None :     0.15827489513745874 :  None : False : False :  Reals
#     (30, 'BW', 'X') :  None :      1.6308733036859155 :  None : False : False :  Reals
#     (30, 'BW', 'Y') :  None :     0.20189517342160979 :  None : False : False :  Reals
#     (30, 'FW', 'X') :  None :      2.0808733036858507 :  None : False : False :  Reals
#     (30, 'FW', 'Y') :  None :     0.20189493132176028 :  None : False : False :  Reals
#     (31, 'BW', 'X') :  None :       1.677705278688119 :  None : False : False :  Reals
#     (31, 'BW', 'Y') :  None :     0.24410254645485227 :  None : False : False :  Reals
#     (31, 'FW', 'X') :  None :      2.1277052786880644 :  None : False : False :  Reals
#     (31, 'FW', 'Y') :  None :      0.2441023243185245 :  None : False : False :  Reals
#     (32, 'BW', 'X') :  None :       1.724537253262612 :  None : False : False :  Reals
#     (32, 'BW', 'Y') :  None :     0.28489727520380603 :  None : False : False :  Reals
#     (32, 'FW', 'X') :  None :       2.174537253262567 :  None : False : False :  Reals
#     (32, 'FW', 'Y') :  None :     0.28489707355603183 :  None : False : False :  Reals
#     (33, 'BW', 'X') :  None :      1.7713692273237134 :  None : False : False :  Reals
#     (33, 'BW', 'Y') :  None :     0.32427935855037504 :  None : False : False :  Reals
#     (33, 'FW', 'X') :  None :      2.2213692273236774 :  None : False : False :  Reals
#     (33, 'FW', 'Y') :  None :      0.3242791782603446 :  None : False : False :  Reals
#     (34, 'BW', 'X') :  None :      1.8182012008222632 :  None : False : False :  Reals
#     (34, 'BW', 'Y') :  None :     0.36224879494973494 :  None : False : False :  Reals
#     (34, 'FW', 'X') :  None :      2.2682012008222356 :  None : False : False :  Reals
#     (34, 'FW', 'Y') :  None :     0.36224863731932316 :  None : False : False :  Reals
#     (35, 'BW', 'X') :  None :      1.8650331743083783 :  None : False : False :  Reals
#     (35, 'BW', 'Y') :  None :      0.3988055826714942 :  None : False : False :  Reals
#     (35, 'FW', 'X') :  None :       2.315033174308359 :  None : False : False :  Reals
#     (35, 'FW', 'Y') :  None :      0.3988054503173139 :  None : False : False :  Reals
#     (36, 'BW', 'X') :  None :       1.911865148638931 :  None : False : False :  Reals
#     (36, 'BW', 'Y') :  None :      0.4339497188032089 :  None : False : False :  Reals
#     (36, 'FW', 'X') :  None :      2.3618651486389197 :  None : False : False :  Reals
#     (36, 'FW', 'Y') :  None :      0.4339496167505556 :  None : False : False :  Reals
#     (37, 'BW', 'X') :  None :       1.958697125035352 :  None : False : False :  Reals
#     (37, 'BW', 'Y') :  None :     0.46768119698481836 :  None : False : False :  Reals
#     (37, 'FW', 'X') :  None :      2.4086971250353475 :  None : False : False :  Reals
#     (37, 'FW', 'Y') :  None :      0.4676811347407349 :  None : False : False :  Reals
#     (38, 'BW', 'X') :  None :        2.00552910733958 :  None : False : False :  Reals
#     (38, 'BW', 'Y') :  None :      0.4999999942500616 :  None : False : False :  Reals
#     (38, 'FW', 'X') :  None :      2.4555291073395797 :  None : False : False :  Reals
#     (38, 'FW', 'Y') :  None :      0.4999999957638323 :  None : False : False :  Reals
#     (39, 'BW', 'X') :  None :       2.038480020605486 :  None : False : False :  Reals
#     (39, 'BW', 'Y') :  None :     0.49744561021087963 :  None : False : False :  Reals
#     (39, 'FW', 'X') :  None :      2.4884759994266106 :  None : False : False :  Reals
#     (39, 'FW', 'Y') :  None :      0.4993479889372643 :  None : False : False :  Reals
#     (40, 'BW', 'X') :  None :       2.072556137916553 :  None : False : False :  Reals
#     (40, 'BW', 'Y') :  None :      0.4881835018933355 :  None : False : False :  Reals
#     (40, 'FW', 'X') :  None :       2.522516101687034 :  None : False : False :  Reals
#     (40, 'FW', 'Y') :  None :      0.4941860849776383 :  None : False : False :  Reals
#     (41, 'BW', 'X') :  None :      2.1072726766196683 :  None : False : False :  Reals
#     (41, 'BW', 'Y') :  None :      0.4759930443448435 :  None : False : False :  Reals
#     (41, 'FW', 'X') :  None :      2.5571429029603623 :  None : False : False :  Reals
#     (41, 'FW', 'Y') :  None :      0.4867994985402914 :  None : False : False :  Reals
#     (42, 'BW', 'X') :  None :      2.1424803292985755 :  None : False : False :  Reals
#     (42, 'BW', 'Y') :  None :     0.46118794202633717 :  None : False : False :  Reals
#     (42, 'FW', 'X') :  None :       2.592195659949577 :  None : False : False :  Reals
#     (42, 'FW', 'Y') :  None :      0.4771917346319824 :  None : False : False :  Reals
#     (43, 'BW', 'X') :  None :      2.1779048554793254 :  None : False : False :  Reals
#     (43, 'BW', 'Y') :  None :       0.444126793538963 :  None : False : False :  Reals
#     (43, 'FW', 'X') :  None :      2.6273992935427772 :  None : False : False :  Reals
#     (43, 'FW', 'Y') :  None :      0.4654516651841114 :  None : False : False :  Reals
#     (44, 'BW', 'X') :  None :      2.2133832734034984 :  None : False : False :  Reals
#     (44, 'BW', 'Y') :  None :     0.42513460997782965 :  None : False : False :  Reals
#     (44, 'FW', 'X') :  None :      2.6626030457807257 :  None : False : False :  Reals
#     (44, 'FW', 'Y') :  None :     0.45162226949145845 :  None : False : False :  Reals
#     (45, 'BW', 'X') :  None :       2.248736548078334 :  None : False : False :  Reals
#     (45, 'BW', 'Y') :  None :     0.40465672520607066 :  None : False : False :  Reals
#     (45, 'FW', 'X') :  None :      2.6976671821649902 :  None : False : False :  Reals
#     (45, 'FW', 'Y') :  None :      0.4356613342232627 :  None : False : False :  Reals
#     (46, 'BW', 'X') :  None :       2.284044196908665 :  None : False : False :  Reals
#     (46, 'BW', 'Y') :  None :      0.3827932799996488 :  None : False : False :  Reals
#     (46, 'FW', 'X') :  None :       2.732701809693148 :  None : False : False :  Reals
#     (46, 'FW', 'Y') :  None :     0.41752577908699656 :  None : False : False :  Reals
#     (47, 'BW', 'X') :  None :       2.319205337579442 :  None : False : False :  Reals
#     (47, 'BW', 'Y') :  None :     0.35969951561833685 :  None : False : False :  Reals
#     (47, 'FW', 'X') :  None :      2.7676284481603193 :  None : False : False :  Reals
#     (47, 'FW', 'Y') :  None :      0.3973387757067806 :  None : False : False :  Reals
#     (48, 'BW', 'X') :  None :       2.354190422257549 :  None : False : False :  Reals
#     (48, 'BW', 'Y') :  None :     0.33550454757541576 :  None : False : False :  Reals
#     (48, 'FW', 'X') :  None :       2.802433709403413 :  None : False : False :  Reals
#     (48, 'FW', 'Y') :  None :     0.37522803599626803 :  None : False : False :  Reals
#     (49, 'BW', 'X') :  None :      2.3890294399453165 :  None : False : False :  Reals
#     (49, 'BW', 'Y') :  None :      0.3103141470234263 :  None : False : False :  Reals
#     (49, 'FW', 'X') :  None :       2.837161642736578 :  None : False : False :  Reals
#     (49, 'FW', 'Y') :  None :      0.3512717937495708 :  None : False : False :  Reals
#     (50, 'BW', 'X') :  None :      2.4239146163036267 :  None : False : False :  Reals
#     (50, 'BW', 'Y') :  None :     0.28415043354492503 :  None : False : False :  Reals
#     (50, 'FW', 'X') :  None :        2.87202279140025 :  None : False : False :  Reals
#     (50, 'FW', 'Y') :  None :      0.3253701304792539 :  None : False : False :  Reals
#     (51, 'BW', 'X') :  None :       2.458795221929645 :  None : False : False :  Reals
#     (51, 'BW', 'Y') :  None :     0.25696965091719925 :  None : False : False :  Reals
#     (51, 'FW', 'X') :  None :       2.906999242372774 :  None : False : False :  Reals
#     (51, 'FW', 'Y') :  None :      0.2971337650225999 :  None : False : False :  Reals
#     (52, 'BW', 'X') :  None :       2.494240001015628 :  None : False : False :  Reals
#     (52, 'BW', 'Y') :  None :      0.2288191515392752 :  None : False : False :  Reals
#     (52, 'FW', 'X') :  None :      2.9426473991477526 :  None : False : False :  Reals
#     (52, 'FW', 'Y') :  None :        0.26664513866894 :  None : False : False :  Reals
#     (53, 'BW', 'X') :  None :      2.5302063551545677 :  None : False : False :  Reals
#     (53, 'BW', 'Y') :  None :       0.199776623883735 :  None : False : False :  Reals
#     (53, 'FW', 'X') :  None :      2.9789085245984923 :  None : False : False :  Reals
#     (53, 'FW', 'Y') :  None :     0.23392868293250021 :  None : False : False :  Reals
#     (54, 'BW', 'X') :  None :       2.566425331079072 :  None : False : False :  Reals
#     (54, 'BW', 'Y') :  None :      0.1699041687385638 :  None : False : False :  Reals
#     (54, 'FW', 'X') :  None :      3.0153930676511984 :  None : False : False :  Reals
#     (54, 'FW', 'Y') :  None :     0.20036679366593138 :  None : False : False :  Reals
#     (55, 'BW', 'X') :  None :       2.602597023805109 :  None : False : False :  Reals
#     (55, 'BW', 'Y') :  None :     0.13944848148236205 :  None : False : False :  Reals
#     (55, 'FW', 'X') :  None :      3.0517986606883207 :  None : False : False :  Reals
#     (55, 'FW', 'Y') :  None :      0.1662419400393425 :  None : False : False :  Reals
#     (56, 'BW', 'X') :  None :       2.656259063423573 :  None : False : False :  Reals
#     (56, 'BW', 'Y') :  None :     0.09289789422485017 :  None : False : False :  Reals
#     (56, 'FW', 'X') :  None :      3.1057514480042316 :  None : False : False :  Reals
#     (56, 'FW', 'Y') :  None :      0.1142660060749155 :  None : False : False :  Reals
#     (57, 'BW', 'X') :  None :      2.6923182205525444 :  None : False : False :  Reals
#     (57, 'BW', 'Y') :  None :     0.06100990481771232 :  None : False : False :  Reals
#     (57, 'FW', 'X') :  None :      3.1419689623013705 :  None : False : False :  Reals
#     (57, 'FW', 'Y') :  None :     0.07873588701254827 :  None : False : False :  Reals
#     (58, 'BW', 'X') :  None :       2.746293498367738 :  None : False : False :  Reals
#     (58, 'BW', 'Y') :  None :    0.011903890561184035 :  None : False : False :  Reals
#     (58, 'FW', 'X') :  None :        3.19612604408256 :  None : False : False :  Reals
#     (58, 'FW', 'Y') :  None :      0.0241791019942475 :  None : False : False :  Reals
#     (59, 'BW', 'X') :  None :       2.785272345308709 :  None : False : False :  Reals
#     (59, 'BW', 'Y') :  None : -1.1681053985783493e-08 :  None : False : False :  Reals
#     (59, 'FW', 'X') :  None :      3.2352723453087093 :  None : False : False :  Reals
#     (59, 'FW', 'Y') :  None : -1.0375087252372598e-08 :  None : False : False :  Reals
#     (60, 'BW', 'X') :   1.2 :       2.877916756983555 :  None : False : False :  Reals
#     (60, 'BW', 'Y') :  None : -5.5532574427769906e-09 :  None : False : False :  Reals
#     (60, 'FW', 'X') :  None :      3.3279167569835546 :  None : False : False :  Reals
#     (60, 'FW', 'Y') :  None :  -4.303018380114775e-09 :  None : False : False :  Reals
#     (61, 'BW', 'X') :  None :       2.930635700903573 :  None : False : False :  Reals
#     (61, 'BW', 'Y') :  None :   5.710432377539652e-08 :  None : False : False :  Reals
#     (61, 'FW', 'X') :  None :      3.3806357009035692 :  None : False : False :  Reals
#     (61, 'FW', 'Y') :  None :  -2.060323532548652e-09 :  None : False : False :  Reals
#     (62, 'BW', 'X') :  None :       3.009553293966703 :  None : False : False :  Reals
#     (62, 'BW', 'Y') :  None :   5.749625891465881e-08 :  None : False : False :  Reals
#     (62, 'FW', 'X') :  None :       3.459553293966703 :  None : False : False :  Reals
#     (62, 'FW', 'Y') :  None :   5.845427445549738e-08 :  None : False : False :  Reals
#     (63, 'BW', 'X') :  None :        3.07731377596713 :  None : False : False :  Reals
#     (63, 'BW', 'Y') :  None :   5.770074353313027e-08 :  None : False : False :  Reals
#     (63, 'FW', 'X') :  None :      3.5273137759671296 :  None : False : False :  Reals
#     (63, 'FW', 'Y') :  None :  5.8545573544354525e-08 :  None : False : False :  Reals
#     (64, 'BW', 'X') :  None :       3.129947256928182 :  None : False : False :  Reals
#     (64, 'BW', 'Y') :  None :  5.7752892306710114e-08 :  None : False : False :  Reals
#     (64, 'FW', 'X') :  None :      3.5799472569281816 :  None : False : False :  Reals
#     (64, 'FW', 'Y') :  None :  5.8697993371925075e-08 :  None : False : False :  Reals
#     (65, 'BW', 'X') :   2.0 :       3.204040856953317 :  None : False : False :  Reals
#     (65, 'BW', 'Y') :  None :  -4.524927786158283e-09 :  None : False : False :  Reals
#     (65, 'FW', 'X') :  None :       3.654040856953317 :  None : False : False :  Reals
#     (65, 'FW', 'Y') :  None :  -3.684222489066118e-09 :  None : False : False :  Reals

# %%
# m.ground_contact.pprint()

# %%
# ANIMATE THE RESULTS
from IPython.display import HTML
# %matplotlib inline

animate_realtime = skaterlib_biped_with_body_new.make_realtime_animation(m, N, hm)
HTML(animate_realtime.to_html5_video()) #you need to convert the animation to HTML5 to embed it in the notebook
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
import matplotlib.pyplot as plt

# Plot some of the variables
F_BFxar  = [BW*m.Fb_b_total[i,'BF','x_b']() for i in range(1,N+1)]
F_FFxar  = [BW*m.Fb_b_total[i,'FF','x_b']() for i in range (1,N+1)]
F_BFyar  = [BW*m.Fb_b_total[i,'BF','y_b']() for i in range(1,N+1)]
F_FFyar  = [BW*m.Fb_b_total[i,'FF','y_b']() for i in range (1,N+1)]
GRF_BWar = [BW*(m.GRF[i,'BW']()+m.GRF_s[i,'BW']()) for i in range(1,N+1)]
GRF_FWar = [BW*(m.GRF[i,'FW']()+m.GRF_s[i,'FW']()) for i in range(1,N+1)]
tau_bar = [BW*m.tau_b[i]() for i in range (1,N+1)]
tau_a_BLar = [BW*m.tau_a[i,'BL']() for i in range (1,N+1)]
tau_a_FLar = [BW*m.tau_a[i,'FL']() for i in range (1,N+1)]
GfuncBWY = [m.Gfunc[i,'BW','Y']() for i in range (1,N+1)]
GfuncBWX = [m.pwheel[i,'BW','X']() for i in range (1,N+1)]
GfuncFWY = [m.Gfunc[i,'FW','Y']() for i in range (1,N+1)]
GfuncFWX = [m.pwheel[i,'FW','X']() for i in range (1,N+1)]

# tarr = [m.h[i]() for i in range (1,N+1)]
# t = hm*np.cumsum(np.asarray(tarr))
# t -= t[0]

nar = np.linspace(1,N,N)

plt.figure(figsize=(15, 15))
plt.subplot(4,1,1)
plt.step(nar, F_BFxar,where='post')
plt.step(nar, F_FFxar,where='post')
plt.title('Friction Force (x)')
plt.xlabel('N')
plt.legend([r'$F_{BFx}$',r'$F_{FFx}$'])
plt.grid(True)

plt.subplot(4,1,2)
plt.step(nar, F_BFyar,where='post')
plt.step(nar, F_FFyar,where='post')
plt.title('Normal Force (y)')
plt.xlabel('N')
plt.legend([r'$F_{BFy}$',r'$F_{FFy}$'])
plt.grid(True)

plt.subplot(4,1,3)
plt.step(nar, GRF_BWar,where='post')
plt.step(nar, GRF_FWar,where='post')
plt.title('Ground Reaction Forces')
plt.xlabel('N')
plt.legend([r'$GRF_{BW}$',r'$GRF_{FW}$'])
plt.grid(True)

plt.subplot(4,1,4)
plt.step(GfuncBWX, GfuncBWY,where='post')
plt.step(GfuncFWX, GfuncFWY,where='post')
plt.title('Ground Function')
plt.xlabel('$x_{BW}$')
plt.ylabel('$y_{BW}$')
# plt.legend([r'$GRF_{BW}$',r'$GRF_{FW}$'])
plt.grid(True)

# plt.subplot(4,1,4)
# plt.step(nar,tau_bar,where ='post')
# plt.step(nar,tau_a_BLar,where ='post')
# plt.step(nar,tau_a_FLar,where ='post')
# plt.title('Applied Torques')
# plt.xlabel('N')
# plt.legend([r'$\tau_{body}$',r'$\tau_{BL}$',r'$\tau_{FL}$'])
# plt.grid(True)

plt.tight_layout()

# %%
# m.Gfunc.pprint()

# %%
# maxGRF

# %%
from datetime import datetime

now = datetime.now() # dd/mm/YY H:M:S
dt_string = now.strftime("%d_%m_%Y_%H_%M.pkl")

Ns = m.N.bounds()[1]

modelname = 'model_biped_OD_N'+str(Ns)+ '_' + dt_string 
filepath = 'saved_models\\'
filename = filepath+modelname
print(filename)

if (str(results.solver.termination_condition) == "optimal"):
    with open(filename, mode='wb') as file:
        cloudpickle.dump(m, file)
        print("model saved")
else:
    print("model not saved - not optimal solution.")
# Out:
# saved_models\model_biped_OD_N65_11_10_2019_13_05.pkl
# model saved
